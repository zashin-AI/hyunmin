# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*14*14, input_dim=100, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((14, 14, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 25088)             2533888
# _________________________________________________________________
# batch_normalization (BatchNo (None, 25088)             100352
# _________________________________________________________________
# reshape (Reshape)            (None, 14, 14, 128)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 28, 28, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 28, 28, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 28, 28, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 28, 28, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 56, 56, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 56, 56, 1)         1601
# =================================================================
# Total params: 2,840,961
# Trainable params: 2,790,657
# Non-trainable params: 50,304
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(56,56,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 28, 28, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 28, 28, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 28, 28, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 14, 14, 128)       204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 14, 14, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 14, 14, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 25088)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 25089
# =================================================================
# Total params: 231,681
# Trainable params: 0
# Non-trainable params: 231,681
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(100,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 56, 56, 1)         2840961
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 231681
# =================================================================
# Total params: 3,072,642
# Trainable params: 2,790,657
# Non-trainable params: 281,985
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\f\\slr_f_data.npy')
x_train = []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (56,56))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (128, 173)
# (56, 56)
# (4680, 56, 56)

# %%
#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):

  # 데이터 불러오기
  X_train = x_train.reshape(x_train.shape[0], 56, 56, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  
  print(X_train.shape)   # (19184, 56, 56, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, 100))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, 100))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 56, 56, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[1], (128, 173))
            print(gen_mels.shape) # (173, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 173)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels,
                      sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (22016,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan02\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
  
            print("end")


gan_train(4001, 32, 100)
# Out:
# 4574
# epoch:3531  d_loss:0.0000  g_loss:16.3978
# epoch:3532  d_loss:0.0000  g_loss:16.4713
# epoch:3533  d_loss:0.0000  g_loss:16.4749
# epoch:3534  d_loss:0.0000  g_loss:16.5210
# epoch:3535  d_loss:0.0000  g_loss:16.5222
# epoch:3536  d_loss:0.0000  g_loss:16.5973
# epoch:3537  d_loss:0.0000  g_loss:16.5663
# epoch:3538  d_loss:0.0000  g_loss:16.5114
# epoch:3539  d_loss:0.0000  g_loss:16.4352
# epoch:3540  d_loss:0.0000  g_loss:16.5436
# epoch:3541  d_loss:0.0000  g_loss:16.2925
# epoch:3542  d_loss:0.0000  g_loss:16.4603
# epoch:3543  d_loss:0.0000  g_loss:16.4142
# epoch:3544  d_loss:0.0000  g_loss:16.3345
# epoch:3545  d_loss:0.0000  g_loss:16.5278
# epoch:3546  d_loss:0.0000  g_loss:16.5048
# epoch:3547  d_loss:0.0000  g_loss:16.3683
# epoch:3548  d_loss:0.0000  g_loss:16.6124
# epoch:3549  d_loss:0.0000  g_loss:16.5469
# epoch:3550  d_loss:0.0000  g_loss:16.6879
# epoch:3551  d_loss:0.0000  g_loss:16.5722
# epoch:3552  d_loss:0.0000  g_loss:16.4787
# epoch:3553  d_loss:0.0000  g_loss:16.4531
# epoch:3554  d_loss:0.0000  g_loss:16.6848
# epoch:3555  d_loss:0.0000  g_loss:16.5338
# epoch:3556  d_loss:0.0000  g_loss:16.4468
# epoch:3557  d_loss:0.0000  g_loss:16.5458
# epoch:3558  d_loss:0.0000  g_loss:16.6535
# epoch:3559  d_loss:0.0000  g_loss:16.4342
# epoch:3560  d_loss:0.0000  g_loss:16.4540
# epoch:3561  d_loss:0.0000  g_loss:16.4058
# epoch:3562  d_loss:0.0000  g_loss:16.6095
# epoch:3563  d_loss:0.0000  g_loss:16.3014
# epoch:3564  d_loss:0.0000  g_loss:16.4691
# epoch:3565  d_loss:0.0000  g_loss:16.5640
# epoch:3566  d_loss:0.0000  g_loss:16.4502
# epoch:3567  d_loss:0.0000  g_loss:16.5356
# epoch:3568  d_loss:0.0000  g_loss:16.5796
# epoch:3569  d_loss:0.0000  g_loss:16.5592
# epoch:3570  d_loss:0.0000  g_loss:16.4264
# epoch:3571  d_loss:0.0000  g_loss:16.3705
# epoch:3572  d_loss:0.0000  g_loss:16.5658
# epoch:3573  d_loss:0.0000  g_loss:16.4281
# epoch:3574  d_loss:0.0000  g_loss:16.4335
# epoch:3575  d_loss:0.0000  g_loss:16.3105
# epoch:3576  d_loss:0.0000  g_loss:16.4951
# epoch:3577  d_loss:0.0000  g_loss:16.4551
# epoch:3578  d_loss:0.0000  g_loss:16.5528
# epoch:3579  d_loss:0.0000  g_loss:16.6145
# epoch:3580  d_loss:0.0000  g_loss:16.4162
# epoch:3581  d_loss:0.0000  g_loss:16.6593
# epoch:3582  d_loss:0.0000  g_loss:16.4451
# epoch:3583  d_loss:0.0000  g_loss:16.7460
# epoch:3584  d_loss:0.0000  g_loss:16.5960
# epoch:3585  d_loss:0.0000  g_loss:16.7065
# epoch:3586  d_loss:0.0000  g_loss:16.8247
# epoch:3587  d_loss:0.0000  g_loss:16.6394
# epoch:3588  d_loss:0.0000  g_loss:16.7069
# epoch:3589  d_loss:0.0000  g_loss:16.4780
# epoch:3590  d_loss:0.0000  g_loss:16.4845
# epoch:3591  d_loss:0.0000  g_loss:16.3258
# epoch:3592  d_loss:0.0000  g_loss:16.3577
# epoch:3593  d_loss:0.0000  g_loss:16.3764
# epoch:3594  d_loss:0.0000  g_loss:16.5010
# epoch:3595  d_loss:0.0000  g_loss:16.4653
# epoch:3596  d_loss:0.0000  g_loss:16.4834
# epoch:3597  d_loss:0.0000  g_loss:16.3649
# epoch:3598  d_loss:0.0000  g_loss:16.4796
# epoch:3599  d_loss:0.0000  g_loss:16.6213
# epoch:3600  d_loss:0.0000  g_loss:16.6370
# (25, 56, 56, 1)
# (173, 128)
# (128, 173)
# (22016,)
# end
# epoch:3601  d_loss:0.0000  g_loss:16.5229
# epoch:3602  d_loss:0.0000  g_loss:16.5604
# epoch:3603  d_loss:0.0000  g_loss:16.6672
# epoch:3604  d_loss:0.0000  g_loss:16.6075
# epoch:3605  d_loss:0.0000  g_loss:16.4917
# epoch:3606  d_loss:0.0000  g_loss:16.6308
# epoch:3607  d_loss:0.0000  g_loss:16.6308
# epoch:3608  d_loss:0.0000  g_loss:16.4394
# epoch:3609  d_loss:0.0000  g_loss:16.4587
# epoch:3610  d_loss:0.0000  g_loss:16.3526
# epoch:3611  d_loss:0.0000  g_loss:16.3468
# epoch:3612  d_loss:0.0000  g_loss:16.3254
# epoch:3613  d_loss:0.0000  g_loss:16.3834
# epoch:3614  d_loss:0.0000  g_loss:16.3677
# epoch:3615  d_loss:0.0000  g_loss:16.5503
# epoch:3616  d_loss:0.0000  g_loss:16.5350
# epoch:3617  d_loss:0.0000  g_loss:16.7101
# epoch:3618  d_loss:0.0000  g_loss:16.5326
# epoch:3619  d_loss:0.0000  g_loss:16.5323
# epoch:3620  d_loss:0.0000  g_loss:16.6822
# epoch:3621  d_loss:0.0000  g_loss:16.6046
# epoch:3622  d_loss:0.0000  g_loss:16.6832
# epoch:3623  d_loss:0.0000  g_loss:16.7817
# epoch:3624  d_loss:0.0000  g_loss:16.7161
# epoch:3625  d_loss:0.0000  g_loss:16.5999
# epoch:3626  d_loss:0.0000  g_loss:16.5626
# epoch:3627  d_loss:0.0000  g_loss:16.5167
# epoch:3628  d_loss:0.0000  g_loss:16.6517
# epoch:3629  d_loss:0.0000  g_loss:16.7312
# epoch:3630  d_loss:0.0000  g_loss:16.5877
# epoch:3631  d_loss:0.0000  g_loss:16.4976
# epoch:3632  d_loss:0.0000  g_loss:16.7238
# epoch:3633  d_loss:0.0000  g_loss:16.4258
# epoch:3634  d_loss:0.0000  g_loss:16.6211
# epoch:3635  d_loss:0.0000  g_loss:16.5554
# epoch:3636  d_loss:0.0000  g_loss:16.4291
# epoch:3637  d_loss:0.0000  g_loss:16.5427
# epoch:3638  d_loss:0.0000  g_loss:16.5885
# epoch:3639  d_loss:0.0000  g_loss:16.6886
# epoch:3640  d_loss:0.0000  g_loss:16.6659
# epoch:3641  d_loss:0.0000  g_loss:16.5338
# epoch:3642  d_loss:0.0000  g_loss:16.4871
# epoch:3643  d_loss:0.0000  g_loss:16.5981
# epoch:3644  d_loss:0.0000  g_loss:16.6714
# epoch:3645  d_loss:0.0000  g_loss:16.5813
# epoch:3646  d_loss:0.0000  g_loss:16.5587
# epoch:3647  d_loss:0.0000  g_loss:16.5332
# epoch:3648  d_loss:0.0000  g_loss:16.4962
# epoch:3649  d_loss:0.0000  g_loss:16.5132
# epoch:3650  d_loss:0.0000  g_loss:16.5565
# epoch:3651  d_loss:0.0000  g_loss:16.7032
# epoch:3652  d_loss:0.0000  g_loss:16.5197
# epoch:3653  d_loss:0.0000  g_loss:16.7203
# epoch:3654  d_loss:0.0000  g_loss:16.5265
# epoch:3655  d_loss:0.0000  g_loss:16.6866
# epoch:3656  d_loss:0.0000  g_loss:16.7150
# epoch:3657  d_loss:0.0000  g_loss:16.7621
# epoch:3658  d_loss:0.0000  g_loss:16.6796
# epoch:3659  d_loss:0.0000  g_loss:16.8658
# epoch:3660  d_loss:0.0000  g_loss:16.8256
# epoch:3661  d_loss:0.0000  g_loss:16.5205
# epoch:3662  d_loss:0.0000  g_loss:16.6965
# epoch:3663  d_loss:0.0000  g_loss:16.5033
# epoch:3664  d_loss:0.0000  g_loss:16.7253
# epoch:3665  d_loss:0.0000  g_loss:16.5451
# epoch:3666  d_loss:0.0000  g_loss:16.6015
# epoch:3667  d_loss:0.0000  g_loss:16.7219
# epoch:3668  d_loss:0.0000  g_loss:16.3310
# epoch:3669  d_loss:0.0000  g_loss:16.6273
# epoch:3670  d_loss:0.0000  g_loss:16.6934
# epoch:3671  d_loss:0.0000  g_loss:16.4058
# epoch:3672  d_loss:0.0000  g_loss:16.6183
# epoch:3673  d_loss:0.0000  g_loss:16.4586
# epoch:3674  d_loss:0.0000  g_loss:16.6114
# epoch:3675  d_loss:0.0000  g_loss:16.5189
# epoch:3676  d_loss:0.0000  g_loss:16.4586
# epoch:3677  d_loss:0.0000  g_loss:16.7486
# epoch:3678  d_loss:0.0000  g_loss:16.5188
# epoch:3679  d_loss:0.0000  g_loss:16.6880
# epoch:3680  d_loss:0.0000  g_loss:16.6833
# epoch:3681  d_loss:0.0000  g_loss:16.6892
# epoch:3682  d_loss:0.0000  g_loss:16.7193
# epoch:3683  d_loss:0.0000  g_loss:16.7434
# epoch:3684  d_loss:0.0000  g_loss:16.8987
# epoch:3685  d_loss:0.0000  g_loss:16.6785
# epoch:3686  d_loss:0.0000  g_loss:16.7394
# epoch:3687  d_loss:0.0000  g_loss:16.7888
# epoch:3688  d_loss:0.0000  g_loss:16.6091
# epoch:3689  d_loss:0.0000  g_loss:16.7105
# epoch:3690  d_loss:0.0000  g_loss:16.6273
# epoch:3691  d_loss:0.0000  g_loss:16.5157
# epoch:3692  d_loss:0.0000  g_loss:16.6175
# epoch:3693  d_loss:0.0000  g_loss:16.5463
# epoch:3694  d_loss:0.0000  g_loss:16.6133
# epoch:3695  d_loss:0.0000  g_loss:16.6147
# epoch:3696  d_loss:0.0000  g_loss:16.4871
# epoch:3697  d_loss:0.0000  g_loss:16.4594
# epoch:3698  d_loss:0.0000  g_loss:16.4749
# epoch:3699  d_loss:0.0000  g_loss:16.5665
# epoch:3700  d_loss:0.0000  g_loss:16.6843
# (25, 56, 56, 1)
# (173, 128)
# (128, 173)
# (22016,)
# end
# epoch:3701  d_loss:0.0000  g_loss:16.5305
# epoch:3702  d_loss:0.0000  g_loss:16.6259
# epoch:3703  d_loss:0.0000  g_loss:16.5385
# epoch:3704  d_loss:0.0000  g_loss:16.4947
# epoch:3705  d_loss:0.0000  g_loss:16.4424
# epoch:3706  d_loss:0.0000  g_loss:16.5973
# epoch:3707  d_loss:0.0000  g_loss:16.5300
# epoch:3708  d_loss:0.0000  g_loss:16.4184
# epoch:3709  d_loss:0.0000  g_loss:16.5987
# epoch:3710  d_loss:0.0000  g_loss:16.6693
# epoch:3711  d_loss:0.0000  g_loss:16.7521
# epoch:3712  d_loss:0.0000  g_loss:16.5824
# epoch:3713  d_loss:0.0000  g_loss:16.7715
# epoch:3714  d_loss:0.0000  g_loss:16.9439
# epoch:3715  d_loss:0.0000  g_loss:16.9076
# epoch:3716  d_loss:0.0000  g_loss:16.6305
# epoch:3717  d_loss:0.0000  g_loss:16.6543
# epoch:3718  d_loss:0.0000  g_loss:16.6171
# epoch:3719  d_loss:0.0000  g_loss:16.6252
# epoch:3720  d_loss:0.0000  g_loss:16.8158
# epoch:3721  d_loss:0.0000  g_loss:16.8595
# epoch:3722  d_loss:0.0000  g_loss:16.7763
# epoch:3723  d_loss:0.0000  g_loss:16.8319
# epoch:3724  d_loss:0.0000  g_loss:16.7182
# epoch:3725  d_loss:0.0000  g_loss:16.7133
# epoch:3726  d_loss:0.0000  g_loss:16.6914
# epoch:3727  d_loss:0.0000  g_loss:16.7155
# epoch:3728  d_loss:0.0000  g_loss:16.8517
# epoch:3729  d_loss:0.0000  g_loss:16.8446
# epoch:3730  d_loss:0.0000  g_loss:16.6807
# epoch:3731  d_loss:0.0000  g_loss:16.8594
# epoch:3732  d_loss:0.0000  g_loss:16.5356
# epoch:3733  d_loss:0.0000  g_loss:16.5995
# epoch:3734  d_loss:0.0000  g_loss:16.6163
# epoch:3735  d_loss:0.0000  g_loss:16.5175
# epoch:3736  d_loss:0.0000  g_loss:16.4711
# epoch:3737  d_loss:0.0000  g_loss:16.5898
# epoch:3738  d_loss:0.0000  g_loss:16.7845
# epoch:3739  d_loss:0.0000  g_loss:16.7744
# epoch:3740  d_loss:0.0000  g_loss:16.9047
# epoch:3741  d_loss:0.0000  g_loss:16.7202
# epoch:3742  d_loss:0.0000  g_loss:16.6976
# epoch:3743  d_loss:0.0000  g_loss:16.7999
# epoch:3744  d_loss:0.0000  g_loss:16.8721
# epoch:3745  d_loss:0.0000  g_loss:16.9470
# epoch:3746  d_loss:0.0000  g_loss:16.8609
# epoch:3747  d_loss:0.0000  g_loss:16.8739
# epoch:3748  d_loss:0.0000  g_loss:16.9689
# epoch:3749  d_loss:0.0000  g_loss:16.8689
# epoch:3750  d_loss:0.0000  g_loss:16.8482
# epoch:3751  d_loss:0.0000  g_loss:16.7837
# epoch:3752  d_loss:0.0000  g_loss:16.6118
# epoch:3753  d_loss:0.0000  g_loss:16.7058
# epoch:3754  d_loss:0.0000  g_loss:16.8246
# epoch:3755  d_loss:0.0000  g_loss:16.6326
# epoch:3756  d_loss:0.0000  g_loss:16.7853
# epoch:3757  d_loss:0.0000  g_loss:16.6752
# epoch:3758  d_loss:0.0000  g_loss:16.7336
# epoch:3759  d_loss:0.0000  g_loss:16.6275
# epoch:3760  d_loss:0.0000  g_loss:16.5302
# epoch:3761  d_loss:0.0000  g_loss:16.6337
# epoch:3762  d_loss:0.0000  g_loss:16.5674
# epoch:3763  d_loss:0.0000  g_loss:16.5002
# epoch:3764  d_loss:0.0000  g_loss:16.7525
# epoch:3765  d_loss:0.0000  g_loss:16.4826
# epoch:3766  d_loss:0.0000  g_loss:16.5890
# epoch:3767  d_loss:0.0000  g_loss:16.8018
# epoch:3768  d_loss:0.0000  g_loss:16.7947
# epoch:3769  d_loss:0.0000  g_loss:16.6405
# epoch:3770  d_loss:0.0000  g_loss:16.9132
# epoch:3771  d_loss:0.0000  g_loss:16.7622
# epoch:3772  d_loss:0.0000  g_loss:16.6802
# epoch:3773  d_loss:0.0000  g_loss:16.8466
# epoch:3774  d_loss:0.0000  g_loss:16.6383
# epoch:3775  d_loss:0.0000  g_loss:16.8001
# epoch:3776  d_loss:0.0000  g_loss:16.8061
# epoch:3777  d_loss:0.0000  g_loss:16.7210
# epoch:3778  d_loss:0.0000  g_loss:16.6008
# epoch:3779  d_loss:0.0000  g_loss:16.6645
# epoch:3780  d_loss:0.0000  g_loss:16.8992
# epoch:3781  d_loss:0.0000  g_loss:16.6861
# epoch:3782  d_loss:0.0000  g_loss:16.7473
# epoch:3783  d_loss:0.0000  g_loss:16.8017
# epoch:3784  d_loss:0.0000  g_loss:16.7638
# epoch:3785  d_loss:0.0000  g_loss:16.8374
# epoch:3786  d_loss:0.0000  g_loss:16.8440
# epoch:3787  d_loss:0.0000  g_loss:16.7199
# epoch:3788  d_loss:0.0000  g_loss:16.7769
# epoch:3789  d_loss:0.0000  g_loss:16.8255
# epoch:3790  d_loss:0.0000  g_loss:16.6818
# epoch:3791  d_loss:0.0000  g_loss:16.8396
# epoch:3792  d_loss:0.0000  g_loss:16.7168
# epoch:3793  d_loss:0.0000  g_loss:16.8362
# epoch:3794  d_loss:0.0000  g_loss:16.7291
# epoch:3795  d_loss:0.0000  g_loss:16.6365
# epoch:3796  d_loss:0.0000  g_loss:16.9139
# epoch:3797  d_loss:0.0000  g_loss:16.8257
# epoch:3798  d_loss:0.0000  g_loss:16.8799
# epoch:3799  d_loss:0.0000  g_loss:16.8762
# epoch:3800  d_loss:0.0000  g_loss:16.9742
# (25, 56, 56, 1)
# (173, 128)
# (128, 173)
# (22016,)
# end
# epoch:3801  d_loss:0.0000  g_loss:16.9570
# epoch:3802  d_loss:0.0000  g_loss:16.8252
# epoch:3803  d_loss:0.0000  g_loss:16.8652
# epoch:3804  d_loss:0.0000  g_loss:16.7174
# epoch:3805  d_loss:0.0000  g_loss:16.8309
# epoch:3806  d_loss:0.0000  g_loss:16.7208
# epoch:3807  d_loss:0.0000  g_loss:16.8075
# epoch:3808  d_loss:0.0000  g_loss:16.8353
# epoch:3809  d_loss:0.0000  g_loss:16.8158
# epoch:3810  d_loss:0.0000  g_loss:16.8030
# epoch:3811  d_loss:0.0000  g_loss:16.7908
# epoch:3812  d_loss:0.0000  g_loss:16.7632
# epoch:3813  d_loss:0.0000  g_loss:16.8279
# epoch:3814  d_loss:0.0000  g_loss:16.8396
# epoch:3815  d_loss:0.0000  g_loss:16.8597
# epoch:3816  d_loss:0.0000  g_loss:16.5990
# epoch:3817  d_loss:0.0000  g_loss:16.8593
# epoch:3818  d_loss:0.0000  g_loss:16.7636
# epoch:3819  d_loss:0.0000  g_loss:16.4279
# epoch:3820  d_loss:0.0000  g_loss:16.7471
# epoch:3821  d_loss:0.0000  g_loss:16.9396
# epoch:3822  d_loss:0.0000  g_loss:16.7021
# epoch:3823  d_loss:0.0000  g_loss:16.8447
# epoch:3824  d_loss:0.0000  g_loss:16.8313
# epoch:3825  d_loss:0.0000  g_loss:16.8600
# epoch:3826  d_loss:0.0000  g_loss:16.7296
# epoch:3827  d_loss:0.0000  g_loss:16.7796
# epoch:3828  d_loss:0.0000  g_loss:16.7870
# epoch:3829  d_loss:0.0000  g_loss:16.7550
# epoch:3830  d_loss:0.0000  g_loss:16.8815
# epoch:3831  d_loss:0.0000  g_loss:16.7104
# epoch:3832  d_loss:0.0000  g_loss:16.9546
# epoch:3833  d_loss:0.0000  g_loss:16.7685
# epoch:3834  d_loss:0.0000  g_loss:16.6692
# epoch:3835  d_loss:0.0000  g_loss:16.9235
# epoch:3836  d_loss:0.0000  g_loss:16.7160
# epoch:3837  d_loss:0.0000  g_loss:16.9124
# epoch:3838  d_loss:0.0000  g_loss:16.6963
# epoch:3839  d_loss:0.0000  g_loss:16.7334
# epoch:3840  d_loss:0.0000  g_loss:16.8246
# epoch:3841  d_loss:0.0000  g_loss:16.8469
# epoch:3842  d_loss:0.0000  g_loss:16.8188
# epoch:3843  d_loss:0.0000  g_loss:16.8945
# epoch:3844  d_loss:0.0000  g_loss:16.8251
# epoch:3845  d_loss:0.0000  g_loss:16.8343
# epoch:3846  d_loss:0.0000  g_loss:16.6523
# epoch:3847  d_loss:0.0000  g_loss:16.4269
# epoch:3848  d_loss:0.0000  g_loss:16.4104
# epoch:3849  d_loss:0.0000  g_loss:16.6025
# epoch:3850  d_loss:0.0000  g_loss:16.8036
# epoch:3851  d_loss:0.0000  g_loss:16.5982
# epoch:3852  d_loss:0.0000  g_loss:16.7190
# epoch:3853  d_loss:0.0000  g_loss:16.9330
# epoch:3854  d_loss:0.0000  g_loss:16.8677
# epoch:3855  d_loss:0.0000  g_loss:16.9101
# epoch:3856  d_loss:0.0000  g_loss:16.9667
# epoch:3857  d_loss:0.0000  g_loss:16.9222
# epoch:3858  d_loss:0.0000  g_loss:16.9795
# epoch:3859  d_loss:0.0000  g_loss:17.0166
# epoch:3860  d_loss:0.0000  g_loss:16.8918
# epoch:3861  d_loss:0.0000  g_loss:16.9898
# epoch:3862  d_loss:0.0000  g_loss:16.9342
# epoch:3863  d_loss:0.0000  g_loss:16.9713
# epoch:3864  d_loss:0.0000  g_loss:16.9114
# epoch:3865  d_loss:0.0000  g_loss:16.6233
# epoch:3866  d_loss:0.0000  g_loss:16.9020
# epoch:3867  d_loss:0.0000  g_loss:16.8805
# epoch:3868  d_loss:0.0000  g_loss:16.7366
# epoch:3869  d_loss:0.0000  g_loss:16.6067
# epoch:3870  d_loss:0.0000  g_loss:16.6763
# epoch:3871  d_loss:0.0000  g_loss:16.6156
# epoch:3872  d_loss:0.0000  g_loss:16.9147
# epoch:3873  d_loss:0.0000  g_loss:16.6783
# epoch:3874  d_loss:0.0000  g_loss:17.0452
# epoch:3875  d_loss:0.0000  g_loss:16.9494
# epoch:3876  d_loss:0.0000  g_loss:16.8895
# epoch:3877  d_loss:0.0000  g_loss:16.9401
# epoch:3878  d_loss:0.0000  g_loss:17.0605
# epoch:3879  d_loss:0.0000  g_loss:16.9326
# epoch:3880  d_loss:0.0000  g_loss:16.7979
# epoch:3881  d_loss:0.0000  g_loss:16.7611
# epoch:3882  d_loss:0.0000  g_loss:16.9069
# epoch:3883  d_loss:0.0000  g_loss:17.0113
# epoch:3884  d_loss:0.0000  g_loss:16.9026
# epoch:3885  d_loss:0.0000  g_loss:16.9226
# epoch:3886  d_loss:0.0000  g_loss:16.6370
# epoch:3887  d_loss:0.0000  g_loss:16.5897
# epoch:3888  d_loss:0.0000  g_loss:16.8555
# epoch:3889  d_loss:0.0000  g_loss:16.8625
# epoch:3890  d_loss:0.0000  g_loss:16.9695
# epoch:3891  d_loss:0.0000  g_loss:16.9913
# epoch:3892  d_loss:0.0000  g_loss:16.7171
# epoch:3893  d_loss:0.0000  g_loss:16.9630
# epoch:3894  d_loss:0.0000  g_loss:16.9785
# epoch:3895  d_loss:0.0000  g_loss:16.9071
# epoch:3896  d_loss:0.0000  g_loss:17.0255
# epoch:3897  d_loss:0.0000  g_loss:16.8446
# epoch:3898  d_loss:0.0000  g_loss:16.9963
# epoch:3899  d_loss:0.0000  g_loss:16.8861
# epoch:3900  d_loss:0.0000  g_loss:16.9340
# (25, 56, 56, 1)
# (173, 128)
# (128, 173)
# (22016,)
# end
# epoch:3901  d_loss:0.0000  g_loss:16.9963
# epoch:3902  d_loss:0.0000  g_loss:16.7923
# epoch:3903  d_loss:0.0000  g_loss:16.8269
# epoch:3904  d_loss:0.0000  g_loss:16.9012
# epoch:3905  d_loss:0.0000  g_loss:16.8796
# epoch:3906  d_loss:0.0000  g_loss:16.9162
# epoch:3907  d_loss:0.0000  g_loss:16.8913
# epoch:3908  d_loss:0.0000  g_loss:16.7551
# epoch:3909  d_loss:0.0000  g_loss:16.7119
# epoch:3910  d_loss:0.0000  g_loss:16.7886
# epoch:3911  d_loss:0.0000  g_loss:16.6677
# epoch:3912  d_loss:0.0000  g_loss:16.8799
# epoch:3913  d_loss:0.0000  g_loss:17.0692
# epoch:3914  d_loss:0.0000  g_loss:16.9359
# epoch:3915  d_loss:0.0000  g_loss:16.7844
# epoch:3916  d_loss:0.0000  g_loss:17.1542
# epoch:3917  d_loss:0.0000  g_loss:16.8653
# epoch:3918  d_loss:0.0000  g_loss:17.0967
# epoch:3919  d_loss:0.0000  g_loss:17.1737
# epoch:3920  d_loss:0.0000  g_loss:17.1705
# epoch:3921  d_loss:0.0000  g_loss:16.8176
# epoch:3922  d_loss:0.0000  g_loss:17.0490
# epoch:3923  d_loss:0.0000  g_loss:16.7476
# epoch:3924  d_loss:0.0000  g_loss:16.7320
# epoch:3925  d_loss:0.0000  g_loss:16.8648
# epoch:3926  d_loss:0.0000  g_loss:16.9638
# epoch:3927  d_loss:0.0000  g_loss:16.6741
# epoch:3928  d_loss:0.0000  g_loss:16.7287
# epoch:3929  d_loss:0.0000  g_loss:16.8583
# epoch:3930  d_loss:0.0000  g_loss:16.7540
# epoch:3931  d_loss:0.0000  g_loss:16.7679
# epoch:3932  d_loss:0.0000  g_loss:16.7077
# epoch:3933  d_loss:0.0000  g_loss:16.8459
# epoch:3934  d_loss:0.0000  g_loss:17.0059
# epoch:3935  d_loss:0.0000  g_loss:16.9926
# epoch:3936  d_loss:0.0000  g_loss:16.8640
# epoch:3937  d_loss:0.0000  g_loss:17.1152
# epoch:3938  d_loss:0.0000  g_loss:16.9762
# epoch:3939  d_loss:0.0000  g_loss:16.9989
# epoch:3940  d_loss:0.0000  g_loss:16.8596
# epoch:3941  d_loss:0.0000  g_loss:16.9269
# epoch:3942  d_loss:0.0000  g_loss:16.7032
# epoch:3943  d_loss:0.0000  g_loss:16.8068
# epoch:3944  d_loss:0.0000  g_loss:16.6989
# epoch:3945  d_loss:0.0000  g_loss:16.8946
# epoch:3946  d_loss:0.0000  g_loss:16.9335
# epoch:3947  d_loss:0.0000  g_loss:16.8390
# epoch:3948  d_loss:0.0000  g_loss:16.8319
# epoch:3949  d_loss:0.0000  g_loss:16.7104
# epoch:3950  d_loss:0.0000  g_loss:17.1920
# epoch:3951  d_loss:0.0000  g_loss:16.9354
# epoch:3952  d_loss:0.0000  g_loss:17.2780
# epoch:3953  d_loss:0.0000  g_loss:16.9614
# epoch:3954  d_loss:0.0000  g_loss:16.8880
# epoch:3955  d_loss:0.0000  g_loss:17.0274
# epoch:3956  d_loss:0.0000  g_loss:17.0952
# epoch:3957  d_loss:0.0000  g_loss:16.9176
# epoch:3958  d_loss:0.0000  g_loss:16.8589
# epoch:3959  d_loss:0.0000  g_loss:16.5410
# epoch:3960  d_loss:0.0000  g_loss:16.9373
# epoch:3961  d_loss:0.0000  g_loss:16.8585
# epoch:3962  d_loss:0.0000  g_loss:16.8913
# epoch:3963  d_loss:0.0000  g_loss:16.9268
# epoch:3964  d_loss:0.0000  g_loss:17.0219
# epoch:3965  d_loss:0.0000  g_loss:17.0173
# epoch:3966  d_loss:0.0000  g_loss:17.0289
# epoch:3967  d_loss:0.0000  g_loss:17.0913
# epoch:3968  d_loss:0.0000  g_loss:17.0084
# epoch:3969  d_loss:0.0000  g_loss:17.1410
# epoch:3970  d_loss:0.0000  g_loss:17.1682
# epoch:3971  d_loss:0.0000  g_loss:17.1569
# epoch:3972  d_loss:0.0000  g_loss:17.3233
# epoch:3973  d_loss:0.0000  g_loss:17.1085
# epoch:3974  d_loss:0.0000  g_loss:17.1825
# epoch:3975  d_loss:0.0000  g_loss:17.0198
# epoch:3976  d_loss:0.0000  g_loss:16.8375
# epoch:3977  d_loss:0.0000  g_loss:16.9184
# epoch:3978  d_loss:0.0000  g_loss:17.1328
# epoch:3979  d_loss:0.0000  g_loss:16.8697
# epoch:3980  d_loss:0.0000  g_loss:16.9058
# epoch:3981  d_loss:0.0000  g_loss:17.1845
# epoch:3982  d_loss:0.0000  g_loss:16.9925
# epoch:3983  d_loss:0.0000  g_loss:17.2061
# epoch:3984  d_loss:0.0000  g_loss:17.1982
# epoch:3985  d_loss:0.0000  g_loss:17.0820
# epoch:3986  d_loss:0.0000  g_loss:16.9839
# epoch:3987  d_loss:0.0000  g_loss:16.9618
# epoch:3988  d_loss:0.0000  g_loss:17.0058
# epoch:3989  d_loss:0.0000  g_loss:17.2128
# epoch:3990  d_loss:0.0000  g_loss:17.3001
# epoch:3991  d_loss:0.0000  g_loss:17.1280
# epoch:3992  d_loss:0.0000  g_loss:17.1743
# epoch:3993  d_loss:0.0000  g_loss:17.0921
# epoch:3994  d_loss:0.0000  g_loss:17.2412
# epoch:3995  d_loss:0.0000  g_loss:17.2395
# epoch:3996  d_loss:0.0000  g_loss:16.9504
# epoch:3997  d_loss:0.0000  g_loss:17.1055
# epoch:3998  d_loss:0.0000  g_loss:16.8642
# epoch:3999  d_loss:0.0000  g_loss:16.9703
# epoch:4000  d_loss:0.0000  g_loss:16.8565
# (25, 56, 56, 1)
# (173, 128)
# (128, 173)
# (22016,)
# end

# %%
"""

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, 100))
              # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
              # print(gen_imgs.shape)   # (25, 28, 28, 1)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
              # Rescale images 0 - 1

            fig, axs = plt.subplots(5, 5)
            count = 0
            for j in range(5):
                  for k in range(5):
                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap='gray')
                      axs[j, k].axis('off') # axis를 제거한다.
                      count += 1
            # fig.savefig("E:\\nmb\\gan_image/gan_mnist_%d.png" % i)
  """
# Out:
# '\n\n        if i % saving_interval == 0:\n            # saving_interval 마다 이미지를 출력한다.\n            noise = np.random.normal(0, 1, (25, 100))\n              # print(noise.shape)  # (25, 100)\n            gen_imgs = generator.predict(noise)\n              # print(gen_imgs.shape)   # (25, 28, 28, 1)\n            \n            gen_imgs = 0.5 * gen_imgs + 0.5\n              # Rescale images 0 - 1\n\n            fig, axs = plt.subplots(5, 5)\n            count = 0\n            for j in range(5):\n                  for k in range(5):\n                      axs[j, k].imshow(gen_imgs[count, :, :, 0], cmap=\'gray\')\n                      axs[j, k].axis(\'off\') # axis를 제거한다.\n                      count += 1\n            # fig.savefig("E:\\nmb\\gan_image/gan_mnist_%d.png" % i)\n  '
