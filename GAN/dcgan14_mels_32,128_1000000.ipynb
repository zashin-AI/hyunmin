# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 32
y_size = 128
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 100001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32768)             3309568
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32768)             131072
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 32, 128)        0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 64, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 64, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 16, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 128, 64)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 128, 1)        1601
# =================================================================
# Total params: 3,647,361
# Trainable params: 3,581,697
# Non-trainable params: 65,664
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 16, 64, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 64, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 32, 128)        204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 32, 128)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 32, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 239,361
# Trainable params: 0
# Non-trainable params: 239,361
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 32, 128, 1)        3647361
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 239361
# =================================================================
# Total params: 3,886,722
# Trainable params: 3,581,697
# Non-trainable params: 305,025
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (2331, 128, 32)
# Out:
# 28, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (2331, 128, 32)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 128, 32)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.00016182661 -80.0

  scale = MaxAbsScaler()
    #   절대값이 0~1사이에 매핑
    #   -1 ~ 1 사이로 재조정
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4096)
  print(np.max(X_train), np.min(X_train))   # -2.0228326e-06 -1.0


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 32, 128, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan14.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            # idx2 = np.random.randint(0, gen_imgs.shape[0])
            idx2 = 5    # 출력 값 고정
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 32, 128, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (862,128))
            # gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            # print(gen_mels.shape) # (862, 128)
            # gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan14\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
            

gan_train(epochs, batch, 500)


end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# 42
# epoch:197  d_loss:0.2719  g_loss:0.4868
# epoch:198  d_loss:0.2565  g_loss:0.6767
# epoch:199  d_loss:0.2884  g_loss:0.3559
# epoch:200  d_loss:0.2169  g_loss:0.2531
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:201  d_loss:0.1777  g_loss:0.2614
# epoch:202  d_loss:0.1770  g_loss:0.5431
# epoch:203  d_loss:0.2010  g_loss:0.4655
# epoch:204  d_loss:0.2016  g_loss:0.2309
# epoch:205  d_loss:0.1602  g_loss:0.1893
# epoch:206  d_loss:0.1232  g_loss:0.2890
# epoch:207  d_loss:0.1145  g_loss:0.5306
# epoch:208  d_loss:0.1131  g_loss:0.5503
# epoch:209  d_loss:0.1819  g_loss:0.1883
# epoch:210  d_loss:0.1695  g_loss:0.1641
# epoch:211  d_loss:0.0973  g_loss:0.4575
# epoch:212  d_loss:0.0986  g_loss:0.7089
# epoch:213  d_loss:0.1390  g_loss:0.3740
# epoch:214  d_loss:0.1037  g_loss:0.1812
# epoch:215  d_loss:0.0828  g_loss:0.3268
# epoch:216  d_loss:0.0543  g_loss:0.5236
# epoch:217  d_loss:0.0742  g_loss:0.4420
# epoch:218  d_loss:0.0512  g_loss:0.3529
# epoch:219  d_loss:0.0874  g_loss:0.3312
# epoch:220  d_loss:0.0593  g_loss:0.3639
# epoch:221  d_loss:0.0599  g_loss:0.5505
# epoch:222  d_loss:0.0714  g_loss:0.3999
# epoch:223  d_loss:0.0581  g_loss:0.3534
# epoch:224  d_loss:0.0679  g_loss:0.3159
# epoch:225  d_loss:0.0779  g_loss:0.6464
# epoch:226  d_loss:0.0629  g_loss:0.8902
# epoch:227  d_loss:0.0445  g_loss:0.8778
# epoch:228  d_loss:0.0390  g_loss:0.5445
# epoch:229  d_loss:0.0871  g_loss:0.6248
# epoch:230  d_loss:0.1171  g_loss:0.9987
# epoch:231  d_loss:0.1644  g_loss:1.5200
# epoch:232  d_loss:0.5042  g_loss:0.6754
# epoch:233  d_loss:6.9649  g_loss:0.4122
# epoch:234  d_loss:5.7987  g_loss:0.7092
# epoch:235  d_loss:1.4113  g_loss:6.3176
# epoch:236  d_loss:0.2090  g_loss:8.4029
# epoch:237  d_loss:0.3516  g_loss:9.2572
# epoch:238  d_loss:0.7918  g_loss:17.4730
# epoch:239  d_loss:3.9769  g_loss:0.9351
# epoch:240  d_loss:3.0713  g_loss:2.3540
# epoch:241  d_loss:0.0672  g_loss:10.2582
# epoch:242  d_loss:3.0632  g_loss:1.6147
# epoch:243  d_loss:1.8489  g_loss:0.4347
# epoch:244  d_loss:0.8714  g_loss:2.3641
# epoch:245  d_loss:0.7626  g_loss:3.5253
# epoch:246  d_loss:1.1173  g_loss:0.8586
# epoch:247  d_loss:0.8599  g_loss:0.4830
# epoch:248  d_loss:0.5414  g_loss:1.2837
# epoch:249  d_loss:0.2794  g_loss:3.0794
# epoch:250  d_loss:0.6529  g_loss:1.8596
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:251  d_loss:0.4727  g_loss:0.9914
# epoch:252  d_loss:0.3198  g_loss:1.5658
# epoch:253  d_loss:0.2491  g_loss:2.1570
# epoch:254  d_loss:0.3550  g_loss:1.9829
# epoch:255  d_loss:0.3695  g_loss:1.7542
# epoch:256  d_loss:0.2925  g_loss:1.6149
# epoch:257  d_loss:0.1715  g_loss:2.2426
# epoch:258  d_loss:0.1574  g_loss:2.4798
# epoch:259  d_loss:0.2124  g_loss:2.0826
# epoch:260  d_loss:0.1694  g_loss:2.2447
# epoch:261  d_loss:0.1530  g_loss:2.3102
# epoch:262  d_loss:0.1181  g_loss:2.8898
# epoch:263  d_loss:0.1100  g_loss:2.7105
# epoch:264  d_loss:0.1304  g_loss:2.5956
# epoch:265  d_loss:0.0853  g_loss:2.5833
# epoch:266  d_loss:0.1157  g_loss:2.7960
# epoch:267  d_loss:0.0752  g_loss:2.9110
# epoch:268  d_loss:0.1095  g_loss:3.1811
# epoch:269  d_loss:0.0839  g_loss:2.6426
# epoch:270  d_loss:0.1108  g_loss:2.9482
# epoch:271  d_loss:0.0813  g_loss:2.7533
# epoch:272  d_loss:0.0525  g_loss:3.6221
# epoch:273  d_loss:0.0720  g_loss:3.7754
# epoch:274  d_loss:0.1699  g_loss:2.9016
# epoch:275  d_loss:0.0616  g_loss:2.4294
# epoch:276  d_loss:0.0736  g_loss:3.0146
# epoch:277  d_loss:0.1141  g_loss:3.9800
# epoch:278  d_loss:0.0855  g_loss:3.9828
# epoch:279  d_loss:0.0357  g_loss:3.6684
# epoch:280  d_loss:0.0813  g_loss:3.4762
# epoch:281  d_loss:0.0576  g_loss:3.4785
# epoch:282  d_loss:0.0607  g_loss:3.6853
# epoch:283  d_loss:0.0451  g_loss:3.6404
# epoch:284  d_loss:0.1017  g_loss:3.4078
# epoch:285  d_loss:0.0752  g_loss:3.4209
# epoch:286  d_loss:0.0804  g_loss:3.5481
# epoch:287  d_loss:0.0844  g_loss:4.0536
# epoch:288  d_loss:0.1056  g_loss:3.6628
# epoch:289  d_loss:0.0783  g_loss:3.5802
# epoch:290  d_loss:0.0542  g_loss:3.4183
# epoch:291  d_loss:0.0928  g_loss:4.4332
# epoch:292  d_loss:0.1102  g_loss:4.2132
# epoch:293  d_loss:0.0578  g_loss:5.0140
# epoch:294  d_loss:0.2768  g_loss:4.1791
# epoch:295  d_loss:0.5509  g_loss:2.7069
# epoch:296  d_loss:0.1314  g_loss:3.7058
# epoch:297  d_loss:0.0416  g_loss:4.8646
# epoch:298  d_loss:0.3513  g_loss:3.8247
# epoch:299  d_loss:0.2190  g_loss:3.2375
# epoch:300  d_loss:0.3537  g_loss:2.8996
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:301  d_loss:0.4328  g_loss:2.6901
# epoch:302  d_loss:0.1005  g_loss:4.0478
# epoch:303  d_loss:0.2371  g_loss:4.4631
# epoch:304  d_loss:0.1546  g_loss:2.8355
# epoch:305  d_loss:0.1320  g_loss:2.1387
# epoch:306  d_loss:0.1267  g_loss:2.5680
# epoch:307  d_loss:0.0699  g_loss:3.4380
# epoch:308  d_loss:0.0609  g_loss:4.3035
# epoch:309  d_loss:0.0543  g_loss:4.8738
# epoch:310  d_loss:0.0785  g_loss:4.0617
# epoch:311  d_loss:0.0833  g_loss:3.7838
# epoch:312  d_loss:0.0855  g_loss:2.9225
# epoch:313  d_loss:0.0976  g_loss:2.8108
# epoch:314  d_loss:0.0518  g_loss:3.5655
# epoch:315  d_loss:0.0522  g_loss:4.4659
# epoch:316  d_loss:0.0902  g_loss:4.0444
# epoch:317  d_loss:0.1270  g_loss:2.4567
# epoch:318  d_loss:0.1021  g_loss:2.1966
# epoch:319  d_loss:0.1782  g_loss:3.0955
# epoch:320  d_loss:0.0299  g_loss:4.6931
# epoch:321  d_loss:0.1988  g_loss:4.7294
# epoch:322  d_loss:0.0473  g_loss:4.3151
# epoch:323  d_loss:0.0761  g_loss:3.3098
# epoch:324  d_loss:0.1419  g_loss:2.8650
# epoch:325  d_loss:0.0397  g_loss:3.3736
# epoch:326  d_loss:0.1158  g_loss:3.5218
# epoch:327  d_loss:0.0490  g_loss:4.1410
# epoch:328  d_loss:0.0525  g_loss:4.0363
# epoch:329  d_loss:0.0542  g_loss:3.9537
# epoch:330  d_loss:0.0498  g_loss:4.2069
# epoch:331  d_loss:0.0398  g_loss:4.4070
# epoch:332  d_loss:0.0332  g_loss:4.8010
# epoch:333  d_loss:0.0519  g_loss:3.9828
# epoch:334  d_loss:0.0665  g_loss:3.8307
# epoch:335  d_loss:0.0653  g_loss:2.7541
# epoch:336  d_loss:0.0709  g_loss:2.8262
# epoch:337  d_loss:0.0822  g_loss:3.6197
# epoch:338  d_loss:0.1030  g_loss:3.9522
# epoch:339  d_loss:0.0506  g_loss:4.0760
# epoch:340  d_loss:0.0153  g_loss:4.1509
# epoch:341  d_loss:0.0226  g_loss:4.4475
# epoch:342  d_loss:0.0556  g_loss:3.6792
# epoch:343  d_loss:0.0304  g_loss:3.7978
# epoch:344  d_loss:0.0281  g_loss:3.7728
# epoch:345  d_loss:0.0140  g_loss:4.0825
# epoch:346  d_loss:0.0413  g_loss:4.3363
# epoch:347  d_loss:0.0098  g_loss:4.6179
# epoch:348  d_loss:0.0228  g_loss:4.5807
# epoch:349  d_loss:0.0169  g_loss:4.2663
# epoch:350  d_loss:0.0381  g_loss:3.7491
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:351  d_loss:0.0816  g_loss:3.2326
# epoch:352  d_loss:0.0479  g_loss:3.2863
# epoch:353  d_loss:0.0251  g_loss:4.2364
# epoch:354  d_loss:0.0181  g_loss:5.0592
# epoch:355  d_loss:0.0124  g_loss:5.3762
# epoch:356  d_loss:0.0969  g_loss:5.0542
# epoch:357  d_loss:0.1172  g_loss:3.4267
# epoch:358  d_loss:0.0543  g_loss:2.7101
# epoch:359  d_loss:0.0508  g_loss:3.1294
# epoch:360  d_loss:0.0240  g_loss:4.1793
# epoch:361  d_loss:0.0207  g_loss:5.4596
# epoch:362  d_loss:0.0777  g_loss:5.5355
# epoch:363  d_loss:0.0051  g_loss:5.2324
# epoch:364  d_loss:0.0641  g_loss:4.5415
# epoch:365  d_loss:0.0162  g_loss:4.3861
# epoch:366  d_loss:0.1759  g_loss:3.3381
# epoch:367  d_loss:0.0394  g_loss:3.3862
# epoch:368  d_loss:0.0261  g_loss:3.9145
# epoch:369  d_loss:0.0110  g_loss:5.2261
# epoch:370  d_loss:0.0160  g_loss:5.8954
# epoch:371  d_loss:0.0570  g_loss:4.8662
# epoch:372  d_loss:0.0391  g_loss:4.5324
# epoch:373  d_loss:0.0350  g_loss:3.4330
# epoch:374  d_loss:0.0263  g_loss:3.5589
# epoch:375  d_loss:0.0287  g_loss:4.5477
# epoch:376  d_loss:0.0156  g_loss:4.8896
# epoch:377  d_loss:0.0062  g_loss:6.0004
# epoch:378  d_loss:0.0041  g_loss:5.6850
# epoch:379  d_loss:0.0267  g_loss:6.1744
# epoch:380  d_loss:0.0242  g_loss:6.0348
# epoch:381  d_loss:0.0259  g_loss:4.8536
# epoch:382  d_loss:0.0164  g_loss:4.4977
# epoch:383  d_loss:0.0318  g_loss:4.1265
# epoch:384  d_loss:0.0324  g_loss:3.6773
# epoch:385  d_loss:0.0243  g_loss:4.5404
# epoch:386  d_loss:0.0210  g_loss:5.0534
# epoch:387  d_loss:0.0912  g_loss:4.8065
# epoch:388  d_loss:0.0210  g_loss:4.4871
# epoch:389  d_loss:0.0508  g_loss:3.6138
# epoch:390  d_loss:0.0253  g_loss:3.8349
# epoch:391  d_loss:0.0291  g_loss:4.2154
# epoch:392  d_loss:0.0815  g_loss:4.5376
# epoch:393  d_loss:0.0505  g_loss:4.3676
# epoch:394  d_loss:0.0455  g_loss:4.7404
# epoch:395  d_loss:0.0451  g_loss:5.0405
# epoch:396  d_loss:0.0482  g_loss:4.8820
# epoch:397  d_loss:0.0199  g_loss:4.8719
# epoch:398  d_loss:0.0299  g_loss:4.7023
# epoch:399  d_loss:0.0377  g_loss:4.3038
# epoch:400  d_loss:0.0602  g_loss:4.4813
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:401  d_loss:0.0143  g_loss:6.0169
# epoch:402  d_loss:0.1998  g_loss:4.5192
# epoch:403  d_loss:0.0819  g_loss:3.7213
# epoch:404  d_loss:0.0893  g_loss:3.8654
# epoch:405  d_loss:0.0754  g_loss:4.3052
# epoch:406  d_loss:0.0181  g_loss:4.9869
# epoch:407  d_loss:0.0240  g_loss:6.0985
# epoch:408  d_loss:0.0479  g_loss:4.9541
# epoch:409  d_loss:0.1367  g_loss:3.4617
# epoch:410  d_loss:0.1231  g_loss:3.5917
# epoch:411  d_loss:0.0369  g_loss:5.1077
# epoch:412  d_loss:0.0066  g_loss:6.7388
# epoch:413  d_loss:0.0106  g_loss:7.3320
# epoch:414  d_loss:0.1029  g_loss:6.5174
# epoch:415  d_loss:0.0361  g_loss:5.4816
# epoch:416  d_loss:0.0162  g_loss:3.9358
# epoch:417  d_loss:0.0608  g_loss:3.1834
# epoch:418  d_loss:0.0640  g_loss:2.8483
# epoch:419  d_loss:0.0470  g_loss:3.8408
# epoch:420  d_loss:0.0117  g_loss:5.4115
# epoch:421  d_loss:0.0022  g_loss:6.8233
# epoch:422  d_loss:0.1133  g_loss:6.3751
# epoch:423  d_loss:0.0090  g_loss:6.3959
# epoch:424  d_loss:0.0617  g_loss:4.3914
# epoch:425  d_loss:0.0803  g_loss:2.8269
# epoch:426  d_loss:0.0594  g_loss:3.0052
# epoch:427  d_loss:0.0296  g_loss:3.8792
# epoch:428  d_loss:0.0239  g_loss:4.0127
# epoch:429  d_loss:0.0170  g_loss:5.5806
# epoch:430  d_loss:0.0811  g_loss:3.9958
# epoch:431  d_loss:0.0466  g_loss:3.4652
# epoch:432  d_loss:0.0959  g_loss:3.4712
# epoch:433  d_loss:0.0476  g_loss:4.2260
# epoch:434  d_loss:0.0499  g_loss:4.3080
# epoch:435  d_loss:0.0525  g_loss:3.1216
# epoch:436  d_loss:0.0415  g_loss:3.3551
# epoch:437  d_loss:0.0789  g_loss:4.3768
# epoch:438  d_loss:0.1249  g_loss:4.2144
# epoch:439  d_loss:0.0485  g_loss:4.1812
# epoch:440  d_loss:0.0214  g_loss:4.9547
# epoch:441  d_loss:0.1640  g_loss:4.1771
# epoch:442  d_loss:0.1493  g_loss:2.6832
# epoch:443  d_loss:0.0937  g_loss:4.4021
# epoch:444  d_loss:0.0625  g_loss:5.3743
# epoch:445  d_loss:0.0499  g_loss:4.4498
# epoch:446  d_loss:0.0487  g_loss:3.4674
# epoch:447  d_loss:0.0668  g_loss:3.6079
# epoch:448  d_loss:0.0214  g_loss:4.3988
# epoch:449  d_loss:0.0753  g_loss:5.3767
# epoch:450  d_loss:0.0273  g_loss:5.1335
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:451  d_loss:0.0517  g_loss:4.3808
# epoch:452  d_loss:0.0992  g_loss:3.2638
# epoch:453  d_loss:0.0487  g_loss:3.5177
# epoch:454  d_loss:0.0781  g_loss:3.4783
# epoch:455  d_loss:0.0467  g_loss:4.0658
# epoch:456  d_loss:0.0324  g_loss:4.4169
# epoch:457  d_loss:0.0355  g_loss:4.8499
# epoch:458  d_loss:0.0681  g_loss:2.7974
# epoch:459  d_loss:0.1200  g_loss:3.2496
# epoch:460  d_loss:0.0674  g_loss:4.0516
# epoch:461  d_loss:0.1266  g_loss:2.8178
# epoch:462  d_loss:0.2222  g_loss:4.7144
# epoch:463  d_loss:0.2605  g_loss:1.8656
# epoch:464  d_loss:0.0442  g_loss:3.7947
# epoch:465  d_loss:0.1636  g_loss:2.4193
# epoch:466  d_loss:0.2301  g_loss:2.3854
# epoch:467  d_loss:0.2842  g_loss:2.8040
# epoch:468  d_loss:0.2087  g_loss:5.0865
# epoch:469  d_loss:0.4231  g_loss:5.1051
# epoch:470  d_loss:0.1852  g_loss:3.0844
# epoch:471  d_loss:0.1557  g_loss:9.3411
# epoch:472  d_loss:4.9356  g_loss:2.8659
# epoch:473  d_loss:0.0711  g_loss:17.1716
# epoch:474  d_loss:5.2108  g_loss:0.0073
# epoch:475  d_loss:6.8365  g_loss:0.0012
# epoch:476  d_loss:0.4591  g_loss:12.1434
# epoch:477  d_loss:1.7810  g_loss:13.2852
# epoch:478  d_loss:2.2322  g_loss:0.0489
# epoch:479  d_loss:4.3829  g_loss:0.0198
# epoch:480  d_loss:1.3770  g_loss:6.5300
# epoch:481  d_loss:0.1828  g_loss:17.2347
# epoch:482  d_loss:2.7706  g_loss:13.4708
# epoch:483  d_loss:2.8992  g_loss:2.2775
# epoch:484  d_loss:1.2328  g_loss:1.3817
# epoch:485  d_loss:2.1859  g_loss:0.5971
# epoch:486  d_loss:0.4289  g_loss:3.4923
# epoch:487  d_loss:0.1990  g_loss:8.6611
# epoch:488  d_loss:1.4333  g_loss:5.1753
# epoch:489  d_loss:0.5442  g_loss:1.9539
# epoch:490  d_loss:0.5030  g_loss:0.9506
# epoch:491  d_loss:0.4980  g_loss:1.6704
# epoch:492  d_loss:0.1189  g_loss:4.1583
# epoch:493  d_loss:0.1055  g_loss:5.6985
# epoch:494  d_loss:0.2448  g_loss:5.2026
# epoch:495  d_loss:0.3530  g_loss:4.4610
# epoch:496  d_loss:0.2707  g_loss:3.6511
# epoch:497  d_loss:0.1675  g_loss:2.5288
# epoch:498  d_loss:0.2743  g_loss:2.3192
# epoch:499  d_loss:0.2661  g_loss:3.2496
# epoch:500  d_loss:0.2346  g_loss:4.7287
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:501  d_loss:0.0520  g_loss:5.1280
# epoch:502  d_loss:0.2435  g_loss:4.1593
# epoch:503  d_loss:0.2727  g_loss:2.4485
# epoch:504  d_loss:0.3065  g_loss:1.7083
# epoch:505  d_loss:0.1619  g_loss:3.0803
# epoch:506  d_loss:0.1611  g_loss:4.2534
# epoch:507  d_loss:0.2270  g_loss:5.3151
# epoch:508  d_loss:0.2198  g_loss:4.1202
# epoch:509  d_loss:0.2856  g_loss:2.8885
# epoch:510  d_loss:0.2120  g_loss:2.0840
# epoch:511  d_loss:0.4602  g_loss:1.9605
# epoch:512  d_loss:0.2369  g_loss:2.8046
# epoch:513  d_loss:0.1738  g_loss:4.3798
# epoch:514  d_loss:0.0863  g_loss:4.5581
# epoch:515  d_loss:0.3302  g_loss:2.5440
# epoch:516  d_loss:0.5147  g_loss:1.5726
# epoch:517  d_loss:0.0738  g_loss:5.1412
# epoch:518  d_loss:0.3479  g_loss:2.5040
# epoch:519  d_loss:0.3371  g_loss:1.7849
# epoch:520  d_loss:0.2083  g_loss:2.3387
# epoch:521  d_loss:0.0955  g_loss:2.7820
# epoch:522  d_loss:0.1439  g_loss:3.2855
# epoch:523  d_loss:0.1259  g_loss:2.7030
# epoch:524  d_loss:0.1679  g_loss:1.9449
# epoch:525  d_loss:0.1736  g_loss:1.8194
# epoch:526  d_loss:0.1434  g_loss:2.1735
# epoch:527  d_loss:0.1857  g_loss:2.6530
# epoch:528  d_loss:0.0687  g_loss:2.7182
# epoch:529  d_loss:0.0684  g_loss:3.1267
# epoch:530  d_loss:0.1548  g_loss:3.7179
# epoch:531  d_loss:0.1551  g_loss:2.9068
# epoch:532  d_loss:0.1430  g_loss:2.8507
# epoch:533  d_loss:0.2410  g_loss:2.0977
# epoch:534  d_loss:0.0713  g_loss:2.5378
# epoch:535  d_loss:0.1504  g_loss:2.8239
# epoch:536  d_loss:0.1365  g_loss:3.1633
# epoch:537  d_loss:0.0613  g_loss:2.9618
# epoch:538  d_loss:0.1713  g_loss:2.3481
# epoch:539  d_loss:0.1448  g_loss:1.9586
# epoch:540  d_loss:0.1380  g_loss:2.5169
# epoch:541  d_loss:0.1042  g_loss:3.0087
# epoch:542  d_loss:0.1387  g_loss:2.5821
# epoch:543  d_loss:0.1598  g_loss:2.0536
# epoch:544  d_loss:0.0931  g_loss:3.0890
# epoch:545  d_loss:0.0619  g_loss:3.2546
# epoch:546  d_loss:0.0998  g_loss:2.9460
# epoch:547  d_loss:0.1133  g_loss:2.0971
# epoch:548  d_loss:0.3084  g_loss:1.4232
# epoch:549  d_loss:0.3215  g_loss:2.0580
# epoch:550  d_loss:0.3218  g_loss:2.5166
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:551  d_loss:0.0894  g_loss:3.1145
# epoch:552  d_loss:0.4324  g_loss:1.5367
# epoch:553  d_loss:0.4761  g_loss:2.5057
# epoch:554  d_loss:0.3483  g_loss:1.7531
# epoch:555  d_loss:0.5607  g_loss:1.1556
# epoch:556  d_loss:0.2459  g_loss:1.6309
# epoch:557  d_loss:0.2028  g_loss:1.5955
# epoch:558  d_loss:0.2932  g_loss:1.6376
# epoch:559  d_loss:0.2749  g_loss:2.0569
# epoch:560  d_loss:0.2127  g_loss:1.9901
# epoch:561  d_loss:0.6323  g_loss:0.8492
# epoch:562  d_loss:0.8898  g_loss:0.5263
# epoch:563  d_loss:0.4714  g_loss:1.8282
# epoch:564  d_loss:0.5486  g_loss:2.9550
# epoch:565  d_loss:0.8071  g_loss:0.5669
# epoch:566  d_loss:0.5556  g_loss:0.6614
# epoch:567  d_loss:0.4355  g_loss:1.7240
# epoch:568  d_loss:0.1185  g_loss:5.0379
# epoch:569  d_loss:2.0404  g_loss:0.1465
# epoch:570  d_loss:1.4477  g_loss:0.1111
# epoch:571  d_loss:0.5036  g_loss:1.1192
# epoch:572  d_loss:0.4154  g_loss:2.3833
# epoch:573  d_loss:0.7736  g_loss:1.6292
# epoch:574  d_loss:0.4407  g_loss:0.7996
# epoch:575  d_loss:0.7769  g_loss:0.3535
# epoch:576  d_loss:0.5926  g_loss:0.7601
# epoch:577  d_loss:0.5366  g_loss:1.0138
# epoch:578  d_loss:0.6715  g_loss:1.0723
# epoch:579  d_loss:0.9234  g_loss:0.3434
# epoch:580  d_loss:0.5406  g_loss:0.4142
# epoch:581  d_loss:0.5675  g_loss:0.5884
# epoch:582  d_loss:0.4324  g_loss:1.0530
# epoch:583  d_loss:0.4655  g_loss:1.8417
# epoch:584  d_loss:0.2815  g_loss:1.5771
# epoch:585  d_loss:0.5601  g_loss:0.8086
# epoch:586  d_loss:0.9231  g_loss:0.2415
# epoch:587  d_loss:0.7752  g_loss:0.6064
# epoch:588  d_loss:0.5230  g_loss:1.9790
# epoch:589  d_loss:0.7844  g_loss:1.0537
# epoch:590  d_loss:0.6699  g_loss:0.6264
# epoch:591  d_loss:0.5504  g_loss:0.4565
# epoch:592  d_loss:0.2688  g_loss:1.0115
# epoch:593  d_loss:0.2634  g_loss:1.2771
# epoch:594  d_loss:0.5324  g_loss:0.8003
# epoch:595  d_loss:0.8594  g_loss:0.4695
# epoch:596  d_loss:0.5750  g_loss:0.7094
# epoch:597  d_loss:0.5517  g_loss:1.3695
# epoch:598  d_loss:1.2422  g_loss:0.6663
# epoch:599  d_loss:0.7835  g_loss:0.7785
# epoch:600  d_loss:0.9818  g_loss:0.8531
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:601  d_loss:0.5822  g_loss:0.8982
# epoch:602  d_loss:0.9967  g_loss:0.6298
# epoch:603  d_loss:0.5766  g_loss:1.3754
# epoch:604  d_loss:0.9651  g_loss:0.7701
# epoch:605  d_loss:0.7595  g_loss:0.6501
# epoch:606  d_loss:0.5453  g_loss:0.6886
# epoch:607  d_loss:0.5296  g_loss:1.0287
# epoch:608  d_loss:0.3497  g_loss:1.3389
# epoch:609  d_loss:0.3896  g_loss:1.0514
# epoch:610  d_loss:0.5207  g_loss:0.6914
# epoch:611  d_loss:0.6413  g_loss:0.9396
# epoch:612  d_loss:0.5755  g_loss:0.6640
# epoch:613  d_loss:0.5953  g_loss:0.8152
# epoch:614  d_loss:0.7712  g_loss:0.8493
# epoch:615  d_loss:0.6701  g_loss:0.8686
# epoch:616  d_loss:0.9313  g_loss:0.4764
# epoch:617  d_loss:0.8635  g_loss:0.4167
# epoch:618  d_loss:0.6627  g_loss:0.9194
# epoch:619  d_loss:1.2986  g_loss:0.5337
# epoch:620  d_loss:0.5357  g_loss:1.2868
# epoch:621  d_loss:0.6829  g_loss:1.3917
# epoch:622  d_loss:0.9346  g_loss:0.5946
# epoch:623  d_loss:0.8095  g_loss:0.6832
# epoch:624  d_loss:0.6579  g_loss:0.8407
# epoch:625  d_loss:0.8452  g_loss:0.6414
# epoch:626  d_loss:0.6179  g_loss:0.7228
# epoch:627  d_loss:0.4675  g_loss:1.1139
# epoch:628  d_loss:0.8069  g_loss:0.7056
# epoch:629  d_loss:0.5478  g_loss:0.7087
# epoch:630  d_loss:0.7083  g_loss:0.7007
# epoch:631  d_loss:0.6272  g_loss:0.6623
# epoch:632  d_loss:0.7331  g_loss:0.7061
# epoch:633  d_loss:0.7170  g_loss:0.7448
# epoch:634  d_loss:0.8254  g_loss:0.5798
# epoch:635  d_loss:0.9619  g_loss:0.6614
# epoch:636  d_loss:0.7122  g_loss:1.2265
# epoch:637  d_loss:0.6113  g_loss:1.7321
# epoch:638  d_loss:0.7719  g_loss:1.4782
# epoch:639  d_loss:0.8603  g_loss:0.6214
# epoch:640  d_loss:0.7725  g_loss:0.8001
# epoch:641  d_loss:0.5369  g_loss:1.3922
# epoch:642  d_loss:0.8679  g_loss:1.0147
# epoch:643  d_loss:0.6532  g_loss:0.9582
# epoch:644  d_loss:0.5791  g_loss:1.0347
# epoch:645  d_loss:0.4312  g_loss:1.3374
# epoch:646  d_loss:0.4666  g_loss:1.5476
# epoch:647  d_loss:0.5055  g_loss:1.3114
# epoch:648  d_loss:0.4184  g_loss:1.1412
# epoch:649  d_loss:0.3298  g_loss:1.2048
# epoch:650  d_loss:0.2904  g_loss:1.4462
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# epoch:651  d_loss:0.3534  g_loss:1.6471
# epoch:652  d_loss:0.3690  g_loss:1.7610
# epoch:653  d_loss:0.5060  g_loss:1.1883
# epoch:654  d_loss:0.4645  g_loss:0.9038
# epoch:655  d_loss:0.6648  g_loss:0.8341
# epoch:656  d_loss:0.5505  g_loss:1.3185
# epoch:657  d_loss:0.5936  g_loss:1.2310
# epoch:658  d_loss:0.6834  g_loss:1.2570
# epoch:659  d_loss:0.5011  g_loss:1.0609
# epoch:660  d_loss:0.8120  g_loss:0.9144
# epoch:661  d_loss:0.7334  g_loss:1.1366
# epoch:662  d_loss:0.6561  g_loss:1.5935
# epoch:663  d_loss:0.8064  g_loss:1.7381
# epoch:664  d_loss:0.4849  g_loss:1.7926
# epoch:665  d_loss:0.6531  g_loss:1.5696
# epoch:666  d_loss:1.2559  g_loss:0.4576
# epoch:667  d_loss:0.9821  g_loss:0.5660
# epoch:668  d_loss:1.0894  g_loss:0.6884
# epoch:669  d_loss:0.8911  g_loss:0.7272
# epoch:670  d_loss:0.5168  g_loss:1.1512
# epoch:671  d_loss:0.4394  g_loss:1.5659
# epoch:672  d_loss:0.4226  g_loss:1.5597
# epoch:673  d_loss:0.3303  g_loss:1.6228
# epoch:674  d_loss:0.2395  g_loss:1.6329
# epoch:675  d_loss:0.2953  g_loss:1.6201
# epoch:676  d_loss:0.2021  g_loss:1.8833
# epoch:677  d_loss:0.2647  g_loss:1.8277
# epoch:678  d_loss:0.3383  g_loss:1.7898
# epoch:679  d_loss:0.3371  g_loss:1.5165
# epoch:680  d_loss:0.2712  g_loss:1.5639
# epoch:681  d_loss:0.3426  g_loss:1.4438
# epoch:682  d_loss:0.2995  g_loss:1.2671
# epoch:683  d_loss:0.5390  g_loss:1.0772
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-89245093b1c2> in <module>
#     130
#     131 # gan_train(epochs, batch, 500)
# --> 132 gan_train(epochs, batch, 50)
#     133
#     134 end = datetime.now()
#
# <ipython-input-7-89245093b1c2> in gan_train(epoch, batch_size, saving_interval)
#      75             # plt.imshow(gen_imgs,'gray')
#      76             # plt.show()
# ---> 77         d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)
#      78
#      79         #판별자와 생성자의 오차를 계산합니다.
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1723       iterator = data_adapter.single_batch_iterator(self.distribute_strategy, x,
#    1724                                                     y, sample_weight,
# -> 1725                                                     class_weight)
#    1726       self.train_function = self.make_train_function()
#    1727       logs = self.train_function(iterator)
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\engine\data_adapter.py in single_batch_iterator(strategy, x, y, sample_weight, class_weight)
#    1512
#    1513   _check_data_cardinality(data)
# -> 1514   dataset = dataset_ops.DatasetV2.from_tensors(data)
#    1515   if class_weight:
#    1516     dataset = dataset.map(_make_class_weight_map_fn(class_weight))
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in from_tensors(tensors)
#     611       Dataset: A `Dataset`.
#     612     """
# --> 613     return TensorDataset(tensors)
#     614
#     615   @staticmethod
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\data\ops\dataset_ops.py in __init__(self, element)
#    3140     variant_tensor = gen_dataset_ops.tensor_dataset(
#    3141         self._tensors,
# -> 3142         output_shapes=structure.get_flat_tensor_shapes(self._structure))
#    3143     super(TensorDataset, self).__init__(variant_tensor)
#    3144
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\ops\gen_dataset_ops.py in tensor_dataset(components, output_shapes, name)
#    6685       _result = pywrap_tfe.TFE_Py_FastPathExecute(
#    6686         _ctx, "TensorDataset", name, components, "output_shapes",
# -> 6687         output_shapes)
#    6688       return _result
#    6689     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan14.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
