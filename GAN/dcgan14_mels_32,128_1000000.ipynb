# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 32
y_size = 128
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 100001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 32768)             3309568
# _________________________________________________________________
# batch_normalization (BatchNo (None, 32768)             131072
# _________________________________________________________________
# reshape (Reshape)            (None, 8, 32, 128)        0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 16, 64, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 16, 64, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 16, 64, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 16, 64, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 32, 128, 64)       0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 32, 128, 1)        1601
# =================================================================
# Total params: 3,647,361
# Trainable params: 3,581,697
# Non-trainable params: 65,664
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 16, 64, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 16, 64, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 16, 64, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 8, 32, 128)        204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 8, 32, 128)        0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 8, 32, 128)        0
# _________________________________________________________________
# flatten (Flatten)            (None, 32768)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 32769
# =================================================================
# Total params: 239,361
# Trainable params: 0
# Non-trainable params: 239,361
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 32, 128, 1)        3647361
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 239361
# =================================================================
# Total params: 3,886,722
# Trainable params: 3,581,697
# Non-trainable params: 305,025
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (2331, 128, 32)
# Out:
# 28, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (128, 862)
# (128, 32)
# (2331, 128, 32)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 128, 32)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.00016182661 -80.0

  scale = MaxAbsScaler()
    #   절대값이 0~1사이에 매핑
    #   -1 ~ 1 사이로 재조정
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4096)
  print(np.max(X_train), np.min(X_train))   # -2.0228326e-06 -1.0


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 32, 128, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan14.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            # idx2 = np.random.randint(0, gen_imgs.shape[0])
            idx2 = 5    # 출력 값 고정
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 32, 128, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (862,128))
            # gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            # print(gen_mels.shape) # (862, 128)
            # gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan14\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
            

gan_train(epochs, batch, 500)


end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# :0.5849  g_loss:8.5318
# epoch:99529  d_loss:0.3105  g_loss:5.2444
# epoch:99530  d_loss:0.1075  g_loss:5.6596
# epoch:99531  d_loss:0.0587  g_loss:4.1146
# epoch:99532  d_loss:0.0326  g_loss:7.3386
# epoch:99533  d_loss:0.0609  g_loss:7.0361
# epoch:99534  d_loss:0.1763  g_loss:8.4227
# epoch:99535  d_loss:0.0736  g_loss:10.3787
# epoch:99536  d_loss:0.2321  g_loss:10.0579
# epoch:99537  d_loss:0.0116  g_loss:9.1352
# epoch:99538  d_loss:0.0037  g_loss:9.1749
# epoch:99539  d_loss:0.0571  g_loss:8.6603
# epoch:99540  d_loss:0.1086  g_loss:9.1703
# epoch:99541  d_loss:0.0633  g_loss:9.8460
# epoch:99542  d_loss:0.0303  g_loss:6.6763
# epoch:99543  d_loss:0.2180  g_loss:4.9609
# epoch:99544  d_loss:0.1688  g_loss:7.0446
# epoch:99545  d_loss:0.1363  g_loss:9.2071
# epoch:99546  d_loss:0.2920  g_loss:7.1970
# epoch:99547  d_loss:0.2282  g_loss:9.0099
# epoch:99548  d_loss:0.3420  g_loss:4.9980
# epoch:99549  d_loss:0.2897  g_loss:6.2683
# epoch:99550  d_loss:0.4966  g_loss:5.3650
# epoch:99551  d_loss:0.2129  g_loss:4.2487
# epoch:99552  d_loss:0.0084  g_loss:9.6046
# epoch:99553  d_loss:0.8870  g_loss:5.8914
# epoch:99554  d_loss:0.7811  g_loss:7.1880
# epoch:99555  d_loss:0.4514  g_loss:6.6956
# epoch:99556  d_loss:0.1548  g_loss:14.2205
# epoch:99557  d_loss:0.2905  g_loss:13.0865
# epoch:99558  d_loss:0.5628  g_loss:12.0755
# epoch:99559  d_loss:0.3084  g_loss:10.0474
# epoch:99560  d_loss:0.3183  g_loss:9.9030
# epoch:99561  d_loss:0.2718  g_loss:10.1082
# epoch:99562  d_loss:0.0101  g_loss:10.9186
# epoch:99563  d_loss:0.1779  g_loss:13.5484
# epoch:99564  d_loss:0.7296  g_loss:7.9019
# epoch:99565  d_loss:0.8220  g_loss:4.4042
# epoch:99566  d_loss:1.5820  g_loss:4.5645
# epoch:99567  d_loss:1.0115  g_loss:5.1631
# epoch:99568  d_loss:0.4676  g_loss:8.2328
# epoch:99569  d_loss:1.2014  g_loss:7.9128
# epoch:99570  d_loss:0.2524  g_loss:3.8818
# epoch:99571  d_loss:0.1913  g_loss:6.8655
# epoch:99572  d_loss:0.1927  g_loss:7.6556
# epoch:99573  d_loss:0.0611  g_loss:8.4464
# epoch:99574  d_loss:0.0534  g_loss:9.7838
# epoch:99575  d_loss:0.3236  g_loss:7.1083
# epoch:99576  d_loss:0.0132  g_loss:5.2593
# epoch:99577  d_loss:0.0815  g_loss:7.0812
# epoch:99578  d_loss:0.1514  g_loss:5.9583
# epoch:99579  d_loss:0.3056  g_loss:8.1386
# epoch:99580  d_loss:0.0537  g_loss:9.1724
# epoch:99581  d_loss:0.0647  g_loss:9.8630
# epoch:99582  d_loss:0.1431  g_loss:10.8492
# epoch:99583  d_loss:0.5186  g_loss:8.2698
# epoch:99584  d_loss:0.3447  g_loss:4.7709
# epoch:99585  d_loss:0.5471  g_loss:5.7116
# epoch:99586  d_loss:0.5584  g_loss:10.0069
# epoch:99587  d_loss:0.0317  g_loss:13.1863
# epoch:99588  d_loss:0.6225  g_loss:11.2120
# epoch:99589  d_loss:0.4373  g_loss:7.9996
# epoch:99590  d_loss:0.7427  g_loss:5.7109
# epoch:99591  d_loss:0.4016  g_loss:7.7688
# epoch:99592  d_loss:0.2068  g_loss:8.9990
# epoch:99593  d_loss:0.0703  g_loss:13.7879
# epoch:99594  d_loss:1.0111  g_loss:10.0376
# epoch:99595  d_loss:0.2606  g_loss:6.3873
# epoch:99596  d_loss:0.3673  g_loss:8.2240
# epoch:99597  d_loss:0.6385  g_loss:11.9395
# epoch:99598  d_loss:0.7469  g_loss:16.8969
# epoch:99599  d_loss:0.3965  g_loss:18.0311
# epoch:99600  d_loss:1.3315  g_loss:9.7843
# epoch:99601  d_loss:0.5097  g_loss:9.9617
# epoch:99602  d_loss:0.7439  g_loss:8.8847
# epoch:99603  d_loss:0.4807  g_loss:10.9112
# epoch:99604  d_loss:1.3604  g_loss:8.4880
# epoch:99605  d_loss:0.4044  g_loss:4.1436
# epoch:99606  d_loss:1.3281  g_loss:6.1408
# epoch:99607  d_loss:0.6269  g_loss:6.4760
# epoch:99608  d_loss:0.3845  g_loss:5.9407
# epoch:99609  d_loss:0.5119  g_loss:5.3464
# epoch:99610  d_loss:0.6171  g_loss:5.5733
# epoch:99611  d_loss:0.1734  g_loss:11.3768
# epoch:99612  d_loss:0.6636  g_loss:10.2859
# epoch:99613  d_loss:0.6246  g_loss:6.7268
# epoch:99614  d_loss:0.1340  g_loss:4.4657
# epoch:99615  d_loss:0.7232  g_loss:6.7011
# epoch:99616  d_loss:0.2849  g_loss:7.2465
# epoch:99617  d_loss:0.2267  g_loss:10.2132
# epoch:99618  d_loss:0.1439  g_loss:6.4894
# epoch:99619  d_loss:0.2006  g_loss:4.1837
# epoch:99620  d_loss:0.3739  g_loss:3.8864
# epoch:99621  d_loss:0.2788  g_loss:4.4183
# epoch:99622  d_loss:0.1545  g_loss:8.0522
# epoch:99623  d_loss:0.2163  g_loss:7.8231
# epoch:99624  d_loss:0.0079  g_loss:9.8498
# epoch:99625  d_loss:0.1225  g_loss:10.4107
# epoch:99626  d_loss:0.6831  g_loss:4.7701
# epoch:99627  d_loss:0.7684  g_loss:4.0661
# epoch:99628  d_loss:0.4026  g_loss:5.2792
# epoch:99629  d_loss:0.2245  g_loss:8.5009
# epoch:99630  d_loss:0.5855  g_loss:8.6093
# epoch:99631  d_loss:0.5566  g_loss:8.0392
# epoch:99632  d_loss:0.3545  g_loss:10.0231
# epoch:99633  d_loss:0.0951  g_loss:11.0379
# epoch:99634  d_loss:0.3540  g_loss:10.0499
# epoch:99635  d_loss:0.2886  g_loss:8.4283
# epoch:99636  d_loss:0.1563  g_loss:7.6988
# epoch:99637  d_loss:0.2161  g_loss:7.1616
# epoch:99638  d_loss:0.2504  g_loss:7.5347
# epoch:99639  d_loss:0.2956  g_loss:6.5895
# epoch:99640  d_loss:0.2372  g_loss:8.1861
# epoch:99641  d_loss:0.2724  g_loss:8.2980
# epoch:99642  d_loss:0.5652  g_loss:4.7434
# epoch:99643  d_loss:0.2877  g_loss:4.5861
# epoch:99644  d_loss:0.3106  g_loss:3.6524
# epoch:99645  d_loss:0.2188  g_loss:5.4105
# epoch:99646  d_loss:0.0103  g_loss:8.9298
# epoch:99647  d_loss:0.2123  g_loss:7.4773
# epoch:99648  d_loss:0.1535  g_loss:7.6041
# epoch:99649  d_loss:0.0103  g_loss:6.3825
# epoch:99650  d_loss:0.4360  g_loss:6.5050
# epoch:99651  d_loss:0.0041  g_loss:8.6927
# epoch:99652  d_loss:0.2161  g_loss:8.9695
# epoch:99653  d_loss:0.0509  g_loss:7.0402
# epoch:99654  d_loss:0.2194  g_loss:6.8390
# epoch:99655  d_loss:0.2180  g_loss:7.3136
# epoch:99656  d_loss:0.0382  g_loss:10.3285
# epoch:99657  d_loss:0.0392  g_loss:7.5013
# epoch:99658  d_loss:0.0798  g_loss:7.2129
# epoch:99659  d_loss:0.0324  g_loss:6.3268
# epoch:99660  d_loss:0.0058  g_loss:8.3493
# epoch:99661  d_loss:0.2504  g_loss:6.5258
# epoch:99662  d_loss:0.2260  g_loss:6.9258
# epoch:99663  d_loss:0.6414  g_loss:6.3155
# epoch:99664  d_loss:0.1619  g_loss:9.0394
# epoch:99665  d_loss:0.3523  g_loss:10.5399
# epoch:99666  d_loss:0.5134  g_loss:8.4394
# epoch:99667  d_loss:0.6295  g_loss:3.7353
# epoch:99668  d_loss:0.2796  g_loss:2.9215
# epoch:99669  d_loss:0.7264  g_loss:4.7115
# epoch:99670  d_loss:0.4743  g_loss:11.0248
# epoch:99671  d_loss:0.3382  g_loss:14.3678
# epoch:99672  d_loss:1.6778  g_loss:9.6756
# epoch:99673  d_loss:0.6442  g_loss:5.1042
# epoch:99674  d_loss:1.8548  g_loss:6.5392
# epoch:99675  d_loss:0.5993  g_loss:10.6065
# epoch:99676  d_loss:0.4567  g_loss:12.6979
# epoch:99677  d_loss:0.4877  g_loss:7.5743
# epoch:99678  d_loss:0.5627  g_loss:3.1185
# epoch:99679  d_loss:0.5644  g_loss:6.0182
# epoch:99680  d_loss:0.3891  g_loss:7.4103
# epoch:99681  d_loss:0.4824  g_loss:7.7695
# epoch:99682  d_loss:0.4371  g_loss:7.3793
# epoch:99683  d_loss:0.3944  g_loss:6.2374
# epoch:99684  d_loss:0.0944  g_loss:6.2322
# epoch:99685  d_loss:0.0707  g_loss:6.0125
# epoch:99686  d_loss:0.7001  g_loss:5.0771
# epoch:99687  d_loss:0.1454  g_loss:6.2236
# epoch:99688  d_loss:0.0291  g_loss:9.3794
# epoch:99689  d_loss:0.3028  g_loss:7.5340
# epoch:99690  d_loss:0.2447  g_loss:6.9657
# epoch:99691  d_loss:0.0702  g_loss:8.7465
# epoch:99692  d_loss:0.1482  g_loss:8.2619
# epoch:99693  d_loss:0.1548  g_loss:7.6480
# epoch:99694  d_loss:0.0698  g_loss:6.0852
# epoch:99695  d_loss:0.0460  g_loss:6.5818
# epoch:99696  d_loss:0.2262  g_loss:5.0907
# epoch:99697  d_loss:0.5835  g_loss:6.0001
# epoch:99698  d_loss:0.3926  g_loss:9.1800
# epoch:99699  d_loss:0.5930  g_loss:9.2208
# epoch:99700  d_loss:0.3390  g_loss:7.1729
# epoch:99701  d_loss:0.9299  g_loss:4.4126
# epoch:99702  d_loss:0.5848  g_loss:5.5229
# epoch:99703  d_loss:0.6934  g_loss:6.0927
# epoch:99704  d_loss:0.5851  g_loss:10.4420
# epoch:99705  d_loss:0.2588  g_loss:14.0411
# epoch:99706  d_loss:0.8636  g_loss:6.8900
# epoch:99707  d_loss:0.7612  g_loss:7.9340
# epoch:99708  d_loss:0.1114  g_loss:6.3475
# epoch:99709  d_loss:0.5551  g_loss:10.7137
# epoch:99710  d_loss:0.3559  g_loss:12.1881
# epoch:99711  d_loss:0.5539  g_loss:12.5977
# epoch:99712  d_loss:0.0721  g_loss:9.1329
# epoch:99713  d_loss:0.8530  g_loss:7.9469
# epoch:99714  d_loss:0.2391  g_loss:8.8052
# epoch:99715  d_loss:0.2227  g_loss:11.8424
# epoch:99716  d_loss:0.7210  g_loss:4.4686
# epoch:99717  d_loss:0.3203  g_loss:4.0135
# epoch:99718  d_loss:0.6971  g_loss:5.5517
# epoch:99719  d_loss:0.3821  g_loss:9.1964
# epoch:99720  d_loss:0.3557  g_loss:9.1649
# epoch:99721  d_loss:0.2720  g_loss:8.6519
# epoch:99722  d_loss:0.3696  g_loss:5.0367
# epoch:99723  d_loss:0.2512  g_loss:4.3708
# epoch:99724  d_loss:0.1117  g_loss:5.4284
# epoch:99725  d_loss:0.1689  g_loss:6.4101
# epoch:99726  d_loss:0.0749  g_loss:7.2493
# epoch:99727  d_loss:0.2254  g_loss:8.8739
# epoch:99728  d_loss:0.0069  g_loss:11.4713
# epoch:99729  d_loss:0.0157  g_loss:11.2456
# epoch:99730  d_loss:0.0012  g_loss:11.1366
# epoch:99731  d_loss:0.0449  g_loss:10.4842
# epoch:99732  d_loss:0.0801  g_loss:10.6161
# epoch:99733  d_loss:0.1477  g_loss:7.2320
# epoch:99734  d_loss:0.2009  g_loss:6.1558
# epoch:99735  d_loss:0.0815  g_loss:4.7075
# epoch:99736  d_loss:0.2423  g_loss:6.6015
# epoch:99737  d_loss:0.1302  g_loss:8.9981
# epoch:99738  d_loss:0.0121  g_loss:10.3604
# epoch:99739  d_loss:0.0017  g_loss:12.3086
# epoch:99740  d_loss:0.3351  g_loss:9.5554
# epoch:99741  d_loss:0.4057  g_loss:6.8684
# epoch:99742  d_loss:0.7630  g_loss:6.0173
# epoch:99743  d_loss:0.1209  g_loss:9.8224
# epoch:99744  d_loss:0.4553  g_loss:9.4315
# epoch:99745  d_loss:0.1637  g_loss:13.3039
# epoch:99746  d_loss:0.6483  g_loss:9.5381
# epoch:99747  d_loss:0.4421  g_loss:6.5216
# epoch:99748  d_loss:1.2507  g_loss:4.6424
# epoch:99749  d_loss:0.4837  g_loss:6.1603
# epoch:99750  d_loss:0.4915  g_loss:9.5854
# epoch:99751  d_loss:0.1902  g_loss:11.6154
# epoch:99752  d_loss:0.1993  g_loss:11.6317
# epoch:99753  d_loss:0.1039  g_loss:8.1596
# epoch:99754  d_loss:0.0308  g_loss:7.9449
# epoch:99755  d_loss:0.1728  g_loss:7.6767
# epoch:99756  d_loss:0.2940  g_loss:9.1387
# epoch:99757  d_loss:0.5003  g_loss:9.3875
# epoch:99758  d_loss:0.0533  g_loss:12.3877
# epoch:99759  d_loss:0.3185  g_loss:12.8791
# epoch:99760  d_loss:0.3179  g_loss:7.3091
# epoch:99761  d_loss:0.2080  g_loss:5.6678
# epoch:99762  d_loss:0.3339  g_loss:3.3285
# epoch:99763  d_loss:0.7038  g_loss:4.2008
# epoch:99764  d_loss:0.2183  g_loss:5.8991
# epoch:99765  d_loss:0.0517  g_loss:9.6696
# epoch:99766  d_loss:0.4667  g_loss:11.5511
# epoch:99767  d_loss:0.4846  g_loss:9.5634
# epoch:99768  d_loss:0.4525  g_loss:7.8494
# epoch:99769  d_loss:0.3882  g_loss:6.4744
# epoch:99770  d_loss:0.2340  g_loss:6.1854
# epoch:99771  d_loss:0.1684  g_loss:5.5508
# epoch:99772  d_loss:0.2993  g_loss:7.5337
# epoch:99773  d_loss:0.4401  g_loss:8.3837
# epoch:99774  d_loss:0.1646  g_loss:7.4054
# epoch:99775  d_loss:0.3560  g_loss:6.6787
# epoch:99776  d_loss:0.0357  g_loss:6.5508
# epoch:99777  d_loss:0.2633  g_loss:6.8253
# epoch:99778  d_loss:0.2520  g_loss:6.0977
# epoch:99779  d_loss:0.5134  g_loss:5.6785
# epoch:99780  d_loss:0.3149  g_loss:7.5101
# epoch:99781  d_loss:0.2394  g_loss:9.9523
# epoch:99782  d_loss:0.9623  g_loss:6.5784
# epoch:99783  d_loss:0.6610  g_loss:6.2842
# epoch:99784  d_loss:0.4953  g_loss:6.0505
# epoch:99785  d_loss:0.6591  g_loss:7.9656
# epoch:99786  d_loss:0.3310  g_loss:8.5059
# epoch:99787  d_loss:0.2815  g_loss:10.8689
# epoch:99788  d_loss:0.3974  g_loss:6.5083
# epoch:99789  d_loss:0.5643  g_loss:6.3247
# epoch:99790  d_loss:0.4802  g_loss:6.4151
# epoch:99791  d_loss:0.1016  g_loss:7.8370
# epoch:99792  d_loss:0.1241  g_loss:7.5529
# epoch:99793  d_loss:0.6031  g_loss:7.4389
# epoch:99794  d_loss:0.1114  g_loss:7.8614
# epoch:99795  d_loss:0.4509  g_loss:6.0927
# epoch:99796  d_loss:0.2411  g_loss:8.2821
# epoch:99797  d_loss:0.1623  g_loss:10.3612
# epoch:99798  d_loss:0.2875  g_loss:8.6364
# epoch:99799  d_loss:0.2072  g_loss:8.5290
# epoch:99800  d_loss:0.1709  g_loss:10.9469
# epoch:99801  d_loss:0.3266  g_loss:9.7235
# epoch:99802  d_loss:0.2833  g_loss:9.0123
# epoch:99803  d_loss:0.1270  g_loss:9.8081
# epoch:99804  d_loss:0.3915  g_loss:7.4407
# epoch:99805  d_loss:0.3575  g_loss:8.3158
# epoch:99806  d_loss:0.4005  g_loss:9.8388
# epoch:99807  d_loss:0.0338  g_loss:9.1666
# epoch:99808  d_loss:0.2026  g_loss:8.0479
# epoch:99809  d_loss:0.4747  g_loss:8.6310
# epoch:99810  d_loss:1.2714  g_loss:5.3450
# epoch:99811  d_loss:0.3562  g_loss:7.5204
# epoch:99812  d_loss:0.2142  g_loss:6.7078
# epoch:99813  d_loss:0.5316  g_loss:7.8311
# epoch:99814  d_loss:0.2447  g_loss:6.7211
# epoch:99815  d_loss:0.0387  g_loss:9.6023
# epoch:99816  d_loss:0.0179  g_loss:9.8132
# epoch:99817  d_loss:0.2464  g_loss:8.7676
# epoch:99818  d_loss:0.6763  g_loss:4.9709
# epoch:99819  d_loss:0.3417  g_loss:4.6027
# epoch:99820  d_loss:0.2653  g_loss:6.4339
# epoch:99821  d_loss:0.1928  g_loss:9.1532
# epoch:99822  d_loss:0.2361  g_loss:11.7201
# epoch:99823  d_loss:0.6542  g_loss:7.2937
# epoch:99824  d_loss:0.1167  g_loss:3.8189
# epoch:99825  d_loss:1.7869  g_loss:4.6799
# epoch:99826  d_loss:0.1797  g_loss:8.7552
# epoch:99827  d_loss:0.1691  g_loss:14.4243
# epoch:99828  d_loss:0.6352  g_loss:14.4123
# epoch:99829  d_loss:0.6547  g_loss:10.0241
# epoch:99830  d_loss:0.2759  g_loss:3.7900
# epoch:99831  d_loss:0.9003  g_loss:4.8768
# epoch:99832  d_loss:0.0527  g_loss:7.8448
# epoch:99833  d_loss:0.1614  g_loss:11.1297
# epoch:99834  d_loss:0.3173  g_loss:10.3956
# epoch:99835  d_loss:0.9602  g_loss:8.0440
# epoch:99836  d_loss:0.3717  g_loss:4.2395
# epoch:99837  d_loss:0.3355  g_loss:6.7549
# epoch:99838  d_loss:0.1148  g_loss:7.0758
# epoch:99839  d_loss:0.5274  g_loss:8.1975
# epoch:99840  d_loss:0.0531  g_loss:9.4642
# epoch:99841  d_loss:0.4666  g_loss:6.7264
# epoch:99842  d_loss:0.1796  g_loss:6.1780
# epoch:99843  d_loss:0.6885  g_loss:5.3249
# epoch:99844  d_loss:0.0441  g_loss:7.6779
# epoch:99845  d_loss:0.0727  g_loss:8.1471
# epoch:99846  d_loss:0.2141  g_loss:6.1602
# epoch:99847  d_loss:0.2397  g_loss:5.8358
# epoch:99848  d_loss:0.2466  g_loss:4.8769
# epoch:99849  d_loss:0.0957  g_loss:6.0085
# epoch:99850  d_loss:0.2238  g_loss:8.3657
# epoch:99851  d_loss:0.1712  g_loss:10.1301
# epoch:99852  d_loss:0.5714  g_loss:6.8076
# epoch:99853  d_loss:0.3541  g_loss:7.1745
# epoch:99854  d_loss:0.0529  g_loss:7.1817
# epoch:99855  d_loss:0.0445  g_loss:7.2229
# epoch:99856  d_loss:0.0843  g_loss:7.8546
# epoch:99857  d_loss:0.1130  g_loss:9.4851
# epoch:99858  d_loss:0.3742  g_loss:8.8476
# epoch:99859  d_loss:0.4554  g_loss:6.9505
# epoch:99860  d_loss:0.7355  g_loss:6.6670
# epoch:99861  d_loss:0.3569  g_loss:8.4984
# epoch:99862  d_loss:0.3642  g_loss:6.3113
# epoch:99863  d_loss:0.4262  g_loss:8.1261
# epoch:99864  d_loss:0.4076  g_loss:7.3218
# epoch:99865  d_loss:0.3989  g_loss:8.3688
# epoch:99866  d_loss:0.2087  g_loss:5.8878
# epoch:99867  d_loss:0.8350  g_loss:3.4838
# epoch:99868  d_loss:0.7053  g_loss:7.3711
# epoch:99869  d_loss:0.3144  g_loss:9.6512
# epoch:99870  d_loss:0.0648  g_loss:15.0104
# epoch:99871  d_loss:1.0404  g_loss:10.5760
# epoch:99872  d_loss:0.6585  g_loss:6.0907
# epoch:99873  d_loss:0.8914  g_loss:8.2592
# epoch:99874  d_loss:0.3321  g_loss:6.5766
# epoch:99875  d_loss:0.6468  g_loss:6.3556
# epoch:99876  d_loss:0.1248  g_loss:9.7364
# epoch:99877  d_loss:0.0300  g_loss:10.7247
# epoch:99878  d_loss:0.9872  g_loss:7.5085
# epoch:99879  d_loss:0.2124  g_loss:5.3977
# epoch:99880  d_loss:0.2213  g_loss:5.3043
# epoch:99881  d_loss:0.4762  g_loss:6.0722
# epoch:99882  d_loss:0.1393  g_loss:7.7105
# epoch:99883  d_loss:0.2320  g_loss:10.0069
# epoch:99884  d_loss:0.4085  g_loss:9.0736
# epoch:99885  d_loss:0.2447  g_loss:7.4376
# epoch:99886  d_loss:0.0968  g_loss:5.5108
# epoch:99887  d_loss:0.1972  g_loss:7.2061
# epoch:99888  d_loss:0.1782  g_loss:8.5326
# epoch:99889  d_loss:0.5478  g_loss:11.2249
# epoch:99890  d_loss:0.2229  g_loss:9.5842
# epoch:99891  d_loss:0.1480  g_loss:6.8706
# epoch:99892  d_loss:0.0887  g_loss:6.1740
# epoch:99893  d_loss:0.3587  g_loss:4.8294
# epoch:99894  d_loss:0.3932  g_loss:5.2388
# epoch:99895  d_loss:0.3401  g_loss:7.0845
# epoch:99896  d_loss:0.3486  g_loss:8.1472
# epoch:99897  d_loss:0.7413  g_loss:7.4261
# epoch:99898  d_loss:0.1201  g_loss:7.3339
# epoch:99899  d_loss:0.2782  g_loss:8.7284
# epoch:99900  d_loss:0.1813  g_loss:7.1341
# epoch:99901  d_loss:0.2002  g_loss:7.4824
# epoch:99902  d_loss:0.2868  g_loss:7.1321
# epoch:99903  d_loss:0.5167  g_loss:8.3965
# epoch:99904  d_loss:0.1220  g_loss:6.9807
# epoch:99905  d_loss:0.3134  g_loss:9.2227
# epoch:99906  d_loss:0.1838  g_loss:9.0417
# epoch:99907  d_loss:0.2020  g_loss:8.5206
# epoch:99908  d_loss:0.2283  g_loss:9.0871
# epoch:99909  d_loss:0.0782  g_loss:9.7893
# epoch:99910  d_loss:0.1590  g_loss:8.1312
# epoch:99911  d_loss:0.1110  g_loss:7.1854
# epoch:99912  d_loss:0.1455  g_loss:7.1726
# epoch:99913  d_loss:0.1019  g_loss:7.1558
# epoch:99914  d_loss:0.0644  g_loss:5.0199
# epoch:99915  d_loss:0.2478  g_loss:4.7821
# epoch:99916  d_loss:0.4208  g_loss:5.1638
# epoch:99917  d_loss:0.0722  g_loss:6.6058
# epoch:99918  d_loss:0.0631  g_loss:6.4893
# epoch:99919  d_loss:0.3257  g_loss:6.9442
# epoch:99920  d_loss:0.0746  g_loss:6.8824
# epoch:99921  d_loss:0.0140  g_loss:6.6061
# epoch:99922  d_loss:0.1999  g_loss:8.8847
# epoch:99923  d_loss:0.3450  g_loss:7.5115
# epoch:99924  d_loss:0.0800  g_loss:6.2913
# epoch:99925  d_loss:0.1676  g_loss:9.2006
# epoch:99926  d_loss:0.1191  g_loss:8.8936
# epoch:99927  d_loss:0.5521  g_loss:6.5972
# epoch:99928  d_loss:0.0573  g_loss:5.1053
# epoch:99929  d_loss:0.1313  g_loss:4.2041
# epoch:99930  d_loss:0.3657  g_loss:4.8522
# epoch:99931  d_loss:0.0202  g_loss:8.4152
# epoch:99932  d_loss:0.1228  g_loss:8.8473
# epoch:99933  d_loss:0.3253  g_loss:8.4999
# epoch:99934  d_loss:0.1369  g_loss:7.3523
# epoch:99935  d_loss:0.0813  g_loss:5.5023
# epoch:99936  d_loss:0.2306  g_loss:5.6599
# epoch:99937  d_loss:0.1879  g_loss:6.2680
# epoch:99938  d_loss:0.1464  g_loss:10.1312
# epoch:99939  d_loss:0.6485  g_loss:7.3339
# epoch:99940  d_loss:0.8217  g_loss:6.8137
# epoch:99941  d_loss:0.7901  g_loss:8.2023
# epoch:99942  d_loss:0.3243  g_loss:10.1603
# epoch:99943  d_loss:0.3362  g_loss:13.7174
# epoch:99944  d_loss:0.1409  g_loss:12.7836
# epoch:99945  d_loss:0.5112  g_loss:10.5650
# epoch:99946  d_loss:1.0329  g_loss:6.8189
# epoch:99947  d_loss:0.8461  g_loss:7.1931
# epoch:99948  d_loss:0.1450  g_loss:8.0383
# epoch:99949  d_loss:0.4346  g_loss:14.6682
# epoch:99950  d_loss:0.5522  g_loss:12.3851
# epoch:99951  d_loss:0.4736  g_loss:9.8271
# epoch:99952  d_loss:0.4529  g_loss:6.0910
# epoch:99953  d_loss:0.2463  g_loss:4.3597
# epoch:99954  d_loss:1.2203  g_loss:4.9366
# epoch:99955  d_loss:0.2956  g_loss:9.3519
# epoch:99956  d_loss:0.5776  g_loss:9.8261
# epoch:99957  d_loss:0.6905  g_loss:8.4868
# epoch:99958  d_loss:0.9295  g_loss:5.3029
# epoch:99959  d_loss:0.1107  g_loss:4.3606
# epoch:99960  d_loss:0.3025  g_loss:6.2156
# epoch:99961  d_loss:0.1394  g_loss:6.0494
# epoch:99962  d_loss:0.1118  g_loss:6.3674
# epoch:99963  d_loss:0.1797  g_loss:10.2486
# epoch:99964  d_loss:0.1427  g_loss:10.3817
# epoch:99965  d_loss:0.3044  g_loss:8.1831
# epoch:99966  d_loss:0.1851  g_loss:6.2268
# epoch:99967  d_loss:0.0574  g_loss:5.7226
# epoch:99968  d_loss:0.2458  g_loss:6.6512
# epoch:99969  d_loss:0.0812  g_loss:9.1632
# epoch:99970  d_loss:0.2136  g_loss:9.2359
# epoch:99971  d_loss:0.0821  g_loss:9.4301
# epoch:99972  d_loss:0.1812  g_loss:9.3035
# epoch:99973  d_loss:0.4181  g_loss:8.3788
# epoch:99974  d_loss:0.6966  g_loss:9.5204
# epoch:99975  d_loss:0.4304  g_loss:6.7357
# epoch:99976  d_loss:0.5083  g_loss:6.7188
# epoch:99977  d_loss:0.6388  g_loss:5.7296
# epoch:99978  d_loss:0.8904  g_loss:5.7760
# epoch:99979  d_loss:0.1263  g_loss:10.1953
# epoch:99980  d_loss:0.1993  g_loss:10.0560
# epoch:99981  d_loss:0.2103  g_loss:7.6391
# epoch:99982  d_loss:0.2689  g_loss:6.0639
# epoch:99983  d_loss:0.6476  g_loss:8.8095
# epoch:99984  d_loss:0.5739  g_loss:9.4272
# epoch:99985  d_loss:0.2769  g_loss:8.8775
# epoch:99986  d_loss:0.4054  g_loss:9.3596
# epoch:99987  d_loss:0.0380  g_loss:8.3946
# epoch:99988  d_loss:0.0660  g_loss:6.6979
# epoch:99989  d_loss:0.2734  g_loss:7.6630
# epoch:99990  d_loss:0.2705  g_loss:8.6351
# epoch:99991  d_loss:0.2798  g_loss:9.5084
# epoch:99992  d_loss:0.0271  g_loss:9.8713
# epoch:99993  d_loss:0.5557  g_loss:8.7390
# epoch:99994  d_loss:0.1039  g_loss:6.9698
# epoch:99995  d_loss:0.2397  g_loss:4.6205
# epoch:99996  d_loss:0.4913  g_loss:4.9052
# epoch:99997  d_loss:0.2493  g_loss:5.5810
# epoch:99998  d_loss:0.0945  g_loss:8.5181
# epoch:99999  d_loss:0.2571  g_loss:9.4092
# epoch:100000  d_loss:0.1506  g_loss:5.0881
# id2 >  5
# (25, 32, 128, 1)
# (128, 862)
# (110208,)
# end
# 작업 시간 :  5:37:59.395317

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan14.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
