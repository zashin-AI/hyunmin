# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 68
y_size = 68
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 80001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 36992)             3736192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 36992)             147968
# _________________________________________________________________
# reshape (Reshape)            (None, 17, 17, 128)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 34, 34, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 34, 34, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 68, 68, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 68, 68, 1)         1601
# =================================================================
# Total params: 4,090,881
# Trainable params: 4,016,769
# Non-trainable params: 74,112
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 34, 34, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 128)       204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36992)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 36993
# =================================================================
# Total params: 243,585
# Trainable params: 0
# Non-trainable params: 243,585
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 68, 68, 1)         4090881
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 243585
# =================================================================
# Total params: 4,334,466
# Trainable params: 4,016,769
# Non-trainable params: 317,697
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (2331, 68, 68)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 68, 68)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.18890941 / -80.0

  scale = MaxAbsScaler()
    #   절대값이 0~1사이에 매핑
    #   -1 ~ 1 사이로 재조정
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4624)
  print(np.max(X_train), np.min(X_train))   # -0.0023613677 -1.0


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 68, 68, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan11.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            idx2 = np.random.randint(0, gen_imgs.shape[0])
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 68, 68, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            print(gen_mels.shape) # (862, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan11\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
            

gan_train(epochs, batch, 100)

end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# 573
# epoch:79543  d_loss:0.3274  g_loss:11.2572
# epoch:79544  d_loss:0.0029  g_loss:12.6903
# epoch:79545  d_loss:0.1973  g_loss:20.8583
# epoch:79546  d_loss:0.1571  g_loss:21.9940
# epoch:79547  d_loss:0.5368  g_loss:18.3805
# epoch:79548  d_loss:0.0002  g_loss:17.5313
# epoch:79549  d_loss:0.0166  g_loss:14.6148
# epoch:79550  d_loss:0.9370  g_loss:17.3447
# epoch:79551  d_loss:0.2711  g_loss:22.4734
# epoch:79552  d_loss:0.6978  g_loss:9.8850
# epoch:79553  d_loss:1.0757  g_loss:12.1990
# epoch:79554  d_loss:0.2914  g_loss:15.6480
# epoch:79555  d_loss:0.1069  g_loss:18.3116
# epoch:79556  d_loss:1.6538  g_loss:11.0382
# epoch:79557  d_loss:0.7611  g_loss:5.0989
# epoch:79558  d_loss:0.2521  g_loss:6.8583
# epoch:79559  d_loss:0.1029  g_loss:11.0097
# epoch:79560  d_loss:0.0005  g_loss:15.6306
# epoch:79561  d_loss:0.0964  g_loss:12.6392
# epoch:79562  d_loss:0.0020  g_loss:15.8165
# epoch:79563  d_loss:0.5127  g_loss:10.9196
# epoch:79564  d_loss:0.6241  g_loss:14.9145
# epoch:79565  d_loss:0.0124  g_loss:18.3949
# epoch:79566  d_loss:2.0040  g_loss:9.4646
# epoch:79567  d_loss:0.3988  g_loss:8.4006
# epoch:79568  d_loss:0.7334  g_loss:10.5545
# epoch:79569  d_loss:0.1419  g_loss:19.9276
# epoch:79570  d_loss:0.3036  g_loss:25.0949
# epoch:79571  d_loss:1.7791  g_loss:12.0705
# epoch:79572  d_loss:0.2922  g_loss:10.1642
# epoch:79573  d_loss:1.0795  g_loss:13.5938
# epoch:79574  d_loss:0.2190  g_loss:19.7767
# epoch:79575  d_loss:0.2996  g_loss:21.8193
# epoch:79576  d_loss:0.0500  g_loss:22.6338
# epoch:79577  d_loss:0.7183  g_loss:18.9274
# epoch:79578  d_loss:0.2051  g_loss:20.9775
# epoch:79579  d_loss:0.1421  g_loss:16.8780
# epoch:79580  d_loss:0.2560  g_loss:17.1208
# epoch:79581  d_loss:0.3528  g_loss:10.9604
# epoch:79582  d_loss:0.0159  g_loss:16.3588
# epoch:79583  d_loss:0.8623  g_loss:10.1316
# epoch:79584  d_loss:0.5337  g_loss:5.5798
# epoch:79585  d_loss:0.1939  g_loss:9.6883
# epoch:79586  d_loss:0.2117  g_loss:12.8484
# epoch:79587  d_loss:0.0062  g_loss:19.6451
# epoch:79588  d_loss:0.4151  g_loss:17.0394
# epoch:79589  d_loss:0.5170  g_loss:10.8869
# epoch:79590  d_loss:0.0338  g_loss:10.3744
# epoch:79591  d_loss:0.3030  g_loss:10.5488
# epoch:79592  d_loss:0.0088  g_loss:13.0262
# epoch:79593  d_loss:0.0101  g_loss:15.3679
# epoch:79594  d_loss:0.0040  g_loss:14.7616
# epoch:79595  d_loss:0.0003  g_loss:18.4207
# epoch:79596  d_loss:0.0073  g_loss:18.9377
# epoch:79597  d_loss:0.2048  g_loss:18.9165
# epoch:79598  d_loss:0.2144  g_loss:14.7683
# epoch:79599  d_loss:0.1114  g_loss:10.6748
# epoch:79600  d_loss:0.2142  g_loss:10.6582
# id2 >  1
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:79601  d_loss:0.3197  g_loss:8.6321
# epoch:79602  d_loss:0.0701  g_loss:11.8904
# epoch:79603  d_loss:0.1711  g_loss:13.7657
# epoch:79604  d_loss:0.0043  g_loss:14.5397
# epoch:79605  d_loss:0.0720  g_loss:14.4423
# epoch:79606  d_loss:0.0014  g_loss:16.4379
# epoch:79607  d_loss:0.0348  g_loss:14.2242
# epoch:79608  d_loss:0.3380  g_loss:13.7301
# epoch:79609  d_loss:0.5109  g_loss:17.8901
# epoch:79610  d_loss:0.3156  g_loss:16.7048
# epoch:79611  d_loss:0.0865  g_loss:16.7910
# epoch:79612  d_loss:0.2199  g_loss:19.9205
# epoch:79613  d_loss:0.6215  g_loss:17.4487
# epoch:79614  d_loss:0.0568  g_loss:18.1950
# epoch:79615  d_loss:0.0198  g_loss:16.4086
# epoch:79616  d_loss:0.0125  g_loss:18.3993
# epoch:79617  d_loss:0.1070  g_loss:16.6086
# epoch:79618  d_loss:0.0721  g_loss:17.1246
# epoch:79619  d_loss:0.0024  g_loss:14.7764
# epoch:79620  d_loss:0.0486  g_loss:19.8035
# epoch:79621  d_loss:0.0115  g_loss:12.2086
# epoch:79622  d_loss:0.1075  g_loss:13.5228
# epoch:79623  d_loss:0.0454  g_loss:12.0596
# epoch:79624  d_loss:0.1482  g_loss:11.9524
# epoch:79625  d_loss:0.3042  g_loss:11.4492
# epoch:79626  d_loss:0.0326  g_loss:13.9741
# epoch:79627  d_loss:0.1822  g_loss:18.6251
# epoch:79628  d_loss:0.0079  g_loss:19.0739
# epoch:79629  d_loss:0.6144  g_loss:9.6795
# epoch:79630  d_loss:0.2555  g_loss:6.6764
# epoch:79631  d_loss:0.0380  g_loss:9.7314
# epoch:79632  d_loss:0.1756  g_loss:14.0396
# epoch:79633  d_loss:0.0005  g_loss:19.7399
# epoch:79634  d_loss:0.0152  g_loss:20.4360
# epoch:79635  d_loss:0.0055  g_loss:21.4017
# epoch:79636  d_loss:0.2849  g_loss:21.3776
# epoch:79637  d_loss:0.1241  g_loss:19.6984
# epoch:79638  d_loss:0.0001  g_loss:16.5212
# epoch:79639  d_loss:0.0134  g_loss:13.2847
# epoch:79640  d_loss:0.4842  g_loss:15.7455
# epoch:79641  d_loss:0.0018  g_loss:20.8880
# epoch:79642  d_loss:0.2409  g_loss:22.4283
# epoch:79643  d_loss:0.1949  g_loss:18.2928
# epoch:79644  d_loss:0.3104  g_loss:16.1305
# epoch:79645  d_loss:0.2200  g_loss:15.3117
# epoch:79646  d_loss:0.4127  g_loss:13.5752
# epoch:79647  d_loss:0.3868  g_loss:12.2525
# epoch:79648  d_loss:0.1372  g_loss:13.0873
# epoch:79649  d_loss:0.0083  g_loss:10.6804
# epoch:79650  d_loss:0.6693  g_loss:14.5304
# epoch:79651  d_loss:0.2676  g_loss:18.5977
# epoch:79652  d_loss:0.1265  g_loss:22.4376
# epoch:79653  d_loss:0.2897  g_loss:23.0870
# epoch:79654  d_loss:0.6194  g_loss:20.1051
# epoch:79655  d_loss:0.0116  g_loss:25.6578
# epoch:79656  d_loss:0.0114  g_loss:22.3430
# epoch:79657  d_loss:0.0042  g_loss:23.8515
# epoch:79658  d_loss:0.0210  g_loss:28.4277
# epoch:79659  d_loss:0.0057  g_loss:19.5043
# epoch:79660  d_loss:0.2441  g_loss:19.8317
# epoch:79661  d_loss:1.5163  g_loss:5.5603
# epoch:79662  d_loss:3.2572  g_loss:8.9069
# epoch:79663  d_loss:0.0012  g_loss:21.2383
# epoch:79664  d_loss:0.9074  g_loss:22.3788
# epoch:79665  d_loss:1.5130  g_loss:11.4462
# epoch:79666  d_loss:0.1656  g_loss:8.1701
# epoch:79667  d_loss:0.0198  g_loss:4.3836
# epoch:79668  d_loss:1.1459  g_loss:20.0738
# epoch:79669  d_loss:0.0021  g_loss:48.1333
# epoch:79670  d_loss:8.9786  g_loss:2.3133
# epoch:79671  d_loss:5.1484  g_loss:7.7007
# epoch:79672  d_loss:0.0489  g_loss:28.0094
# epoch:79673  d_loss:0.3117  g_loss:52.0595
# epoch:79674  d_loss:2.4790  g_loss:28.5489
# epoch:79675  d_loss:0.2107  g_loss:18.0208
# epoch:79676  d_loss:0.0349  g_loss:11.9579
# epoch:79677  d_loss:0.5363  g_loss:17.0929
# epoch:79678  d_loss:0.1210  g_loss:25.3315
# epoch:79679  d_loss:0.0172  g_loss:41.8991
# epoch:79680  d_loss:3.2748  g_loss:9.1144
# epoch:79681  d_loss:2.4327  g_loss:15.8322
# epoch:79682  d_loss:0.2658  g_loss:35.4880
# epoch:79683  d_loss:1.8151  g_loss:12.7115
# epoch:79684  d_loss:3.0046  g_loss:12.1086
# epoch:79685  d_loss:0.3450  g_loss:20.9254
# epoch:79686  d_loss:2.7762  g_loss:17.2417
# epoch:79687  d_loss:2.9934  g_loss:11.1438
# epoch:79688  d_loss:5.9076  g_loss:11.3004
# epoch:79689  d_loss:3.6588  g_loss:17.2371
# epoch:79690  d_loss:2.3826  g_loss:18.3186
# epoch:79691  d_loss:0.6617  g_loss:33.1930
# epoch:79692  d_loss:0.6285  g_loss:26.6517
# epoch:79693  d_loss:0.5513  g_loss:37.1225
# epoch:79694  d_loss:0.9379  g_loss:61.8422
# epoch:79695  d_loss:0.0671  g_loss:84.0579
# epoch:79696  d_loss:0.2681  g_loss:66.4740
# epoch:79697  d_loss:0.0000  g_loss:48.4261
# epoch:79698  d_loss:1.6085  g_loss:58.3914
# epoch:79699  d_loss:0.0000  g_loss:66.9314
# epoch:79700  d_loss:1.3071  g_loss:47.1566
# id2 >  8
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:79701  d_loss:0.3848  g_loss:26.7056
# epoch:79702  d_loss:2.2543  g_loss:16.0599
# epoch:79703  d_loss:3.7393  g_loss:24.8786
# epoch:79704  d_loss:5.8563  g_loss:22.0736
# epoch:79705  d_loss:1.1263  g_loss:25.0563
# epoch:79706  d_loss:2.6839  g_loss:32.7945
# epoch:79707  d_loss:0.0107  g_loss:41.6322
# epoch:79708  d_loss:0.2484  g_loss:52.7052
# epoch:79709  d_loss:0.0062  g_loss:50.6946
# epoch:79710  d_loss:0.0000  g_loss:42.4832
# epoch:79711  d_loss:0.3732  g_loss:30.2912
# epoch:79712  d_loss:3.8346  g_loss:45.7378
# epoch:79713  d_loss:0.6229  g_loss:69.0911
# epoch:79714  d_loss:6.1977  g_loss:1.4906
# epoch:79715  d_loss:8.5666  g_loss:5.9583
# epoch:79716  d_loss:0.0000  g_loss:40.7493
# epoch:79717  d_loss:0.7284  g_loss:58.8920
# epoch:79718  d_loss:1.1544  g_loss:56.0292
# epoch:79719  d_loss:1.9801  g_loss:34.2845
# epoch:79720  d_loss:0.0000  g_loss:19.9161
# epoch:79721  d_loss:0.2423  g_loss:9.6868
# epoch:79722  d_loss:1.8614  g_loss:19.5816
# epoch:79723  d_loss:0.0000  g_loss:31.0559
# epoch:79724  d_loss:0.0000  g_loss:43.6374
# epoch:79725  d_loss:0.1012  g_loss:47.8513
# epoch:79726  d_loss:0.3656  g_loss:39.6290
# epoch:79727  d_loss:0.0000  g_loss:39.0051
# epoch:79728  d_loss:0.1416  g_loss:36.6090
# epoch:79729  d_loss:0.0001  g_loss:31.9334
# epoch:79730  d_loss:0.0001  g_loss:25.6057
# epoch:79731  d_loss:0.1037  g_loss:20.5398
# epoch:79732  d_loss:0.1709  g_loss:16.9414
# epoch:79733  d_loss:0.3645  g_loss:15.7892
# epoch:79734  d_loss:0.0008  g_loss:20.1150
# epoch:79735  d_loss:0.2570  g_loss:24.1428
# epoch:79736  d_loss:0.4049  g_loss:21.0315
# epoch:79737  d_loss:0.4255  g_loss:29.2245
# epoch:79738  d_loss:1.7438  g_loss:22.1804
# epoch:79739  d_loss:0.8594  g_loss:16.5005
# epoch:79740  d_loss:1.1730  g_loss:15.8677
# epoch:79741  d_loss:3.4520  g_loss:22.3701
# epoch:79742  d_loss:2.4222  g_loss:20.4282
# epoch:79743  d_loss:7.2880  g_loss:19.1397
# epoch:79744  d_loss:2.0502  g_loss:38.5941
# epoch:79745  d_loss:3.4728  g_loss:46.4704
# epoch:79746  d_loss:1.0362  g_loss:54.9017
# epoch:79747  d_loss:0.0146  g_loss:59.5077
# epoch:79748  d_loss:0.2257  g_loss:65.7250
# epoch:79749  d_loss:0.0000  g_loss:65.5556
# epoch:79750  d_loss:0.0249  g_loss:64.2167
# epoch:79751  d_loss:0.6517  g_loss:56.9445
# epoch:79752  d_loss:0.0000  g_loss:52.1951
# epoch:79753  d_loss:1.4971  g_loss:39.2037
# epoch:79754  d_loss:0.6528  g_loss:45.7891
# epoch:79755  d_loss:0.0734  g_loss:48.8964
# epoch:79756  d_loss:0.2956  g_loss:31.2026
# epoch:79757  d_loss:0.1177  g_loss:28.1470
# epoch:79758  d_loss:0.5380  g_loss:23.8415
# epoch:79759  d_loss:0.1172  g_loss:23.2544
# epoch:79760  d_loss:0.7600  g_loss:20.9255
# epoch:79761  d_loss:0.7505  g_loss:26.5403
# epoch:79762  d_loss:1.4177  g_loss:15.3778
# epoch:79763  d_loss:0.0662  g_loss:10.4586
# epoch:79764  d_loss:0.3501  g_loss:13.9223
# epoch:79765  d_loss:0.0700  g_loss:13.5435
# epoch:79766  d_loss:0.0050  g_loss:11.0405
# epoch:79767  d_loss:0.0011  g_loss:16.3521
# epoch:79768  d_loss:0.1591  g_loss:15.3365
# epoch:79769  d_loss:0.3901  g_loss:9.3528
# epoch:79770  d_loss:0.2525  g_loss:12.0776
# epoch:79771  d_loss:0.3012  g_loss:12.5187
# epoch:79772  d_loss:0.0185  g_loss:18.6315
# epoch:79773  d_loss:0.2514  g_loss:21.4136
# epoch:79774  d_loss:0.0142  g_loss:21.3652
# epoch:79775  d_loss:0.0020  g_loss:18.3267
# epoch:79776  d_loss:0.1039  g_loss:17.9901
# epoch:79777  d_loss:0.0001  g_loss:17.1681
# epoch:79778  d_loss:0.1174  g_loss:17.6810
# epoch:79779  d_loss:0.0025  g_loss:17.2678
# epoch:79780  d_loss:0.0294  g_loss:15.3696
# epoch:79781  d_loss:0.1290  g_loss:15.3607
# epoch:79782  d_loss:0.0014  g_loss:17.8870
# epoch:79783  d_loss:0.2098  g_loss:16.7583
# epoch:79784  d_loss:0.0084  g_loss:14.9704
# epoch:79785  d_loss:0.2407  g_loss:19.0705
# epoch:79786  d_loss:0.1018  g_loss:20.1833
# epoch:79787  d_loss:0.1279  g_loss:24.8748
# epoch:79788  d_loss:0.4607  g_loss:26.0134
# epoch:79789  d_loss:0.0031  g_loss:23.3762
# epoch:79790  d_loss:0.2695  g_loss:16.1295
# epoch:79791  d_loss:1.0407  g_loss:16.7314
# epoch:79792  d_loss:0.4206  g_loss:24.3383
# epoch:79793  d_loss:1.0333  g_loss:17.0256
# epoch:79794  d_loss:1.0080  g_loss:31.6707
# epoch:79795  d_loss:1.1657  g_loss:38.6592
# epoch:79796  d_loss:0.0134  g_loss:45.7408
# epoch:79797  d_loss:0.0487  g_loss:42.6128
# epoch:79798  d_loss:0.3776  g_loss:45.1723
# epoch:79799  d_loss:1.4395  g_loss:36.5336
# epoch:79800  d_loss:1.0698  g_loss:22.9492
# id2 >  22
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:79801  d_loss:0.1786  g_loss:29.2639
# epoch:79802  d_loss:0.0700  g_loss:19.2928
# epoch:79803  d_loss:1.3606  g_loss:28.5053
# epoch:79804  d_loss:0.0030  g_loss:39.9041
# epoch:79805  d_loss:0.0000  g_loss:41.3678
# epoch:79806  d_loss:1.0582  g_loss:24.9672
# epoch:79807  d_loss:0.8931  g_loss:15.8099
# epoch:79808  d_loss:0.0000  g_loss:16.8332
# epoch:79809  d_loss:0.0004  g_loss:13.7073
# epoch:79810  d_loss:0.1148  g_loss:17.7317
# epoch:79811  d_loss:0.2457  g_loss:16.5221
# epoch:79812  d_loss:0.0388  g_loss:25.3438
# epoch:79813  d_loss:0.0211  g_loss:20.4107
# epoch:79814  d_loss:0.0003  g_loss:21.7111
# epoch:79815  d_loss:0.3221  g_loss:20.5721
# epoch:79816  d_loss:0.0147  g_loss:18.4573
# epoch:79817  d_loss:0.0194  g_loss:18.2030
# epoch:79818  d_loss:0.0158  g_loss:17.4575
# epoch:79819  d_loss:0.5075  g_loss:16.4939
# epoch:79820  d_loss:0.1836  g_loss:18.3783
# epoch:79821  d_loss:0.5943  g_loss:20.0341
# epoch:79822  d_loss:0.6800  g_loss:27.7465
# epoch:79823  d_loss:0.3720  g_loss:29.1165
# epoch:79824  d_loss:0.6756  g_loss:21.0591
# epoch:79825  d_loss:0.0055  g_loss:17.4346
# epoch:79826  d_loss:0.4890  g_loss:18.3239
# epoch:79827  d_loss:0.9784  g_loss:20.3848
# epoch:79828  d_loss:0.0000  g_loss:22.6156
# epoch:79829  d_loss:0.0048  g_loss:28.0398
# epoch:79830  d_loss:1.2915  g_loss:22.9639
# epoch:79831  d_loss:0.3602  g_loss:13.7801
# epoch:79832  d_loss:0.4961  g_loss:24.0499
# epoch:79833  d_loss:0.4585  g_loss:21.6193
# epoch:79834  d_loss:0.1093  g_loss:22.1715
# epoch:79835  d_loss:0.2486  g_loss:23.5126
# epoch:79836  d_loss:0.7944  g_loss:24.2888
# epoch:79837  d_loss:0.0006  g_loss:18.2650
# epoch:79838  d_loss:0.4222  g_loss:17.2223
# epoch:79839  d_loss:0.0024  g_loss:18.7856
# epoch:79840  d_loss:0.1791  g_loss:20.5655
# epoch:79841  d_loss:0.2234  g_loss:21.0327
# epoch:79842  d_loss:0.5695  g_loss:20.3638
# epoch:79843  d_loss:0.0890  g_loss:20.3982
# epoch:79844  d_loss:0.0005  g_loss:22.0830
# epoch:79845  d_loss:0.0108  g_loss:18.6315
# epoch:79846  d_loss:0.0499  g_loss:22.4439
# epoch:79847  d_loss:0.2601  g_loss:19.0830
# epoch:79848  d_loss:0.5742  g_loss:24.6413
# epoch:79849  d_loss:0.1214  g_loss:26.5873
# epoch:79850  d_loss:0.5374  g_loss:28.7533
# epoch:79851  d_loss:0.0036  g_loss:22.7892
# epoch:79852  d_loss:0.3740  g_loss:19.3171
# epoch:79853  d_loss:0.7917  g_loss:25.8849
# epoch:79854  d_loss:0.0003  g_loss:39.1089
# epoch:79855  d_loss:0.9347  g_loss:27.1232
# epoch:79856  d_loss:0.6611  g_loss:28.4312
# epoch:79857  d_loss:0.1617  g_loss:24.8374
# epoch:79858  d_loss:0.2352  g_loss:18.4736
# epoch:79859  d_loss:0.0768  g_loss:24.8501
# epoch:79860  d_loss:0.0034  g_loss:25.0576
# epoch:79861  d_loss:0.1148  g_loss:22.7432
# epoch:79862  d_loss:0.1443  g_loss:24.0665
# epoch:79863  d_loss:0.0003  g_loss:34.6571
# epoch:79864  d_loss:0.9288  g_loss:26.2584
# epoch:79865  d_loss:0.5454  g_loss:17.4395
# epoch:79866  d_loss:0.9301  g_loss:17.9504
# epoch:79867  d_loss:0.0784  g_loss:22.0767
# epoch:79868  d_loss:0.0063  g_loss:27.4064
# epoch:79869  d_loss:0.0721  g_loss:27.2533
# epoch:79870  d_loss:0.0002  g_loss:29.7906
# epoch:79871  d_loss:0.0046  g_loss:28.1415
# epoch:79872  d_loss:0.7233  g_loss:20.1228
# epoch:79873  d_loss:0.0065  g_loss:17.5576
# epoch:79874  d_loss:0.0646  g_loss:13.2846
# epoch:79875  d_loss:0.0037  g_loss:11.2397
# epoch:79876  d_loss:0.0045  g_loss:11.5315
# epoch:79877  d_loss:0.0411  g_loss:8.0579
# epoch:79878  d_loss:0.0240  g_loss:13.4396
# epoch:79879  d_loss:0.2220  g_loss:9.4833
# epoch:79880  d_loss:0.1279  g_loss:11.9445
# epoch:79881  d_loss:0.1243  g_loss:10.4869
# epoch:79882  d_loss:0.0026  g_loss:10.9763
# epoch:79883  d_loss:0.0004  g_loss:10.7137
# epoch:79884  d_loss:0.0191  g_loss:11.6363
# epoch:79885  d_loss:0.0468  g_loss:11.8019
# epoch:79886  d_loss:0.0068  g_loss:13.4427
# epoch:79887  d_loss:0.0057  g_loss:12.9281
# epoch:79888  d_loss:0.0063  g_loss:13.3311
# epoch:79889  d_loss:0.0008  g_loss:15.6995
# epoch:79890  d_loss:0.0001  g_loss:13.5136
# epoch:79891  d_loss:0.0028  g_loss:14.3183
# epoch:79892  d_loss:0.0016  g_loss:14.6158
# epoch:79893  d_loss:0.1658  g_loss:13.3898
# epoch:79894  d_loss:0.0093  g_loss:14.2172
# epoch:79895  d_loss:0.0026  g_loss:10.1318
# epoch:79896  d_loss:0.0224  g_loss:12.2781
# epoch:79897  d_loss:0.0021  g_loss:8.4965
# epoch:79898  d_loss:0.3032  g_loss:11.0377
# epoch:79899  d_loss:0.0789  g_loss:12.9346
# epoch:79900  d_loss:0.1173  g_loss:14.4739
# id2 >  18
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:79901  d_loss:0.0124  g_loss:17.4267
# epoch:79902  d_loss:0.1092  g_loss:16.1222
# epoch:79903  d_loss:0.0058  g_loss:18.7522
# epoch:79904  d_loss:0.5638  g_loss:16.4386
# epoch:79905  d_loss:0.0132  g_loss:16.5750
# epoch:79906  d_loss:0.0027  g_loss:13.3105
# epoch:79907  d_loss:0.1672  g_loss:9.6507
# epoch:79908  d_loss:0.5186  g_loss:13.6612
# epoch:79909  d_loss:0.2952  g_loss:16.9681
# epoch:79910  d_loss:0.2525  g_loss:18.0115
# epoch:79911  d_loss:0.0049  g_loss:23.5070
# epoch:79912  d_loss:0.4567  g_loss:22.9631
# epoch:79913  d_loss:0.0264  g_loss:25.2751
# epoch:79914  d_loss:0.5729  g_loss:19.4601
# epoch:79915  d_loss:0.0921  g_loss:18.8645
# epoch:79916  d_loss:0.1879  g_loss:15.1428
# epoch:79917  d_loss:0.0151  g_loss:24.9727
# epoch:79918  d_loss:0.0950  g_loss:22.3945
# epoch:79919  d_loss:0.1825  g_loss:20.6868
# epoch:79920  d_loss:0.0005  g_loss:17.2431
# epoch:79921  d_loss:0.0001  g_loss:17.1710
# epoch:79922  d_loss:0.0007  g_loss:21.7494
# epoch:79923  d_loss:0.1029  g_loss:20.3031
# epoch:79924  d_loss:0.0495  g_loss:16.6017
# epoch:79925  d_loss:0.6957  g_loss:11.7310
# epoch:79926  d_loss:0.0013  g_loss:14.4071
# epoch:79927  d_loss:0.0192  g_loss:16.5333
# epoch:79928  d_loss:0.0017  g_loss:15.9610
# epoch:79929  d_loss:0.0235  g_loss:14.8865
# epoch:79930  d_loss:0.1445  g_loss:14.0455
# epoch:79931  d_loss:0.0045  g_loss:10.4295
# epoch:79932  d_loss:0.0231  g_loss:11.2376
# epoch:79933  d_loss:0.0090  g_loss:11.0880
# epoch:79934  d_loss:0.0293  g_loss:13.7416
# epoch:79935  d_loss:0.0002  g_loss:11.5742
# epoch:79936  d_loss:0.0018  g_loss:12.6468
# epoch:79937  d_loss:0.0018  g_loss:14.2442
# epoch:79938  d_loss:0.0002  g_loss:12.4978
# epoch:79939  d_loss:0.0002  g_loss:13.1428
# epoch:79940  d_loss:0.0034  g_loss:14.2256
# epoch:79941  d_loss:0.0035  g_loss:13.4639
# epoch:79942  d_loss:0.0000  g_loss:12.9087
# epoch:79943  d_loss:0.0434  g_loss:12.5905
# epoch:79944  d_loss:0.0255  g_loss:12.2891
# epoch:79945  d_loss:0.1666  g_loss:14.6973
# epoch:79946  d_loss:0.0224  g_loss:12.1754
# epoch:79947  d_loss:0.1097  g_loss:10.9570
# epoch:79948  d_loss:0.0031  g_loss:11.6191
# epoch:79949  d_loss:0.0184  g_loss:14.3993
# epoch:79950  d_loss:0.0021  g_loss:12.6727
# epoch:79951  d_loss:0.0003  g_loss:13.1961
# epoch:79952  d_loss:0.1679  g_loss:14.2258
# epoch:79953  d_loss:0.2912  g_loss:13.8875
# epoch:79954  d_loss:0.2220  g_loss:13.0293
# epoch:79955  d_loss:0.2379  g_loss:15.1554
# epoch:79956  d_loss:0.2021  g_loss:11.1551
# epoch:79957  d_loss:0.0136  g_loss:11.7877
# epoch:79958  d_loss:0.0606  g_loss:11.6996
# epoch:79959  d_loss:0.0138  g_loss:14.3813
# epoch:79960  d_loss:0.0005  g_loss:15.7411
# epoch:79961  d_loss:0.1294  g_loss:17.3448
# epoch:79962  d_loss:0.3068  g_loss:17.2817
# epoch:79963  d_loss:0.0896  g_loss:17.4865
# epoch:79964  d_loss:0.6643  g_loss:17.3339
# epoch:79965  d_loss:0.3249  g_loss:10.0570
# epoch:79966  d_loss:0.5457  g_loss:15.7543
# epoch:79967  d_loss:0.0820  g_loss:20.4410
# epoch:79968  d_loss:0.3276  g_loss:24.8287
# epoch:79969  d_loss:0.6261  g_loss:18.9689
# epoch:79970  d_loss:0.1424  g_loss:13.9829
# epoch:79971  d_loss:0.1325  g_loss:15.4610
# epoch:79972  d_loss:0.1129  g_loss:17.3070
# epoch:79973  d_loss:0.6359  g_loss:26.7927
# epoch:79974  d_loss:0.5346  g_loss:26.6278
# epoch:79975  d_loss:0.9151  g_loss:15.8670
# epoch:79976  d_loss:0.4713  g_loss:12.2578
# epoch:79977  d_loss:0.0176  g_loss:10.4026
# epoch:79978  d_loss:0.6147  g_loss:18.9910
# epoch:79979  d_loss:0.1885  g_loss:21.1708
# epoch:79980  d_loss:0.1583  g_loss:23.9142
# epoch:79981  d_loss:0.4557  g_loss:18.5074
# epoch:79982  d_loss:0.1959  g_loss:11.7365
# epoch:79983  d_loss:0.2512  g_loss:8.3326
# epoch:79984  d_loss:0.5484  g_loss:9.4477
# epoch:79985  d_loss:0.1777  g_loss:13.5661
# epoch:79986  d_loss:0.1660  g_loss:14.8108
# epoch:79987  d_loss:0.4225  g_loss:15.4060
# epoch:79988  d_loss:0.1664  g_loss:15.6409
# epoch:79989  d_loss:0.0978  g_loss:12.9024
# epoch:79990  d_loss:0.2108  g_loss:10.0677
# epoch:79991  d_loss:0.8691  g_loss:11.7684
# epoch:79992  d_loss:0.0569  g_loss:16.7466
# epoch:79993  d_loss:0.0900  g_loss:21.1189
# epoch:79994  d_loss:0.6827  g_loss:18.9899
# epoch:79995  d_loss:0.1945  g_loss:21.1771
# epoch:79996  d_loss:0.5195  g_loss:11.9352
# epoch:79997  d_loss:0.0690  g_loss:10.7026
# epoch:79998  d_loss:0.5200  g_loss:6.6098
# epoch:79999  d_loss:0.4776  g_loss:8.7191
# epoch:80000  d_loss:0.2487  g_loss:14.1284
# id2 >  17
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# 작업 시간 :  5:45:55.450840

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan11.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
