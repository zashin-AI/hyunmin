# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 68
y_size = 68
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 40001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='relu'))
generator.summary()
# Out:
# Model: "sequential_4"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_4 (Dense)              (None, 36992)             3736192
# _________________________________________________________________
# batch_normalization_4 (Batch (None, 36992)             147968
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 17, 17, 128)       0
# _________________________________________________________________
# up_sampling2d_4 (UpSampling2 (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d_8 (Conv2D)            (None, 34, 34, 64)        204864
# _________________________________________________________________
# batch_normalization_5 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation_6 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# up_sampling2d_5 (UpSampling2 (None, 68, 68, 64)        0
# _________________________________________________________________
# conv2d_9 (Conv2D)            (None, 68, 68, 1)         1601
# =================================================================
# Total params: 4,090,881
# Trainable params: 4,016,769
# Non-trainable params: 74,112
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_5"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_10 (Conv2D)           (None, 34, 34, 64)        1664
# _________________________________________________________________
# activation_7 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# dropout_4 (Dropout)          (None, 34, 34, 64)        0
# _________________________________________________________________
# conv2d_11 (Conv2D)           (None, 17, 17, 128)       204928
# _________________________________________________________________
# activation_8 (Activation)    (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_5 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 36993
# =================================================================
# Total params: 243,585
# Trainable params: 0
# Non-trainable params: 243,585
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_3 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential_4 (Sequential)    (None, 68, 68, 1)         4090881
# _________________________________________________________________
# sequential_5 (Sequential)    (None, 1)                 243585
# =================================================================
# Total params: 4,334,466
# Trainable params: 4,016,769
# Non-trainable params: 317,697
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (2331, 68, 68)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 68, 68)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.18890941 / -80.0

    #   scale = MaxAbsScaler()  
  scale = MinMaxScaler()
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4624)
  print(np.max(X_train), np.min(X_train))   # 1.0000001 0.0


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 68, 68, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan07.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            idx2 = np.random.randint(0, gen_imgs.shape[0])
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 68, 68, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            print(gen_mels.shape) # (862, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan07\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
            

gan_train(epochs, batch, 100)

end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# 34  d_loss:0.1826  g_loss:13.7462
# epoch:39535  d_loss:0.3064  g_loss:12.5619
# epoch:39536  d_loss:0.1299  g_loss:14.2099
# epoch:39537  d_loss:0.1152  g_loss:10.0071
# epoch:39538  d_loss:0.1435  g_loss:6.7593
# epoch:39539  d_loss:0.6356  g_loss:3.9640
# epoch:39540  d_loss:0.5198  g_loss:6.9805
# epoch:39541  d_loss:0.0831  g_loss:8.6587
# epoch:39542  d_loss:0.0463  g_loss:9.5186
# epoch:39543  d_loss:0.0058  g_loss:11.8129
# epoch:39544  d_loss:0.2676  g_loss:9.4355
# epoch:39545  d_loss:0.8283  g_loss:6.5604
# epoch:39546  d_loss:0.3154  g_loss:6.7543
# epoch:39547  d_loss:0.2812  g_loss:5.7148
# epoch:39548  d_loss:0.0472  g_loss:5.8174
# epoch:39549  d_loss:0.2898  g_loss:5.4402
# epoch:39550  d_loss:0.0277  g_loss:7.2111
# epoch:39551  d_loss:0.0277  g_loss:8.9254
# epoch:39552  d_loss:0.1783  g_loss:8.5407
# epoch:39553  d_loss:0.1708  g_loss:9.1634
# epoch:39554  d_loss:0.1295  g_loss:9.1766
# epoch:39555  d_loss:0.5269  g_loss:9.6852
# epoch:39556  d_loss:0.0945  g_loss:8.0370
# epoch:39557  d_loss:0.2151  g_loss:9.4304
# epoch:39558  d_loss:0.2387  g_loss:7.1744
# epoch:39559  d_loss:0.1257  g_loss:8.5017
# epoch:39560  d_loss:0.1025  g_loss:9.4275
# epoch:39561  d_loss:0.4218  g_loss:7.1092
# epoch:39562  d_loss:0.5927  g_loss:7.1153
# epoch:39563  d_loss:0.0237  g_loss:7.0378
# epoch:39564  d_loss:0.0945  g_loss:8.0257
# epoch:39565  d_loss:0.0314  g_loss:7.7235
# epoch:39566  d_loss:0.1862  g_loss:7.0540
# epoch:39567  d_loss:0.3634  g_loss:8.4345
# epoch:39568  d_loss:0.2258  g_loss:9.5219
# epoch:39569  d_loss:0.1687  g_loss:9.4221
# epoch:39570  d_loss:0.0153  g_loss:8.0646
# epoch:39571  d_loss:0.0113  g_loss:9.5044
# epoch:39572  d_loss:0.3153  g_loss:9.0305
# epoch:39573  d_loss:0.3648  g_loss:9.4448
# epoch:39574  d_loss:0.3542  g_loss:9.4756
# epoch:39575  d_loss:0.1170  g_loss:8.6264
# epoch:39576  d_loss:0.1651  g_loss:7.2578
# epoch:39577  d_loss:0.1401  g_loss:6.5456
# epoch:39578  d_loss:0.3085  g_loss:5.7643
# epoch:39579  d_loss:0.3516  g_loss:6.6193
# epoch:39580  d_loss:0.1929  g_loss:4.3026
# epoch:39581  d_loss:0.1611  g_loss:5.7943
# epoch:39582  d_loss:0.2387  g_loss:7.1651
# epoch:39583  d_loss:0.5508  g_loss:8.2875
# epoch:39584  d_loss:0.0741  g_loss:11.2885
# epoch:39585  d_loss:0.0962  g_loss:13.4137
# epoch:39586  d_loss:0.4672  g_loss:8.5090
# epoch:39587  d_loss:0.3283  g_loss:6.3980
# epoch:39588  d_loss:0.3327  g_loss:5.9329
# epoch:39589  d_loss:0.3514  g_loss:4.3278
# epoch:39590  d_loss:0.3301  g_loss:8.2733
# epoch:39591  d_loss:0.2255  g_loss:11.9207
# epoch:39592  d_loss:0.0769  g_loss:11.4074
# epoch:39593  d_loss:0.2016  g_loss:9.2218
# epoch:39594  d_loss:0.0150  g_loss:9.4862
# epoch:39595  d_loss:0.1873  g_loss:8.6781
# epoch:39596  d_loss:0.4148  g_loss:8.1404
# epoch:39597  d_loss:0.2782  g_loss:6.1085
# epoch:39598  d_loss:0.5027  g_loss:5.4565
# epoch:39599  d_loss:0.6818  g_loss:7.9907
# epoch:39600  d_loss:0.3858  g_loss:12.6748
# id2 >  10
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39601  d_loss:0.5114  g_loss:12.5468
# epoch:39602  d_loss:0.9391  g_loss:6.8457
# epoch:39603  d_loss:0.6541  g_loss:3.0180
# epoch:39604  d_loss:0.6067  g_loss:5.8044
# epoch:39605  d_loss:0.0284  g_loss:9.7905
# epoch:39606  d_loss:0.4813  g_loss:10.7751
# epoch:39607  d_loss:0.5241  g_loss:8.1108
# epoch:39608  d_loss:0.4872  g_loss:5.6928
# epoch:39609  d_loss:0.2956  g_loss:5.2566
# epoch:39610  d_loss:0.8794  g_loss:4.9645
# epoch:39611  d_loss:0.1180  g_loss:8.7694
# epoch:39612  d_loss:0.3438  g_loss:6.6148
# epoch:39613  d_loss:0.2218  g_loss:6.5809
# epoch:39614  d_loss:0.6258  g_loss:7.3230
# epoch:39615  d_loss:0.3398  g_loss:7.7378
# epoch:39616  d_loss:0.6533  g_loss:5.8142
# epoch:39617  d_loss:0.4670  g_loss:6.5562
# epoch:39618  d_loss:0.1883  g_loss:6.0971
# epoch:39619  d_loss:0.1302  g_loss:5.8551
# epoch:39620  d_loss:0.0253  g_loss:6.5773
# epoch:39621  d_loss:0.0454  g_loss:6.9866
# epoch:39622  d_loss:0.1944  g_loss:8.0859
# epoch:39623  d_loss:0.2421  g_loss:8.7298
# epoch:39624  d_loss:0.1561  g_loss:7.4100
# epoch:39625  d_loss:0.5006  g_loss:6.1178
# epoch:39626  d_loss:0.1308  g_loss:6.9653
# epoch:39627  d_loss:0.0603  g_loss:8.3451
# epoch:39628  d_loss:0.0280  g_loss:9.2873
# epoch:39629  d_loss:0.1953  g_loss:9.0335
# epoch:39630  d_loss:0.1458  g_loss:8.6058
# epoch:39631  d_loss:0.1745  g_loss:5.9943
# epoch:39632  d_loss:0.0316  g_loss:6.3502
# epoch:39633  d_loss:0.1028  g_loss:5.8213
# epoch:39634  d_loss:0.0337  g_loss:7.4253
# epoch:39635  d_loss:0.1161  g_loss:8.0607
# epoch:39636  d_loss:0.0686  g_loss:6.9230
# epoch:39637  d_loss:0.0588  g_loss:6.2042
# epoch:39638  d_loss:0.1012  g_loss:5.9064
# epoch:39639  d_loss:0.0728  g_loss:8.7727
# epoch:39640  d_loss:0.1294  g_loss:8.3787
# epoch:39641  d_loss:0.7732  g_loss:6.7372
# epoch:39642  d_loss:0.0844  g_loss:6.4545
# epoch:39643  d_loss:0.1324  g_loss:5.5148
# epoch:39644  d_loss:0.0680  g_loss:4.6598
# epoch:39645  d_loss:0.0191  g_loss:5.7467
# epoch:39646  d_loss:0.0710  g_loss:6.0624
# epoch:39647  d_loss:0.1679  g_loss:7.8833
# epoch:39648  d_loss:0.0118  g_loss:10.2164
# epoch:39649  d_loss:0.0926  g_loss:9.5578
# epoch:39650  d_loss:0.5229  g_loss:9.0864
# epoch:39651  d_loss:0.0322  g_loss:10.3190
# epoch:39652  d_loss:0.6207  g_loss:8.5751
# epoch:39653  d_loss:0.5131  g_loss:8.1592
# epoch:39654  d_loss:0.1259  g_loss:6.5855
# epoch:39655  d_loss:0.4676  g_loss:5.2616
# epoch:39656  d_loss:0.3506  g_loss:7.2337
# epoch:39657  d_loss:0.5140  g_loss:10.2633
# epoch:39658  d_loss:0.2382  g_loss:10.9374
# epoch:39659  d_loss:0.3791  g_loss:8.8792
# epoch:39660  d_loss:0.2940  g_loss:8.1920
# epoch:39661  d_loss:0.1257  g_loss:6.7391
# epoch:39662  d_loss:0.0714  g_loss:4.1466
# epoch:39663  d_loss:0.7730  g_loss:5.9099
# epoch:39664  d_loss:0.1837  g_loss:8.1147
# epoch:39665  d_loss:0.1171  g_loss:10.3309
# epoch:39666  d_loss:0.4547  g_loss:10.6097
# epoch:39667  d_loss:0.5281  g_loss:8.6786
# epoch:39668  d_loss:0.3238  g_loss:6.8123
# epoch:39669  d_loss:0.0251  g_loss:10.0512
# epoch:39670  d_loss:0.0054  g_loss:9.2912
# epoch:39671  d_loss:0.2790  g_loss:9.7132
# epoch:39672  d_loss:0.0729  g_loss:10.1692
# epoch:39673  d_loss:0.0395  g_loss:10.6585
# epoch:39674  d_loss:0.2276  g_loss:9.9975
# epoch:39675  d_loss:0.3346  g_loss:9.0496
# epoch:39676  d_loss:0.3957  g_loss:5.9809
# epoch:39677  d_loss:0.1485  g_loss:6.3576
# epoch:39678  d_loss:0.1224  g_loss:5.8918
# epoch:39679  d_loss:0.0515  g_loss:8.1828
# epoch:39680  d_loss:0.2825  g_loss:6.8751
# epoch:39681  d_loss:0.1311  g_loss:9.1935
# epoch:39682  d_loss:0.1632  g_loss:7.0326
# epoch:39683  d_loss:0.2180  g_loss:6.1676
# epoch:39684  d_loss:0.0935  g_loss:7.9189
# epoch:39685  d_loss:0.6324  g_loss:5.9733
# epoch:39686  d_loss:0.0113  g_loss:9.3336
# epoch:39687  d_loss:0.3736  g_loss:7.4852
# epoch:39688  d_loss:0.4378  g_loss:7.0299
# epoch:39689  d_loss:0.1984  g_loss:7.3342
# epoch:39690  d_loss:0.2365  g_loss:7.9332
# epoch:39691  d_loss:0.0992  g_loss:6.1965
# epoch:39692  d_loss:0.6237  g_loss:5.3768
# epoch:39693  d_loss:0.4660  g_loss:4.3384
# epoch:39694  d_loss:0.1310  g_loss:6.1535
# epoch:39695  d_loss:0.0954  g_loss:9.9706
# epoch:39696  d_loss:0.1600  g_loss:10.5868
# epoch:39697  d_loss:0.3475  g_loss:8.3748
# epoch:39698  d_loss:0.1477  g_loss:5.3746
# epoch:39699  d_loss:0.1803  g_loss:5.2587
# epoch:39700  d_loss:0.1126  g_loss:4.7342
# id2 >  17
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39701  d_loss:0.1959  g_loss:7.0349
# epoch:39702  d_loss:0.1533  g_loss:10.2081
# epoch:39703  d_loss:0.0743  g_loss:7.6959
# epoch:39704  d_loss:0.0583  g_loss:9.8989
# epoch:39705  d_loss:0.3050  g_loss:10.1605
# epoch:39706  d_loss:0.1370  g_loss:7.0168
# epoch:39707  d_loss:0.4263  g_loss:7.2131
# epoch:39708  d_loss:0.1436  g_loss:5.6526
# epoch:39709  d_loss:0.6934  g_loss:5.5955
# epoch:39710  d_loss:0.2082  g_loss:8.3542
# epoch:39711  d_loss:0.0212  g_loss:12.3188
# epoch:39712  d_loss:1.0187  g_loss:10.1788
# epoch:39713  d_loss:0.4074  g_loss:6.7557
# epoch:39714  d_loss:0.1688  g_loss:5.9847
# epoch:39715  d_loss:0.5393  g_loss:4.3578
# epoch:39716  d_loss:0.1451  g_loss:5.8487
# epoch:39717  d_loss:0.1456  g_loss:7.6882
# epoch:39718  d_loss:0.0253  g_loss:7.7813
# epoch:39719  d_loss:0.0077  g_loss:10.2604
# epoch:39720  d_loss:0.4278  g_loss:9.4251
# epoch:39721  d_loss:0.4960  g_loss:9.0570
# epoch:39722  d_loss:0.1830  g_loss:6.0732
# epoch:39723  d_loss:0.4579  g_loss:4.6079
# epoch:39724  d_loss:0.6690  g_loss:6.4575
# epoch:39725  d_loss:0.0494  g_loss:6.6656
# epoch:39726  d_loss:0.3275  g_loss:7.8513
# epoch:39727  d_loss:0.0859  g_loss:10.8155
# epoch:39728  d_loss:0.2518  g_loss:9.7335
# epoch:39729  d_loss:0.1311  g_loss:8.7966
# epoch:39730  d_loss:0.2481  g_loss:6.1675
# epoch:39731  d_loss:0.1754  g_loss:7.2642
# epoch:39732  d_loss:0.0113  g_loss:6.9640
# epoch:39733  d_loss:0.2641  g_loss:5.2419
# epoch:39734  d_loss:0.5796  g_loss:7.8669
# epoch:39735  d_loss:0.0594  g_loss:9.3960
# epoch:39736  d_loss:0.2689  g_loss:8.3613
# epoch:39737  d_loss:0.1682  g_loss:7.2028
# epoch:39738  d_loss:0.2827  g_loss:8.2696
# epoch:39739  d_loss:0.2501  g_loss:8.4736
# epoch:39740  d_loss:0.3413  g_loss:7.3162
# epoch:39741  d_loss:0.2085  g_loss:8.2669
# epoch:39742  d_loss:0.3887  g_loss:9.2301
# epoch:39743  d_loss:0.1245  g_loss:9.2280
# epoch:39744  d_loss:0.3057  g_loss:7.2625
# epoch:39745  d_loss:0.7900  g_loss:7.2737
# epoch:39746  d_loss:0.2215  g_loss:8.1944
# epoch:39747  d_loss:0.3795  g_loss:10.8507
# epoch:39748  d_loss:0.3424  g_loss:12.2937
# epoch:39749  d_loss:0.2279  g_loss:8.6935
# epoch:39750  d_loss:0.3750  g_loss:8.3267
# epoch:39751  d_loss:0.0593  g_loss:6.0590
# epoch:39752  d_loss:0.1672  g_loss:4.1340
# epoch:39753  d_loss:1.1752  g_loss:4.1563
# epoch:39754  d_loss:0.0703  g_loss:8.7068
# epoch:39755  d_loss:0.0012  g_loss:10.3950
# epoch:39756  d_loss:0.1542  g_loss:10.2577
# epoch:39757  d_loss:0.3092  g_loss:8.6655
# epoch:39758  d_loss:0.1873  g_loss:7.6559
# epoch:39759  d_loss:0.1874  g_loss:8.3868
# epoch:39760  d_loss:0.0403  g_loss:8.6256
# epoch:39761  d_loss:0.1103  g_loss:7.8882
# epoch:39762  d_loss:0.0690  g_loss:7.4303
# epoch:39763  d_loss:0.1285  g_loss:7.8227
# epoch:39764  d_loss:0.0431  g_loss:7.2481
# epoch:39765  d_loss:0.0532  g_loss:9.7973
# epoch:39766  d_loss:0.8171  g_loss:9.8497
# epoch:39767  d_loss:0.9598  g_loss:9.2517
# epoch:39768  d_loss:0.3356  g_loss:8.2518
# epoch:39769  d_loss:0.2392  g_loss:6.1956
# epoch:39770  d_loss:0.1452  g_loss:7.7018
# epoch:39771  d_loss:0.0638  g_loss:7.3809
# epoch:39772  d_loss:0.5382  g_loss:4.5710
# epoch:39773  d_loss:0.2649  g_loss:7.6909
# epoch:39774  d_loss:0.4847  g_loss:10.3597
# epoch:39775  d_loss:0.1669  g_loss:11.1738
# epoch:39776  d_loss:0.0583  g_loss:11.1504
# epoch:39777  d_loss:0.4029  g_loss:11.7195
# epoch:39778  d_loss:0.3098  g_loss:9.9227
# epoch:39779  d_loss:0.2906  g_loss:7.0778
# epoch:39780  d_loss:0.3061  g_loss:9.7938
# epoch:39781  d_loss:0.0388  g_loss:8.8982
# epoch:39782  d_loss:0.1255  g_loss:9.0078
# epoch:39783  d_loss:0.1243  g_loss:8.9858
# epoch:39784  d_loss:0.0726  g_loss:9.3354
# epoch:39785  d_loss:0.0927  g_loss:8.6852
# epoch:39786  d_loss:0.1126  g_loss:9.3557
# epoch:39787  d_loss:0.3520  g_loss:9.3161
# epoch:39788  d_loss:0.0436  g_loss:8.0972
# epoch:39789  d_loss:0.1441  g_loss:6.7798
# epoch:39790  d_loss:0.0937  g_loss:6.5833
# epoch:39791  d_loss:0.6965  g_loss:5.2684
# epoch:39792  d_loss:0.1547  g_loss:9.1065
# epoch:39793  d_loss:0.1013  g_loss:7.5175
# epoch:39794  d_loss:0.5372  g_loss:6.9394
# epoch:39795  d_loss:0.0294  g_loss:8.7394
# epoch:39796  d_loss:0.2729  g_loss:9.9187
# epoch:39797  d_loss:0.4875  g_loss:6.6365
# epoch:39798  d_loss:0.5661  g_loss:4.9367
# epoch:39799  d_loss:0.0737  g_loss:8.9090
# epoch:39800  d_loss:0.5444  g_loss:8.5717
# id2 >  8
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39801  d_loss:0.0093  g_loss:11.1312
# epoch:39802  d_loss:0.3005  g_loss:9.5245
# epoch:39803  d_loss:0.3647  g_loss:8.1427
# epoch:39804  d_loss:0.1310  g_loss:6.1943
# epoch:39805  d_loss:0.5897  g_loss:3.6076
# epoch:39806  d_loss:0.2875  g_loss:3.6988
# epoch:39807  d_loss:0.1784  g_loss:4.7042
# epoch:39808  d_loss:0.8387  g_loss:9.1865
# epoch:39809  d_loss:0.0124  g_loss:13.0017
# epoch:39810  d_loss:0.3656  g_loss:14.8154
# epoch:39811  d_loss:0.2830  g_loss:13.5336
# epoch:39812  d_loss:0.2089  g_loss:10.6966
# epoch:39813  d_loss:0.1605  g_loss:7.7578
# epoch:39814  d_loss:0.0214  g_loss:7.6844
# epoch:39815  d_loss:0.1922  g_loss:7.3773
# epoch:39816  d_loss:0.1545  g_loss:8.2027
# epoch:39817  d_loss:0.0010  g_loss:10.4007
# epoch:39818  d_loss:0.1069  g_loss:9.0477
# epoch:39819  d_loss:0.1515  g_loss:9.5502
# epoch:39820  d_loss:0.1736  g_loss:7.8950
# epoch:39821  d_loss:0.4869  g_loss:9.0076
# epoch:39822  d_loss:0.0360  g_loss:6.0427
# epoch:39823  d_loss:0.4304  g_loss:6.2234
# epoch:39824  d_loss:0.0736  g_loss:7.3130
# epoch:39825  d_loss:0.1633  g_loss:7.2466
# epoch:39826  d_loss:0.2355  g_loss:7.7564
# epoch:39827  d_loss:0.3187  g_loss:9.3267
# epoch:39828  d_loss:0.1625  g_loss:10.1040
# epoch:39829  d_loss:0.1089  g_loss:8.0905
# epoch:39830  d_loss:0.1584  g_loss:6.9214
# epoch:39831  d_loss:0.3529  g_loss:7.2831
# epoch:39832  d_loss:0.0022  g_loss:8.5545
# epoch:39833  d_loss:0.5768  g_loss:11.4508
# epoch:39834  d_loss:0.1603  g_loss:8.9530
# epoch:39835  d_loss:0.1692  g_loss:8.2613
# epoch:39836  d_loss:0.4182  g_loss:6.8929
# epoch:39837  d_loss:0.1350  g_loss:8.4534
# epoch:39838  d_loss:0.3253  g_loss:6.9776
# epoch:39839  d_loss:0.0114  g_loss:8.7678
# epoch:39840  d_loss:0.1894  g_loss:5.7548
# epoch:39841  d_loss:0.1839  g_loss:4.5017
# epoch:39842  d_loss:0.2854  g_loss:7.5493
# epoch:39843  d_loss:0.4905  g_loss:7.2665
# epoch:39844  d_loss:0.0407  g_loss:6.4412
# epoch:39845  d_loss:0.1806  g_loss:7.2345
# epoch:39846  d_loss:0.1367  g_loss:9.5435
# epoch:39847  d_loss:0.3090  g_loss:9.7891
# epoch:39848  d_loss:0.1226  g_loss:5.7623
# epoch:39849  d_loss:0.3846  g_loss:5.7883
# epoch:39850  d_loss:0.1201  g_loss:5.5331
# epoch:39851  d_loss:0.3614  g_loss:6.9756
# epoch:39852  d_loss:0.2122  g_loss:7.5811
# epoch:39853  d_loss:0.1892  g_loss:7.6165
# epoch:39854  d_loss:0.0936  g_loss:7.1776
# epoch:39855  d_loss:0.1893  g_loss:9.8722
# epoch:39856  d_loss:0.1841  g_loss:7.3489
# epoch:39857  d_loss:0.3084  g_loss:6.3718
# epoch:39858  d_loss:0.0919  g_loss:5.2550
# epoch:39859  d_loss:0.0791  g_loss:5.6465
# epoch:39860  d_loss:0.3823  g_loss:5.9187
# epoch:39861  d_loss:0.2955  g_loss:6.7869
# epoch:39862  d_loss:0.0847  g_loss:8.6511
# epoch:39863  d_loss:0.0414  g_loss:9.1927
# epoch:39864  d_loss:0.1807  g_loss:8.9017
# epoch:39865  d_loss:0.0711  g_loss:7.7129
# epoch:39866  d_loss:0.0994  g_loss:8.2665
# epoch:39867  d_loss:0.0686  g_loss:6.8231
# epoch:39868  d_loss:0.0456  g_loss:8.3487
# epoch:39869  d_loss:0.0175  g_loss:7.9568
# epoch:39870  d_loss:0.5560  g_loss:6.9171
# epoch:39871  d_loss:0.1127  g_loss:6.5202
# epoch:39872  d_loss:0.4623  g_loss:4.8462
# epoch:39873  d_loss:0.1973  g_loss:8.8675
# epoch:39874  d_loss:0.1262  g_loss:8.0500
# epoch:39875  d_loss:0.2445  g_loss:9.2913
# epoch:39876  d_loss:0.0295  g_loss:10.1541
# epoch:39877  d_loss:0.1307  g_loss:10.2036
# epoch:39878  d_loss:0.3597  g_loss:7.9100
# epoch:39879  d_loss:0.0561  g_loss:8.4828
# epoch:39880  d_loss:0.1682  g_loss:6.6021
# epoch:39881  d_loss:0.2508  g_loss:4.1634
# epoch:39882  d_loss:0.2662  g_loss:5.0846
# epoch:39883  d_loss:0.2947  g_loss:6.9174
# epoch:39884  d_loss:0.0745  g_loss:8.4682
# epoch:39885  d_loss:0.5626  g_loss:9.9570
# epoch:39886  d_loss:0.4541  g_loss:8.3910
# epoch:39887  d_loss:0.1218  g_loss:5.4013
# epoch:39888  d_loss:0.1573  g_loss:8.8219
# epoch:39889  d_loss:0.1473  g_loss:8.0743
# epoch:39890  d_loss:0.0527  g_loss:8.7989
# epoch:39891  d_loss:0.2818  g_loss:9.6675
# epoch:39892  d_loss:0.3691  g_loss:10.3093
# epoch:39893  d_loss:0.0416  g_loss:10.7706
# epoch:39894  d_loss:0.0574  g_loss:10.9806
# epoch:39895  d_loss:0.0056  g_loss:12.6062
# epoch:39896  d_loss:0.3149  g_loss:13.1635
# epoch:39897  d_loss:0.2449  g_loss:9.9983
# epoch:39898  d_loss:0.1163  g_loss:7.9305
# epoch:39899  d_loss:0.1097  g_loss:7.0713
# epoch:39900  d_loss:0.0851  g_loss:5.0078
# id2 >  16
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39901  d_loss:0.8054  g_loss:5.2900
# epoch:39902  d_loss:0.3041  g_loss:7.4879
# epoch:39903  d_loss:0.2498  g_loss:9.4013
# epoch:39904  d_loss:0.8100  g_loss:7.5335
# epoch:39905  d_loss:0.2623  g_loss:7.0517
# epoch:39906  d_loss:0.2091  g_loss:6.1846
# epoch:39907  d_loss:0.0512  g_loss:5.0352
# epoch:39908  d_loss:0.2111  g_loss:5.0525
# epoch:39909  d_loss:0.2345  g_loss:7.4080
# epoch:39910  d_loss:0.1228  g_loss:7.9665
# epoch:39911  d_loss:0.0585  g_loss:10.1159
# epoch:39912  d_loss:0.2616  g_loss:10.5713
# epoch:39913  d_loss:0.4572  g_loss:5.6349
# epoch:39914  d_loss:0.3254  g_loss:8.2910
# epoch:39915  d_loss:0.2918  g_loss:6.8658
# epoch:39916  d_loss:0.0806  g_loss:5.7087
# epoch:39917  d_loss:0.0980  g_loss:5.4813
# epoch:39918  d_loss:0.3734  g_loss:5.6520
# epoch:39919  d_loss:0.0092  g_loss:6.7868
# epoch:39920  d_loss:0.1491  g_loss:5.9955
# epoch:39921  d_loss:0.1301  g_loss:7.8794
# epoch:39922  d_loss:0.3045  g_loss:10.8339
# epoch:39923  d_loss:0.4968  g_loss:10.3398
# epoch:39924  d_loss:0.2042  g_loss:9.9740
# epoch:39925  d_loss:0.3862  g_loss:9.3953
# epoch:39926  d_loss:0.4298  g_loss:5.9969
# epoch:39927  d_loss:0.1417  g_loss:6.4347
# epoch:39928  d_loss:0.3841  g_loss:4.3506
# epoch:39929  d_loss:0.2213  g_loss:7.0415
# epoch:39930  d_loss:0.2415  g_loss:8.2311
# epoch:39931  d_loss:0.2339  g_loss:10.4360
# epoch:39932  d_loss:0.3746  g_loss:11.1316
# epoch:39933  d_loss:0.3217  g_loss:9.1617
# epoch:39934  d_loss:0.2104  g_loss:5.9187
# epoch:39935  d_loss:0.0316  g_loss:5.8411
# epoch:39936  d_loss:0.0822  g_loss:4.8615
# epoch:39937  d_loss:0.2029  g_loss:4.8573
# epoch:39938  d_loss:0.2280  g_loss:5.1280
# epoch:39939  d_loss:0.2013  g_loss:7.5353
# epoch:39940  d_loss:0.6513  g_loss:8.1359
# epoch:39941  d_loss:0.3166  g_loss:8.0854
# epoch:39942  d_loss:0.3036  g_loss:7.3079
# epoch:39943  d_loss:0.5693  g_loss:4.9753
# epoch:39944  d_loss:0.1191  g_loss:8.3896
# epoch:39945  d_loss:0.9806  g_loss:9.2717
# epoch:39946  d_loss:0.3064  g_loss:8.8568
# epoch:39947  d_loss:0.2036  g_loss:10.3481
# epoch:39948  d_loss:0.1402  g_loss:10.7957
# epoch:39949  d_loss:0.4357  g_loss:9.0777
# epoch:39950  d_loss:0.3144  g_loss:9.5170
# epoch:39951  d_loss:0.1695  g_loss:9.1486
# epoch:39952  d_loss:0.0240  g_loss:10.3987
# epoch:39953  d_loss:0.0098  g_loss:8.7449
# epoch:39954  d_loss:0.1042  g_loss:8.0471
# epoch:39955  d_loss:0.1338  g_loss:6.0297
# epoch:39956  d_loss:0.1762  g_loss:7.2143
# epoch:39957  d_loss:0.4775  g_loss:7.4006
# epoch:39958  d_loss:0.4145  g_loss:8.1159
# epoch:39959  d_loss:0.1016  g_loss:8.2610
# epoch:39960  d_loss:0.2977  g_loss:8.4869
# epoch:39961  d_loss:0.3989  g_loss:6.4783
# epoch:39962  d_loss:0.1610  g_loss:5.7237
# epoch:39963  d_loss:0.0329  g_loss:4.4417
# epoch:39964  d_loss:0.3587  g_loss:6.7211
# epoch:39965  d_loss:0.0596  g_loss:8.1680
# epoch:39966  d_loss:0.2510  g_loss:7.7628
# epoch:39967  d_loss:0.4580  g_loss:10.2960
# epoch:39968  d_loss:0.1594  g_loss:9.2506
# epoch:39969  d_loss:0.1300  g_loss:6.9744
# epoch:39970  d_loss:0.3597  g_loss:7.3423
# epoch:39971  d_loss:0.0943  g_loss:4.4841
# epoch:39972  d_loss:0.5330  g_loss:4.6464
# epoch:39973  d_loss:0.4684  g_loss:6.8485
# epoch:39974  d_loss:0.1785  g_loss:7.7579
# epoch:39975  d_loss:0.1244  g_loss:9.8567
# epoch:39976  d_loss:0.0771  g_loss:10.4690
# epoch:39977  d_loss:0.0417  g_loss:9.3340
# epoch:39978  d_loss:0.2735  g_loss:8.6683
# epoch:39979  d_loss:0.5647  g_loss:6.4614
# epoch:39980  d_loss:0.3133  g_loss:4.9925
# epoch:39981  d_loss:0.5676  g_loss:5.3951
# epoch:39982  d_loss:0.1714  g_loss:8.5528
# epoch:39983  d_loss:0.0374  g_loss:8.2063
# epoch:39984  d_loss:0.0851  g_loss:8.2760
# epoch:39985  d_loss:0.0166  g_loss:9.2146
# epoch:39986  d_loss:0.3915  g_loss:9.0270
# epoch:39987  d_loss:0.3464  g_loss:7.3011
# epoch:39988  d_loss:0.0841  g_loss:7.5981
# epoch:39989  d_loss:0.1408  g_loss:6.0870
# epoch:39990  d_loss:0.2260  g_loss:7.1050
# epoch:39991  d_loss:0.3221  g_loss:6.7313
# epoch:39992  d_loss:0.3087  g_loss:4.6527
# epoch:39993  d_loss:0.4357  g_loss:5.2335
# epoch:39994  d_loss:0.2084  g_loss:6.8064
# epoch:39995  d_loss:0.3009  g_loss:5.7959
# epoch:39996  d_loss:0.0228  g_loss:7.5349
# epoch:39997  d_loss:0.1484  g_loss:8.6701
# epoch:39998  d_loss:0.0395  g_loss:10.7169
# epoch:39999  d_loss:0.5000  g_loss:9.4385
# epoch:40000  d_loss:0.0278  g_loss:7.8586
# id2 >  1
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# 작업 시간 :  2:39:11.644600

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan07.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
