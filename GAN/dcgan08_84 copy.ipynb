# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 50
x_size = 84
y_size = 84
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 40001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='relu'))
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='elu'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 56448)             2878848
# _________________________________________________________________
# batch_normalization (BatchNo (None, 56448)             225792
# _________________________________________________________________
# reshape (Reshape)            (None, 21, 21, 128)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 42, 42, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 42, 42, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 42, 42, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 42, 42, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 84, 84, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 84, 84, 1)         1601
# =================================================================
# Total params: 3,311,361
# Trainable params: 3,198,337
# Non-trainable params: 113,024
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 42, 42, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 42, 42, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 42, 42, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 21, 21, 128)       204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 21, 21, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 21, 21, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 56448)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 56449
# =================================================================
# Total params: 263,041
# Trainable params: 0
# Non-trainable params: 263,041
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 50)]              0
# _________________________________________________________________
# sequential (Sequential)      (None, 84, 84, 1)         3311361
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 263041
# =================================================================
# Total params: 3,574,402
# Trainable params: 3,198,337
# Non-trainable params: 376,065
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (128, 862)
# (84, 84)
# (2331, 84, 84)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 68, 68)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.18890941 / -80.0

  scale = MaxAbsScaler()
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4624)
  print(np.max(X_train), np.min(X_train))   # 48.270073 -1.1008358


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 68, 68, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        # gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan08.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            idx2 = np.random.randint(0, gen_imgs.shape[0])
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 68, 68, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            print(gen_mels.shape) # (862, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            # sf.write(f'E:\\nmb\\gan_image\\dcgan08\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
          

gan_train(epochs, batch, 100)

end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# (2331, 84, 84)
# -0.11894652 -80.0
# (2331, 7056)
# -0.0014868316 -1.0
# (2331, 84, 84, 1)
# epoch:0  d_loss:0.6800  g_loss:0.8130
# id2 >  9
# (25, 84, 84, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:1  d_loss:0.3462  g_loss:0.5894
# epoch:2  d_loss:0.4865  g_loss:3.4643
# epoch:3  d_loss:0.2352  g_loss:8.8854
# epoch:4  d_loss:3.6269  g_loss:0.0000
# epoch:5  d_loss:1.2699  g_loss:0.0000
# epoch:6  d_loss:1.9289  g_loss:0.0390
# epoch:7  d_loss:1.4467  g_loss:0.0000
# epoch:8  d_loss:0.8349  g_loss:0.0000
# epoch:9  d_loss:0.2952  g_loss:0.0000
# epoch:10  d_loss:0.0526  g_loss:0.0179
# epoch:11  d_loss:0.0131  g_loss:2.2718
# epoch:12  d_loss:1.0277  g_loss:0.0084
# epoch:13  d_loss:0.0220  g_loss:0.0000
# epoch:14  d_loss:0.0416  g_loss:0.0000
# epoch:15  d_loss:0.1051  g_loss:0.0000
# epoch:16  d_loss:0.1127  g_loss:0.0000
# epoch:17  d_loss:0.1065  g_loss:0.0000
# epoch:18  d_loss:0.1172  g_loss:0.0000
# epoch:19  d_loss:0.0605  g_loss:0.0000
# epoch:20  d_loss:0.0196  g_loss:0.0000
# epoch:21  d_loss:0.2272  g_loss:0.0000
# epoch:22  d_loss:0.0714  g_loss:0.0000
# epoch:23  d_loss:0.0724  g_loss:0.0000
# epoch:24  d_loss:0.0021  g_loss:0.0001
# epoch:25  d_loss:0.0005  g_loss:0.1678
# epoch:26  d_loss:0.0684  g_loss:0.0001
# epoch:27  d_loss:0.0017  g_loss:0.0000
# epoch:28  d_loss:0.0101  g_loss:0.0000
# epoch:29  d_loss:0.0022  g_loss:0.0000
# epoch:30  d_loss:0.1340  g_loss:0.0000
# epoch:31  d_loss:0.0261  g_loss:0.0000
# epoch:32  d_loss:0.0403  g_loss:0.0000
# epoch:33  d_loss:0.0012  g_loss:0.0000
# epoch:34  d_loss:0.0005  g_loss:0.0007
# epoch:35  d_loss:0.0013  g_loss:0.0211
# epoch:36  d_loss:0.0388  g_loss:0.0003
# epoch:37  d_loss:0.0181  g_loss:0.0001
# epoch:38  d_loss:0.0292  g_loss:0.0000
# epoch:39  d_loss:0.0228  g_loss:0.0003
# epoch:40  d_loss:0.0012  g_loss:0.0047
# epoch:41  d_loss:0.0083  g_loss:0.0771
# epoch:42  d_loss:0.0268  g_loss:0.0002
# epoch:43  d_loss:0.0182  g_loss:0.0000
# epoch:44  d_loss:0.0534  g_loss:0.0002
# epoch:45  d_loss:0.0035  g_loss:0.0316
# epoch:46  d_loss:0.1025  g_loss:0.0000
# epoch:47  d_loss:1.2906  g_loss:0.0007
# epoch:48  d_loss:0.0016  g_loss:16.1463
# epoch:49  d_loss:8.4314  g_loss:0.0002
# epoch:50  d_loss:2.1515  g_loss:0.0000
# epoch:51  d_loss:1.9651  g_loss:0.0002
# epoch:52  d_loss:0.8940  g_loss:0.0740
# epoch:53  d_loss:0.1505  g_loss:2.7627
# epoch:54  d_loss:1.2712  g_loss:1.7688
# epoch:55  d_loss:0.9013  g_loss:0.5428
# epoch:56  d_loss:0.5019  g_loss:0.2098
# epoch:57  d_loss:0.4982  g_loss:0.1546
# epoch:58  d_loss:0.4388  g_loss:0.1769
# epoch:59  d_loss:0.4036  g_loss:0.2490
# epoch:60  d_loss:0.3814  g_loss:0.3487
# epoch:61  d_loss:0.3517  g_loss:0.4164
# epoch:62  d_loss:0.3507  g_loss:0.4065
# epoch:63  d_loss:0.3403  g_loss:0.3175
# epoch:64  d_loss:0.3203  g_loss:0.2466
# epoch:65  d_loss:0.2518  g_loss:0.1843
# epoch:66  d_loss:0.2509  g_loss:0.1682
# epoch:67  d_loss:0.1966  g_loss:0.1777
# epoch:68  d_loss:0.1451  g_loss:0.1982
# epoch:69  d_loss:0.1425  g_loss:0.1637
# epoch:70  d_loss:0.1129  g_loss:0.1246
# epoch:71  d_loss:0.0995  g_loss:0.0916
# epoch:72  d_loss:0.0752  g_loss:0.0804
# epoch:73  d_loss:0.0698  g_loss:0.0784
# epoch:74  d_loss:0.0517  g_loss:0.0884
# epoch:75  d_loss:0.0447  g_loss:0.0759
# epoch:76  d_loss:0.0436  g_loss:0.0509
# epoch:77  d_loss:0.0450  g_loss:0.0433
# epoch:78  d_loss:0.0301  g_loss:0.0412
# epoch:79  d_loss:0.0248  g_loss:0.0414
# epoch:80  d_loss:0.0253  g_loss:0.0417
# epoch:81  d_loss:0.0160  g_loss:0.0287
# epoch:82  d_loss:0.0195  g_loss:0.0229
# epoch:83  d_loss:0.0169  g_loss:0.0125
# epoch:84  d_loss:0.0126  g_loss:0.0152
# epoch:85  d_loss:0.2209  g_loss:0.0087
# epoch:86  d_loss:0.0162  g_loss:0.0109
# epoch:87  d_loss:0.0095  g_loss:0.0208
# epoch:88  d_loss:0.0098  g_loss:0.0221
# epoch:89  d_loss:0.0121  g_loss:0.0299
# epoch:90  d_loss:0.0120  g_loss:0.0170
# epoch:91  d_loss:0.0109  g_loss:0.0112
# epoch:92  d_loss:0.0149  g_loss:0.0113
# epoch:93  d_loss:0.0085  g_loss:0.0123
# epoch:94  d_loss:0.0078  g_loss:0.0187
# epoch:95  d_loss:0.0085  g_loss:0.0202
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-a9f79947b4cf> in <module>
#     125
#     126
# --> 127 gan_train(epochs, batch, 100)
#     128
#     129 end = datetime.now()
#
# <ipython-input-7-a9f79947b4cf> in gan_train(epoch, batch_size, saving_interval)
#      77         #판별자와 생성자의 오차를 계산합니다.
#      78         d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
# ---> 79         g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
#      80         print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)
#      81
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\engine\training.py in train_on_batch(self, x, y, sample_weight, class_weight, reset_metrics, return_dict)
#    1728
#    1729     if reset_metrics:
# -> 1730       self.reset_metrics()
#    1731     logs = tf_utils.to_numpy_or_python_type(logs)
#    1732     if return_dict:
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\engine\training.py in reset_metrics(self)
#    1667     """
#    1668     for m in self.metrics:
# -> 1669       m.reset_states()
#    1670
#    1671   def train_on_batch(self,
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\metrics.py in reset_states(self)
#     251     when a metric is evaluated during training.
#     252     """
# --> 253     K.batch_set_value([(v, 0) for v in self.variables])
#     254
#     255   @abc.abstractmethod
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\util\dispatch.py in wrapper(*args, **kwargs)
#     199     """Call target, and fall back on dispatchers if there is a TypeError."""
#     200     try:
# --> 201       return target(*args, **kwargs)
#     202     except (TypeError, ValueError):
#     203       # Note: convert_to_eager_tensor currently raises a ValueError, not a
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\keras\backend.py in batch_set_value(tuples)
#    3704   if ops.executing_eagerly_outside_functions():
#    3705     for x, value in tuples:
# -> 3706       x.assign(np.asarray(value, dtype=dtype(x)))
#    3707   else:
#    3708     with get_graph().as_default():
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\ops\resource_variable_ops.py in assign(self, value, use_locking, name, read_value)
#     891             (tensor_name, self._shape, value_tensor.shape))
#     892       assign_op = gen_resource_variable_ops.assign_variable_op(
# --> 893           self.handle, value_tensor, name=name)
#     894       if read_value:
#     895         return self._lazy_read(assign_op)
#
# ~\anaconda3\envs\pj21\lib\site-packages\tensorflow\python\ops\gen_resource_variable_ops.py in assign_variable_op(resource, value, name)
#     139     try:
#     140       _result = pywrap_tfe.TFE_Py_FastPathExecute(
# --> 141         _ctx, "AssignVariableOp", name, resource, value)
#     142       return _result
#     143     except _core._NotOkStatusException as e:
#
# KeyboardInterrupt:

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan08.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
