# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf
# Out:
# C:\Users\nammr\anaconda3\envs\pj21\lib\site-packages\librosa\util\decorators.py:9: NumbaDeprecationWarning: An import was requested from a module that has moved location.
# Import of 'jit' requested from: 'numba.decorators', please update to use 'numba.core.decorators' or pin to Numba version 0.48.0. This alias will not be present in Numba version 0.50.0.
#   from numba.decorators import jit as optional_jit

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 100
x_size = 68
y_size = 68
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 40001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
generator.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense (Dense)                (None, 36992)             3736192
# _________________________________________________________________
# batch_normalization (BatchNo (None, 36992)             147968
# _________________________________________________________________
# reshape (Reshape)            (None, 17, 17, 128)       0
# _________________________________________________________________
# up_sampling2d (UpSampling2D) (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d (Conv2D)              (None, 34, 34, 64)        204864
# _________________________________________________________________
# batch_normalization_1 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation (Activation)      (None, 34, 34, 64)        0
# _________________________________________________________________
# up_sampling2d_1 (UpSampling2 (None, 68, 68, 64)        0
# _________________________________________________________________
# conv2d_1 (Conv2D)            (None, 68, 68, 1)         1601
# =================================================================
# Total params: 4,090,881
# Trainable params: 4,016,769
# Non-trainable params: 74,112
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_2 (Conv2D)            (None, 34, 34, 64)        1664
# _________________________________________________________________
# activation_1 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# dropout (Dropout)            (None, 34, 34, 64)        0
# _________________________________________________________________
# conv2d_3 (Conv2D)            (None, 17, 17, 128)       204928
# _________________________________________________________________
# activation_2 (Activation)    (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_1 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten (Flatten)            (None, 36992)             0
# _________________________________________________________________
# dense_1 (Dense)              (None, 1)                 36993
# =================================================================
# Total params: 243,585
# Trainable params: 0
# Non-trainable params: 243,585
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_1 (InputLayer)         [(None, 100)]             0
# _________________________________________________________________
# sequential (Sequential)      (None, 68, 68, 1)         4090881
# _________________________________________________________________
# sequential_1 (Sequential)    (None, 1)                 243585
# =================================================================
# Total params: 4,334,466
# Trainable params: 4,016,769
# Non-trainable params: 317,697
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (2331, 68, 68)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  X_train = x_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  X_train = (X_train - 127.5) / 127.5  
  print(X_train.shape)   # (19184, 56, 56, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan05.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            idx2 = np.random.randint(0, gen_imgs.shape[0])
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 68, 68, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            print(gen_mels.shape) # (862, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan05\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
  
            print("end")

gan_train(epochs, batch, 100)

end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# poch:39554  d_loss:0.0000  g_loss:232.1762
# epoch:39555  d_loss:0.0000  g_loss:227.8395
# epoch:39556  d_loss:0.0000  g_loss:231.3311
# epoch:39557  d_loss:0.0000  g_loss:227.6596
# epoch:39558  d_loss:0.0000  g_loss:231.4346
# epoch:39559  d_loss:0.0000  g_loss:231.5176
# epoch:39560  d_loss:0.0000  g_loss:224.7041
# epoch:39561  d_loss:0.0000  g_loss:232.2361
# epoch:39562  d_loss:0.0000  g_loss:225.2166
# epoch:39563  d_loss:0.0000  g_loss:220.4133
# epoch:39564  d_loss:0.0000  g_loss:230.7876
# epoch:39565  d_loss:0.0000  g_loss:221.8062
# epoch:39566  d_loss:0.0000  g_loss:227.5977
# epoch:39567  d_loss:0.0000  g_loss:226.1235
# epoch:39568  d_loss:0.0000  g_loss:231.5616
# epoch:39569  d_loss:0.0000  g_loss:224.9861
# epoch:39570  d_loss:0.0000  g_loss:229.0226
# epoch:39571  d_loss:0.0000  g_loss:221.4249
# epoch:39572  d_loss:0.0000  g_loss:227.7415
# epoch:39573  d_loss:0.0000  g_loss:230.0213
# epoch:39574  d_loss:0.0000  g_loss:220.6352
# epoch:39575  d_loss:0.0000  g_loss:227.1134
# epoch:39576  d_loss:0.0000  g_loss:229.1044
# epoch:39577  d_loss:0.0000  g_loss:229.5491
# epoch:39578  d_loss:0.0000  g_loss:232.0418
# epoch:39579  d_loss:0.0000  g_loss:231.3293
# epoch:39580  d_loss:0.0000  g_loss:233.0011
# epoch:39581  d_loss:0.0000  g_loss:227.2974
# epoch:39582  d_loss:0.0000  g_loss:218.3783
# epoch:39583  d_loss:0.0000  g_loss:229.1737
# epoch:39584  d_loss:0.0000  g_loss:231.3653
# epoch:39585  d_loss:0.0000  g_loss:226.7643
# epoch:39586  d_loss:0.0000  g_loss:228.9112
# epoch:39587  d_loss:0.0000  g_loss:230.6997
# epoch:39588  d_loss:0.0000  g_loss:223.4067
# epoch:39589  d_loss:0.0000  g_loss:227.2547
# epoch:39590  d_loss:0.0000  g_loss:227.2252
# epoch:39591  d_loss:0.0000  g_loss:228.7906
# epoch:39592  d_loss:0.0000  g_loss:224.3911
# epoch:39593  d_loss:0.0000  g_loss:230.7031
# epoch:39594  d_loss:0.0000  g_loss:228.9409
# epoch:39595  d_loss:0.0000  g_loss:226.9161
# epoch:39596  d_loss:0.0000  g_loss:223.1345
# epoch:39597  d_loss:0.0000  g_loss:228.4705
# epoch:39598  d_loss:0.0000  g_loss:228.8760
# epoch:39599  d_loss:0.0000  g_loss:221.7341
# epoch:39600  d_loss:0.0000  g_loss:230.5197
# id2 >  10
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39601  d_loss:0.0000  g_loss:227.5364
# epoch:39602  d_loss:0.0000  g_loss:227.3586
# epoch:39603  d_loss:0.0000  g_loss:232.2999
# epoch:39604  d_loss:0.0000  g_loss:229.0311
# epoch:39605  d_loss:0.0000  g_loss:227.1744
# epoch:39606  d_loss:0.0000  g_loss:229.6062
# epoch:39607  d_loss:0.0000  g_loss:226.6491
# epoch:39608  d_loss:0.0000  g_loss:229.0782
# epoch:39609  d_loss:0.0000  g_loss:232.9034
# epoch:39610  d_loss:0.0000  g_loss:230.6119
# epoch:39611  d_loss:0.0000  g_loss:226.1662
# epoch:39612  d_loss:0.0000  g_loss:226.2929
# epoch:39613  d_loss:0.0000  g_loss:229.7408
# epoch:39614  d_loss:0.0000  g_loss:224.9144
# epoch:39615  d_loss:0.0000  g_loss:231.2492
# epoch:39616  d_loss:0.0000  g_loss:228.7257
# epoch:39617  d_loss:0.0000  g_loss:227.7648
# epoch:39618  d_loss:0.0000  g_loss:229.6599
# epoch:39619  d_loss:0.0000  g_loss:232.1287
# epoch:39620  d_loss:0.0000  g_loss:227.3175
# epoch:39621  d_loss:0.0000  g_loss:229.5842
# epoch:39622  d_loss:0.0000  g_loss:227.5141
# epoch:39623  d_loss:0.0000  g_loss:224.4113
# epoch:39624  d_loss:0.0000  g_loss:232.6921
# epoch:39625  d_loss:0.0000  g_loss:228.5452
# epoch:39626  d_loss:0.0000  g_loss:230.0453
# epoch:39627  d_loss:0.0000  g_loss:228.4440
# epoch:39628  d_loss:0.0000  g_loss:228.3991
# epoch:39629  d_loss:0.0000  g_loss:233.8785
# epoch:39630  d_loss:0.0000  g_loss:229.8414
# epoch:39631  d_loss:0.0000  g_loss:227.6300
# epoch:39632  d_loss:0.0000  g_loss:221.7823
# epoch:39633  d_loss:0.0000  g_loss:230.2876
# epoch:39634  d_loss:0.0000  g_loss:231.6147
# epoch:39635  d_loss:0.0000  g_loss:228.6398
# epoch:39636  d_loss:0.0000  g_loss:228.5966
# epoch:39637  d_loss:0.0000  g_loss:230.5059
# epoch:39638  d_loss:0.0000  g_loss:232.7193
# epoch:39639  d_loss:0.0000  g_loss:228.6141
# epoch:39640  d_loss:0.0000  g_loss:230.4360
# epoch:39641  d_loss:0.0000  g_loss:229.5043
# epoch:39642  d_loss:0.0000  g_loss:224.7033
# epoch:39643  d_loss:0.0000  g_loss:232.7177
# epoch:39644  d_loss:0.0000  g_loss:228.8323
# epoch:39645  d_loss:0.0000  g_loss:222.6327
# epoch:39646  d_loss:0.0000  g_loss:231.2508
# epoch:39647  d_loss:0.0000  g_loss:230.1536
# epoch:39648  d_loss:0.0000  g_loss:223.4985
# epoch:39649  d_loss:0.0000  g_loss:227.1996
# epoch:39650  d_loss:0.0000  g_loss:232.7974
# epoch:39651  d_loss:0.0000  g_loss:223.9667
# epoch:39652  d_loss:0.0000  g_loss:234.4971
# epoch:39653  d_loss:0.0000  g_loss:230.3454
# epoch:39654  d_loss:0.0000  g_loss:232.0022
# epoch:39655  d_loss:0.0000  g_loss:226.2128
# epoch:39656  d_loss:0.0000  g_loss:227.2863
# epoch:39657  d_loss:0.0000  g_loss:228.3493
# epoch:39658  d_loss:0.0000  g_loss:230.8615
# epoch:39659  d_loss:0.0000  g_loss:228.2783
# epoch:39660  d_loss:0.0000  g_loss:226.9116
# epoch:39661  d_loss:0.0000  g_loss:230.4172
# epoch:39662  d_loss:0.0000  g_loss:224.3719
# epoch:39663  d_loss:0.0000  g_loss:224.5940
# epoch:39664  d_loss:0.0000  g_loss:229.1213
# epoch:39665  d_loss:0.0000  g_loss:226.1496
# epoch:39666  d_loss:0.0000  g_loss:232.8047
# epoch:39667  d_loss:0.0000  g_loss:221.0667
# epoch:39668  d_loss:0.0000  g_loss:227.7258
# epoch:39669  d_loss:0.0000  g_loss:232.1678
# epoch:39670  d_loss:0.0000  g_loss:234.5513
# epoch:39671  d_loss:0.0000  g_loss:226.1190
# epoch:39672  d_loss:0.0000  g_loss:232.3012
# epoch:39673  d_loss:0.0000  g_loss:224.6792
# epoch:39674  d_loss:0.0000  g_loss:226.7388
# epoch:39675  d_loss:0.0000  g_loss:230.0939
# epoch:39676  d_loss:0.0000  g_loss:232.4315
# epoch:39677  d_loss:0.0000  g_loss:231.1588
# epoch:39678  d_loss:0.0000  g_loss:236.3278
# epoch:39679  d_loss:0.0000  g_loss:226.8074
# epoch:39680  d_loss:0.0000  g_loss:233.0150
# epoch:39681  d_loss:0.0000  g_loss:227.3647
# epoch:39682  d_loss:0.0000  g_loss:228.2059
# epoch:39683  d_loss:0.0000  g_loss:231.0395
# epoch:39684  d_loss:0.0000  g_loss:223.2691
# epoch:39685  d_loss:0.0000  g_loss:229.7730
# epoch:39686  d_loss:0.0000  g_loss:236.9903
# epoch:39687  d_loss:0.0000  g_loss:229.0957
# epoch:39688  d_loss:0.0000  g_loss:230.0670
# epoch:39689  d_loss:0.0000  g_loss:231.4718
# epoch:39690  d_loss:0.0000  g_loss:223.4451
# epoch:39691  d_loss:0.0000  g_loss:229.6646
# epoch:39692  d_loss:0.0000  g_loss:230.7043
# epoch:39693  d_loss:0.0000  g_loss:228.2640
# epoch:39694  d_loss:0.0000  g_loss:224.3285
# epoch:39695  d_loss:0.0000  g_loss:228.7418
# epoch:39696  d_loss:0.0000  g_loss:223.6019
# epoch:39697  d_loss:0.0000  g_loss:231.9400
# epoch:39698  d_loss:0.0000  g_loss:224.4824
# epoch:39699  d_loss:0.0000  g_loss:228.3244
# epoch:39700  d_loss:0.0000  g_loss:224.8210
# id2 >  17
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39701  d_loss:0.0000  g_loss:233.0949
# epoch:39702  d_loss:0.0000  g_loss:232.9488
# epoch:39703  d_loss:0.0000  g_loss:229.9456
# epoch:39704  d_loss:0.0000  g_loss:230.6187
# epoch:39705  d_loss:0.0000  g_loss:231.6745
# epoch:39706  d_loss:0.0000  g_loss:228.4580
# epoch:39707  d_loss:0.0000  g_loss:224.0394
# epoch:39708  d_loss:0.0000  g_loss:234.4153
# epoch:39709  d_loss:0.0000  g_loss:229.1939
# epoch:39710  d_loss:0.0000  g_loss:227.4891
# epoch:39711  d_loss:0.0000  g_loss:229.8358
# epoch:39712  d_loss:0.0000  g_loss:234.6549
# epoch:39713  d_loss:0.0000  g_loss:230.1733
# epoch:39714  d_loss:0.0000  g_loss:230.0318
# epoch:39715  d_loss:0.0000  g_loss:227.0872
# epoch:39716  d_loss:0.0000  g_loss:231.3394
# epoch:39717  d_loss:0.0000  g_loss:227.3280
# epoch:39718  d_loss:0.0000  g_loss:226.4745
# epoch:39719  d_loss:0.0000  g_loss:227.7542
# epoch:39720  d_loss:0.0000  g_loss:224.2107
# epoch:39721  d_loss:0.0000  g_loss:231.3187
# epoch:39722  d_loss:0.0000  g_loss:226.7073
# epoch:39723  d_loss:0.0000  g_loss:229.5279
# epoch:39724  d_loss:0.0000  g_loss:231.1376
# epoch:39725  d_loss:0.0000  g_loss:230.4310
# epoch:39726  d_loss:0.0000  g_loss:227.0757
# epoch:39727  d_loss:0.0000  g_loss:231.8214
# epoch:39728  d_loss:0.0000  g_loss:233.3035
# epoch:39729  d_loss:0.0000  g_loss:226.1309
# epoch:39730  d_loss:0.0000  g_loss:225.8623
# epoch:39731  d_loss:0.0000  g_loss:229.7131
# epoch:39732  d_loss:0.0000  g_loss:220.8475
# epoch:39733  d_loss:0.0000  g_loss:224.2957
# epoch:39734  d_loss:0.0000  g_loss:223.3960
# epoch:39735  d_loss:0.0000  g_loss:229.1933
# epoch:39736  d_loss:0.0000  g_loss:230.3538
# epoch:39737  d_loss:0.0000  g_loss:232.9520
# epoch:39738  d_loss:0.0000  g_loss:231.8510
# epoch:39739  d_loss:0.0000  g_loss:225.4032
# epoch:39740  d_loss:0.0000  g_loss:229.0364
# epoch:39741  d_loss:0.0000  g_loss:224.9073
# epoch:39742  d_loss:0.0000  g_loss:227.8249
# epoch:39743  d_loss:0.0000  g_loss:230.3956
# epoch:39744  d_loss:0.0000  g_loss:225.0388
# epoch:39745  d_loss:0.0000  g_loss:226.4076
# epoch:39746  d_loss:0.0000  g_loss:223.6507
# epoch:39747  d_loss:0.0000  g_loss:233.2204
# epoch:39748  d_loss:0.0000  g_loss:225.6031
# epoch:39749  d_loss:0.0000  g_loss:229.0393
# epoch:39750  d_loss:0.0000  g_loss:226.1861
# epoch:39751  d_loss:0.0000  g_loss:225.5188
# epoch:39752  d_loss:0.0000  g_loss:226.5679
# epoch:39753  d_loss:0.0000  g_loss:226.1830
# epoch:39754  d_loss:0.0000  g_loss:224.5390
# epoch:39755  d_loss:0.0000  g_loss:231.3455
# epoch:39756  d_loss:0.0000  g_loss:225.0936
# epoch:39757  d_loss:0.0000  g_loss:232.6761
# epoch:39758  d_loss:0.0000  g_loss:230.2896
# epoch:39759  d_loss:0.0000  g_loss:229.2365
# epoch:39760  d_loss:0.0000  g_loss:229.8859
# epoch:39761  d_loss:0.0000  g_loss:223.5236
# epoch:39762  d_loss:0.0000  g_loss:231.0402
# epoch:39763  d_loss:0.0000  g_loss:230.3116
# epoch:39764  d_loss:0.0000  g_loss:223.2034
# epoch:39765  d_loss:0.0000  g_loss:224.8931
# epoch:39766  d_loss:0.0000  g_loss:230.0303
# epoch:39767  d_loss:0.0000  g_loss:232.0251
# epoch:39768  d_loss:0.0000  g_loss:224.6042
# epoch:39769  d_loss:0.0000  g_loss:226.8852
# epoch:39770  d_loss:0.0000  g_loss:228.4426
# epoch:39771  d_loss:0.0000  g_loss:224.9073
# epoch:39772  d_loss:0.0000  g_loss:230.0188
# epoch:39773  d_loss:0.0000  g_loss:228.6524
# epoch:39774  d_loss:0.0000  g_loss:224.8942
# epoch:39775  d_loss:0.0000  g_loss:224.4005
# epoch:39776  d_loss:0.0000  g_loss:229.0756
# epoch:39777  d_loss:0.0000  g_loss:231.2311
# epoch:39778  d_loss:0.0000  g_loss:234.4019
# epoch:39779  d_loss:0.0000  g_loss:231.4290
# epoch:39780  d_loss:0.0000  g_loss:227.9043
# epoch:39781  d_loss:0.0000  g_loss:225.0875
# epoch:39782  d_loss:0.0000  g_loss:222.0514
# epoch:39783  d_loss:0.0000  g_loss:224.0674
# epoch:39784  d_loss:0.0000  g_loss:228.1130
# epoch:39785  d_loss:0.0000  g_loss:229.2316
# epoch:39786  d_loss:0.0000  g_loss:235.7871
# epoch:39787  d_loss:0.0000  g_loss:228.4610
# epoch:39788  d_loss:0.0000  g_loss:224.2635
# epoch:39789  d_loss:0.0000  g_loss:224.7828
# epoch:39790  d_loss:0.0000  g_loss:230.4311
# epoch:39791  d_loss:0.0000  g_loss:224.8658
# epoch:39792  d_loss:0.0000  g_loss:228.0843
# epoch:39793  d_loss:0.0000  g_loss:231.2473
# epoch:39794  d_loss:0.0000  g_loss:228.4968
# epoch:39795  d_loss:0.0000  g_loss:232.6175
# epoch:39796  d_loss:0.0000  g_loss:227.1375
# epoch:39797  d_loss:0.0000  g_loss:225.7711
# epoch:39798  d_loss:0.0000  g_loss:225.9033
# epoch:39799  d_loss:0.0000  g_loss:229.7748
# epoch:39800  d_loss:0.0000  g_loss:233.0688
# id2 >  8
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39801  d_loss:0.0000  g_loss:225.7456
# epoch:39802  d_loss:0.0000  g_loss:232.6808
# epoch:39803  d_loss:0.0000  g_loss:223.2415
# epoch:39804  d_loss:0.0000  g_loss:225.9508
# epoch:39805  d_loss:0.0000  g_loss:229.7914
# epoch:39806  d_loss:0.0000  g_loss:228.1103
# epoch:39807  d_loss:0.0000  g_loss:223.7696
# epoch:39808  d_loss:0.0000  g_loss:230.6647
# epoch:39809  d_loss:0.0000  g_loss:229.4869
# epoch:39810  d_loss:0.0000  g_loss:224.7701
# epoch:39811  d_loss:0.0000  g_loss:224.7957
# epoch:39812  d_loss:0.0000  g_loss:223.6406
# epoch:39813  d_loss:0.0000  g_loss:230.4823
# epoch:39814  d_loss:0.0000  g_loss:226.6043
# epoch:39815  d_loss:0.0000  g_loss:228.3599
# epoch:39816  d_loss:0.0000  g_loss:231.7354
# epoch:39817  d_loss:0.0000  g_loss:228.9715
# epoch:39818  d_loss:0.0000  g_loss:225.7980
# epoch:39819  d_loss:0.0000  g_loss:225.8930
# epoch:39820  d_loss:0.0000  g_loss:224.3609
# epoch:39821  d_loss:0.0000  g_loss:230.4437
# epoch:39822  d_loss:0.0000  g_loss:222.7936
# epoch:39823  d_loss:0.0000  g_loss:226.2543
# epoch:39824  d_loss:0.0000  g_loss:224.1450
# epoch:39825  d_loss:0.0000  g_loss:223.9427
# epoch:39826  d_loss:0.0000  g_loss:231.9206
# epoch:39827  d_loss:0.0000  g_loss:217.5342
# epoch:39828  d_loss:0.0000  g_loss:231.2697
# epoch:39829  d_loss:0.0000  g_loss:222.1036
# epoch:39830  d_loss:0.0000  g_loss:223.6806
# epoch:39831  d_loss:0.0000  g_loss:226.3794
# epoch:39832  d_loss:0.0000  g_loss:226.3178
# epoch:39833  d_loss:0.0000  g_loss:224.5744
# epoch:39834  d_loss:0.0000  g_loss:231.1638
# epoch:39835  d_loss:0.0000  g_loss:226.6921
# epoch:39836  d_loss:0.0000  g_loss:223.4641
# epoch:39837  d_loss:0.0000  g_loss:223.9045
# epoch:39838  d_loss:0.0000  g_loss:224.7481
# epoch:39839  d_loss:0.0000  g_loss:224.6799
# epoch:39840  d_loss:0.0000  g_loss:231.2379
# epoch:39841  d_loss:0.0000  g_loss:221.5319
# epoch:39842  d_loss:0.0000  g_loss:234.9744
# epoch:39843  d_loss:0.0000  g_loss:228.1903
# epoch:39844  d_loss:0.0000  g_loss:225.8094
# epoch:39845  d_loss:0.0000  g_loss:230.0878
# epoch:39846  d_loss:0.0000  g_loss:233.0064
# epoch:39847  d_loss:0.0000  g_loss:225.7123
# epoch:39848  d_loss:0.0000  g_loss:231.1986
# epoch:39849  d_loss:0.0000  g_loss:225.1371
# epoch:39850  d_loss:0.0000  g_loss:226.4253
# epoch:39851  d_loss:0.0000  g_loss:222.2676
# epoch:39852  d_loss:0.0000  g_loss:226.2702
# epoch:39853  d_loss:0.0000  g_loss:227.3180
# epoch:39854  d_loss:0.0000  g_loss:229.5887
# epoch:39855  d_loss:0.0000  g_loss:229.0222
# epoch:39856  d_loss:0.0000  g_loss:231.7554
# epoch:39857  d_loss:0.0000  g_loss:231.7395
# epoch:39858  d_loss:0.0000  g_loss:228.8326
# epoch:39859  d_loss:0.0000  g_loss:227.6826
# epoch:39860  d_loss:0.0000  g_loss:229.8449
# epoch:39861  d_loss:0.0000  g_loss:227.9031
# epoch:39862  d_loss:0.0000  g_loss:231.2009
# epoch:39863  d_loss:0.0000  g_loss:228.4610
# epoch:39864  d_loss:0.0000  g_loss:229.8632
# epoch:39865  d_loss:0.0000  g_loss:223.7784
# epoch:39866  d_loss:0.0000  g_loss:225.1962
# epoch:39867  d_loss:0.0000  g_loss:228.2525
# epoch:39868  d_loss:0.0000  g_loss:227.6075
# epoch:39869  d_loss:0.0000  g_loss:226.8009
# epoch:39870  d_loss:0.0000  g_loss:232.3854
# epoch:39871  d_loss:0.0000  g_loss:228.8520
# epoch:39872  d_loss:0.0000  g_loss:229.7322
# epoch:39873  d_loss:0.0000  g_loss:224.9004
# epoch:39874  d_loss:0.0000  g_loss:223.5444
# epoch:39875  d_loss:0.0000  g_loss:227.4674
# epoch:39876  d_loss:0.0000  g_loss:223.4684
# epoch:39877  d_loss:0.0000  g_loss:227.3372
# epoch:39878  d_loss:0.0000  g_loss:226.5706
# epoch:39879  d_loss:0.0000  g_loss:225.1927
# epoch:39880  d_loss:0.0000  g_loss:228.6731
# epoch:39881  d_loss:0.0000  g_loss:224.8663
# epoch:39882  d_loss:0.0000  g_loss:231.9760
# epoch:39883  d_loss:0.0000  g_loss:232.9332
# epoch:39884  d_loss:0.0000  g_loss:225.6868
# epoch:39885  d_loss:0.0000  g_loss:225.2938
# epoch:39886  d_loss:0.0000  g_loss:226.6696
# epoch:39887  d_loss:0.0000  g_loss:231.4033
# epoch:39888  d_loss:0.0000  g_loss:224.7740
# epoch:39889  d_loss:0.0000  g_loss:231.2277
# epoch:39890  d_loss:0.0000  g_loss:224.3232
# epoch:39891  d_loss:0.0000  g_loss:229.8031
# epoch:39892  d_loss:0.0000  g_loss:232.3214
# epoch:39893  d_loss:0.0000  g_loss:228.2985
# epoch:39894  d_loss:0.0000  g_loss:231.6931
# epoch:39895  d_loss:0.0000  g_loss:224.6467
# epoch:39896  d_loss:0.0000  g_loss:230.1274
# epoch:39897  d_loss:0.0000  g_loss:232.1234
# epoch:39898  d_loss:0.0000  g_loss:231.3312
# epoch:39899  d_loss:0.0000  g_loss:225.7941
# epoch:39900  d_loss:0.0000  g_loss:228.2673
# id2 >  16
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39901  d_loss:0.0000  g_loss:222.0691
# epoch:39902  d_loss:0.0000  g_loss:227.0306
# epoch:39903  d_loss:0.0000  g_loss:228.9683
# epoch:39904  d_loss:0.0000  g_loss:224.1207
# epoch:39905  d_loss:0.0000  g_loss:228.3789
# epoch:39906  d_loss:0.0000  g_loss:227.8109
# epoch:39907  d_loss:0.0000  g_loss:226.5517
# epoch:39908  d_loss:0.0000  g_loss:233.4129
# epoch:39909  d_loss:0.0000  g_loss:230.5442
# epoch:39910  d_loss:0.0000  g_loss:224.5511
# epoch:39911  d_loss:0.0000  g_loss:232.4405
# epoch:39912  d_loss:0.0000  g_loss:235.2178
# epoch:39913  d_loss:0.0000  g_loss:229.6839
# epoch:39914  d_loss:0.0000  g_loss:231.6800
# epoch:39915  d_loss:0.0000  g_loss:222.7932
# epoch:39916  d_loss:0.0000  g_loss:221.9697
# epoch:39917  d_loss:0.0000  g_loss:227.4016
# epoch:39918  d_loss:0.0000  g_loss:219.6460
# epoch:39919  d_loss:0.0000  g_loss:229.4508
# epoch:39920  d_loss:0.0000  g_loss:221.4524
# epoch:39921  d_loss:0.0000  g_loss:233.0971
# epoch:39922  d_loss:0.0000  g_loss:227.3246
# epoch:39923  d_loss:0.0000  g_loss:225.9333
# epoch:39924  d_loss:0.0000  g_loss:230.3158
# epoch:39925  d_loss:0.0000  g_loss:231.9518
# epoch:39926  d_loss:0.0000  g_loss:229.9205
# epoch:39927  d_loss:0.0000  g_loss:232.6604
# epoch:39928  d_loss:0.0000  g_loss:227.8334
# epoch:39929  d_loss:0.0000  g_loss:229.5382
# epoch:39930  d_loss:0.0000  g_loss:231.0946
# epoch:39931  d_loss:0.0000  g_loss:227.4082
# epoch:39932  d_loss:0.0000  g_loss:224.2538
# epoch:39933  d_loss:0.0000  g_loss:228.0127
# epoch:39934  d_loss:0.0000  g_loss:232.1053
# epoch:39935  d_loss:0.0000  g_loss:229.2790
# epoch:39936  d_loss:0.0000  g_loss:233.2442
# epoch:39937  d_loss:0.0000  g_loss:231.6707
# epoch:39938  d_loss:0.0000  g_loss:224.8082
# epoch:39939  d_loss:0.0000  g_loss:227.6810
# epoch:39940  d_loss:0.0000  g_loss:227.1149
# epoch:39941  d_loss:0.0000  g_loss:225.2778
# epoch:39942  d_loss:0.0000  g_loss:227.0103
# epoch:39943  d_loss:0.0000  g_loss:232.0443
# epoch:39944  d_loss:0.0000  g_loss:226.2591
# epoch:39945  d_loss:0.0000  g_loss:228.3523
# epoch:39946  d_loss:0.0000  g_loss:231.9698
# epoch:39947  d_loss:0.0000  g_loss:233.0897
# epoch:39948  d_loss:0.0000  g_loss:227.5024
# epoch:39949  d_loss:0.0000  g_loss:231.1489
# epoch:39950  d_loss:0.0000  g_loss:232.6232
# epoch:39951  d_loss:0.0000  g_loss:229.7311
# epoch:39952  d_loss:0.0000  g_loss:225.6864
# epoch:39953  d_loss:0.0000  g_loss:232.3560
# epoch:39954  d_loss:0.0000  g_loss:232.1885
# epoch:39955  d_loss:0.0000  g_loss:226.5868
# epoch:39956  d_loss:0.0000  g_loss:225.1371
# epoch:39957  d_loss:0.0000  g_loss:230.2018
# epoch:39958  d_loss:0.0000  g_loss:226.0238
# epoch:39959  d_loss:0.0000  g_loss:227.8321
# epoch:39960  d_loss:0.0000  g_loss:226.4534
# epoch:39961  d_loss:0.0000  g_loss:226.9042
# epoch:39962  d_loss:0.0000  g_loss:232.1807
# epoch:39963  d_loss:0.0000  g_loss:228.7430
# epoch:39964  d_loss:0.0000  g_loss:238.5047
# epoch:39965  d_loss:0.0000  g_loss:228.2484
# epoch:39966  d_loss:0.0000  g_loss:225.5724
# epoch:39967  d_loss:0.0000  g_loss:225.8313
# epoch:39968  d_loss:0.0000  g_loss:229.4995
# epoch:39969  d_loss:0.0000  g_loss:231.6164
# epoch:39970  d_loss:0.0000  g_loss:232.4779
# epoch:39971  d_loss:0.0000  g_loss:234.5269
# epoch:39972  d_loss:0.0000  g_loss:231.0917
# epoch:39973  d_loss:0.0000  g_loss:234.0715
# epoch:39974  d_loss:0.0000  g_loss:229.9992
# epoch:39975  d_loss:0.0000  g_loss:225.0728
# epoch:39976  d_loss:0.0000  g_loss:235.8718
# epoch:39977  d_loss:0.0000  g_loss:222.8645
# epoch:39978  d_loss:0.0000  g_loss:228.6883
# epoch:39979  d_loss:0.0000  g_loss:231.6556
# epoch:39980  d_loss:0.0000  g_loss:230.2058
# epoch:39981  d_loss:0.0000  g_loss:230.2361
# epoch:39982  d_loss:0.0000  g_loss:222.9677
# epoch:39983  d_loss:0.0000  g_loss:233.1261
# epoch:39984  d_loss:0.0000  g_loss:231.3188
# epoch:39985  d_loss:0.0000  g_loss:227.6631
# epoch:39986  d_loss:0.0000  g_loss:231.2942
# epoch:39987  d_loss:0.0000  g_loss:233.6199
# epoch:39988  d_loss:0.0000  g_loss:226.6420
# epoch:39989  d_loss:0.0000  g_loss:230.2775
# epoch:39990  d_loss:0.0000  g_loss:229.0936
# epoch:39991  d_loss:0.0000  g_loss:232.5203
# epoch:39992  d_loss:0.0000  g_loss:222.1579
# epoch:39993  d_loss:0.0000  g_loss:230.4930
# epoch:39994  d_loss:0.0000  g_loss:227.2251
# epoch:39995  d_loss:0.0000  g_loss:227.2046
# epoch:39996  d_loss:0.0000  g_loss:228.5794
# epoch:39997  d_loss:0.0000  g_loss:231.7325
# epoch:39998  d_loss:0.0000  g_loss:234.4621
# epoch:39999  d_loss:0.0000  g_loss:227.9461
# epoch:40000  d_loss:0.0000  g_loss:232.4543
# id2 >  1
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# 작업 시간 :  13:24:08.298638

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan05.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
