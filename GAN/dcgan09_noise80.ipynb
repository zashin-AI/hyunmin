# %% [markdown]
# # 모두의 딥러닝 20_GAN

# %% [markdown]
# https://github.com/gilbutITbook/080228/blob/master/deeplearning/run_project/20_GAN.ipynb

# %%
from tensorflow.keras.layers import Input, Dense, Reshape, Flatten, Dropout
from tensorflow.keras.layers import BatchNormalization, Activation, LeakyReLU, UpSampling2D, Conv2D
from tensorflow.keras.models import Sequential, Model
from sklearn.preprocessing import MinMaxScaler, StandardScaler, MaxAbsScaler

import numpy as np
import pandas as pd
import tensorflow as tf
import cv2
import matplotlib.pyplot as plt

import librosa
import librosa.display
import soundfile as sf

# %%
#이미지가 저장될 폴더가 없다면 만듭니다.
# import os
# if not os.path.exists("E:\\nmb\\gan_images"):
#     os.makedirs("E:\\nmb\\gan_image")

np.random.seed(3)
tf.random.set_seed(3)

nosie_size = 80
x_size = 68
y_size = 68
gx1 = int(x_size/4)
gy1 = int(y_size/4)

epochs = 40001
batch = 16

# %%
#생성자 모델을 만듭니다.
generator = Sequential()
generator.add(Dense(128*gx1*gy1, input_dim=nosie_size, activation=LeakyReLU(0.2)))
generator.add(BatchNormalization())
generator.add(Reshape((gx1, gy1, 128)))
generator.add(UpSampling2D())
generator.add(Conv2D(64, kernel_size=5, padding='same'))
generator.add(BatchNormalization())
generator.add(Activation(LeakyReLU(0.2)))
generator.add(UpSampling2D())
generator.add(Conv2D(1, kernel_size=5, padding='same', activation='tanh'))
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='relu'))
# generator.add(Conv2D(1, kernel_size=5, padding='same', activation='elu'))
generator.summary()
# Out:
# Model: "sequential_6"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_6 (Dense)              (None, 36992)             2996352
# _________________________________________________________________
# batch_normalization_6 (Batch (None, 36992)             147968
# _________________________________________________________________
# reshape_3 (Reshape)          (None, 17, 17, 128)       0
# _________________________________________________________________
# up_sampling2d_6 (UpSampling2 (None, 34, 34, 128)       0
# _________________________________________________________________
# conv2d_12 (Conv2D)           (None, 34, 34, 64)        204864
# _________________________________________________________________
# batch_normalization_7 (Batch (None, 34, 34, 64)        256
# _________________________________________________________________
# activation_9 (Activation)    (None, 34, 34, 64)        0
# _________________________________________________________________
# up_sampling2d_7 (UpSampling2 (None, 68, 68, 64)        0
# _________________________________________________________________
# conv2d_13 (Conv2D)           (None, 68, 68, 1)         1601
# =================================================================
# Total params: 3,351,041
# Trainable params: 3,276,929
# Non-trainable params: 74,112
# _________________________________________________________________

# %%
#판별자 모델을 만듭니다.
discriminator = Sequential()
discriminator.add(Conv2D(64, kernel_size=5, strides=2, input_shape=(x_size,y_size,1), padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Conv2D(128, kernel_size=5, strides=2, padding="same"))
discriminator.add(Activation(LeakyReLU(0.2)))
discriminator.add(Dropout(0.3))
discriminator.add(Flatten())
discriminator.add(Dense(1, activation='sigmoid'))

# compile
discriminator.compile(loss='binary_crossentropy', optimizer='adam')
discriminator.trainable = False
# discriminator.trainable = True
discriminator.summary()
# Out:
# Model: "sequential_7"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_14 (Conv2D)           (None, 34, 34, 64)        1664
# _________________________________________________________________
# activation_10 (Activation)   (None, 34, 34, 64)        0
# _________________________________________________________________
# dropout_6 (Dropout)          (None, 34, 34, 64)        0
# _________________________________________________________________
# conv2d_15 (Conv2D)           (None, 17, 17, 128)       204928
# _________________________________________________________________
# activation_11 (Activation)   (None, 17, 17, 128)       0
# _________________________________________________________________
# dropout_7 (Dropout)          (None, 17, 17, 128)       0
# _________________________________________________________________
# flatten_3 (Flatten)          (None, 36992)             0
# _________________________________________________________________
# dense_7 (Dense)              (None, 1)                 36993
# =================================================================
# Total params: 243,585
# Trainable params: 0
# Non-trainable params: 243,585
# _________________________________________________________________

# %%
#생성자와 판별자 모델을 연결시키는 gan 모델을 만듭니다.
ginput = Input(shape=(nosie_size,))                    # input
dis_output = discriminator(generator(ginput))   # output
gan = Model(ginput, dis_output)
gan.compile(loss='binary_crossentropy', optimizer='adam')
gan.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_4 (InputLayer)         [(None, 80)]              0
# _________________________________________________________________
# sequential_6 (Sequential)    (None, 68, 68, 1)         3351041
# _________________________________________________________________
# sequential_7 (Sequential)    (None, 1)                 243585
# =================================================================
# Total params: 3,594,626
# Trainable params: 3,276,929
# Non-trainable params: 317,697
# _________________________________________________________________

# %%
# X_train = np.load('E:\\nmb\\nmb_data\\npy\\1m2s\\concate\\total_fm_data.npy')
X_train = np.load('E:\\nmb\\nmb_data\\npy\\2m5s\\project_total_npy\\total_f_data.npy')
print(X_train.shape)    # (2331, 128, 862)

x_train= []
for i in range (X_train.shape[0]) : 
    print(X_train[i].shape)
    img_resize = cv2.resize(X_train[i], (x_size, y_size))
    print(img_resize.shape)
    x_train.append(img_resize)
    
x_train = np.array(x_train)
x_train.shape    # (4680, 56, 56)
# Out:
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (128, 862)
# (68, 68)
# (2331, 68, 68)

# %%
from datetime import datetime
start = datetime.now()

#신경망을 실행시키는 함수를 만듭니다.
def gan_train(epoch, batch_size, saving_interval):
  
  global nosie_size, x_size, y_size


  # 데이터 불러오기
  print(x_train.shape)  # (2331, 68, 68)
  X_train = x_train.reshape(x_train.shape[0], x_size*y_size).astype('float32')
  print(np.max(X_train), np.min(X_train))   # -0.18890941 / -80.0

  scale = MaxAbsScaler()
  X_train = scale.fit_transform(X_train)
  print(X_train.shape)   # (2331, 4624)
  print(np.max(X_train), np.min(X_train))   # 48.270073 -1.1008358


  X_train = X_train.reshape(x_train.shape[0], x_size, y_size, 1).astype('float32')
  print(X_train.shape)  # (2331, 68, 68, 1)

  true = np.ones((batch_size, 1))   # 1로 라벨링
    # print(true.shape)     # (32, 1)
    # print(true)
  fake = np.zeros((batch_size, 1))  # 0으로 라벨링
    # print(fake.shape)     # (32, 1)
    # print(fake)

  d_loss_list = list()
  g_loss_list = list()

  for i in range(epoch):
        # [1] 실제 데이터를 판별자에 입력하는 부분입니다.
        idx = np.random.randint(0, X_train.shape[0], batch_size)    
            # 0부터 X_train.shape[0] 까지 batch_size개의 랜덤 값(정수형)을 반환한다.
            # print(idx.shape)        # (32,) == (batch_size, )
            # print(idx)
        imgs = X_train[idx]
            # print(imgs.shape)   # (32, 56, 56, 1)
            # print(imgs)

            # 실제 데이터 이미지 확인하기
            # imgs = np.array(imgs[0])
            # imgs = np.reshape(imgs,(128, 173))
            # print(imgs.shape)         # (128, 173)
            # plt.imshow(imgs,'gray')
            # plt.show()

            # batch_size : 한 에폭당 생성되는 이미지의 개수

        d_loss_real = discriminator.train_on_batch(imgs, true)
            # train_on_batch : fit() 과 유사한 기능을 함
            # fit()과 차이점 : 고정된 batch_size에 신경쓰지 않는다. 
            # generator는 매번 새로운 image를 전달해야 하기 때문에 새로운 데이터를 학습해야 한다.
            # 현재 전달받은 데이터를 활용해서 가중치를 계산한다.

       # [2] 가상 이미지를 판별자에 입력하는 부분입니다.
        noise = np.random.normal(0, 1, (batch_size, nosie_size))   
            # 평균이 0, 분산이 1인 표준 정규분포, 랜덤한 값을 반환해준다.
            # (batch_size, 100) 행렬로 반환
            # print(noise.shape)  # (32, 100)
            # print(noise)
        gen_imgs = generator.predict(noise)
            # print(gen_imgs.shape)     # (32, 56, 56, 1)
            # print(gen_imgs)

            # 실제 데이터 이미지 확인하기
            # gen_imgs = np.array(gen_imgs[0])
            # gen_imgs = np.reshape(gen_imgs,(28, 28))
            # print(gen_imgs.shape)           # (28, 28)
            # plt.imshow(gen_imgs,'gray')
            # plt.show()
        d_loss_fake = discriminator.train_on_batch(gen_imgs, fake)

        #판별자와 생성자의 오차를 계산합니다.
        d_loss = 0.5 * np.add(d_loss_real, d_loss_fake) # 판별자 loss
        g_loss = gan.train_on_batch(noise, true)        # 생성자 loss
        print('epoch:%d' % i, ' d_loss:%.4f' % d_loss, ' g_loss:%.4f' % g_loss)

        # loss 값 저장하기
        d_loss_list.append(float(d_loss))
        g_loss_list.append(float(g_loss))

        # pandas dataframe
        d_loss_df = pd.DataFrame(d_loss_list)
        g_loss_df = pd.DataFrame(g_loss_list)

        d_loss_df.columns = ['d_loss']
        g_loss_df.columns = ['g_loss']

        gd_loss_df = pd.concat([d_loss_df, g_loss_df], axis = 1)

        gd_loss_df.to_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan09.csv', index = False)

        if i % saving_interval == 0:
            # saving_interval 마다 이미지를 출력한다.
            noise = np.random.normal(0, 1, (25, nosie_size))
                # print(noise.shape)  # (25, 100)
            gen_imgs = generator.predict(noise)
                # print(gen_imgs.shape)   # (25, 28, 28, 1)
            idx2 = np.random.randint(0, gen_imgs.shape[0])
            print("id2 > ", idx2)
            
            gen_imgs = 0.5 * gen_imgs + 0.5
                # Rescale images 0 - 1
            print(gen_imgs.shape) # (25, 68, 68, 1)
       
            # 다시 melspectrogram으로 바꾸기 (shape 맞추기)
            gen_mels = cv2.resize(gen_imgs[idx2], (128, 862))
            print(gen_mels.shape) # (862, 128)
            gen_mels = gen_mels.reshape(gen_mels.shape[1], gen_mels.shape[0] )
            print(gen_mels.shape) # (128, 862)

            # 다시 melspectrogram으로 바꾸기
            remels = librosa.feature.inverse.mel_to_audio (gen_mels, sr=22050, hop_length=128, n_fft=512)
            print(remels.shape)   # (110208,)

            sf.write(f'E:\\nmb\\gan_image\\dcgan09\\{i}.wav', remels, 22050)

            # librosa.display.waveplot(remels, 22050)
            # plt.show()
            print("end")
          

gan_train(epochs, batch, 100)

end = datetime.now()
time = end - start
print("작업 시간 : " , time)
# Out:
# ch:39537  d_loss:0.0433  g_loss:7.6131
# epoch:39538  d_loss:0.0026  g_loss:9.7897
# epoch:39539  d_loss:0.1148  g_loss:10.7642
# epoch:39540  d_loss:0.0395  g_loss:10.3847
# epoch:39541  d_loss:0.1825  g_loss:8.9888
# epoch:39542  d_loss:0.0670  g_loss:8.2081
# epoch:39543  d_loss:0.0073  g_loss:9.7618
# epoch:39544  d_loss:0.0012  g_loss:8.4024
# epoch:39545  d_loss:0.0115  g_loss:10.1262
# epoch:39546  d_loss:0.0375  g_loss:8.8754
# epoch:39547  d_loss:0.2969  g_loss:8.6941
# epoch:39548  d_loss:0.0249  g_loss:9.2821
# epoch:39549  d_loss:0.0009  g_loss:10.8158
# epoch:39550  d_loss:0.2859  g_loss:9.1870
# epoch:39551  d_loss:0.0734  g_loss:7.8754
# epoch:39552  d_loss:0.2293  g_loss:6.7285
# epoch:39553  d_loss:0.1079  g_loss:10.7380
# epoch:39554  d_loss:0.0175  g_loss:11.6692
# epoch:39555  d_loss:0.0371  g_loss:10.5452
# epoch:39556  d_loss:0.4121  g_loss:7.2308
# epoch:39557  d_loss:0.3108  g_loss:5.3095
# epoch:39558  d_loss:0.0534  g_loss:7.3223
# epoch:39559  d_loss:0.0053  g_loss:8.2335
# epoch:39560  d_loss:0.0030  g_loss:9.2097
# epoch:39561  d_loss:0.0140  g_loss:10.9669
# epoch:39562  d_loss:0.1331  g_loss:10.5632
# epoch:39563  d_loss:0.0683  g_loss:8.7675
# epoch:39564  d_loss:0.0011  g_loss:11.7043
# epoch:39565  d_loss:0.0168  g_loss:11.1831
# epoch:39566  d_loss:0.1269  g_loss:10.4592
# epoch:39567  d_loss:0.0099  g_loss:6.7288
# epoch:39568  d_loss:0.1138  g_loss:8.0610
# epoch:39569  d_loss:0.1176  g_loss:9.8443
# epoch:39570  d_loss:0.0181  g_loss:9.6002
# epoch:39571  d_loss:0.1169  g_loss:7.8247
# epoch:39572  d_loss:0.0136  g_loss:11.1621
# epoch:39573  d_loss:0.0605  g_loss:8.0689
# epoch:39574  d_loss:0.0539  g_loss:6.6642
# epoch:39575  d_loss:0.0836  g_loss:8.2084
# epoch:39576  d_loss:0.0019  g_loss:9.0053
# epoch:39577  d_loss:0.0026  g_loss:10.3057
# epoch:39578  d_loss:0.0154  g_loss:10.6072
# epoch:39579  d_loss:0.1143  g_loss:8.9817
# epoch:39580  d_loss:0.0171  g_loss:8.1529
# epoch:39581  d_loss:0.0323  g_loss:8.9478
# epoch:39582  d_loss:0.0446  g_loss:9.5523
# epoch:39583  d_loss:0.0453  g_loss:10.9304
# epoch:39584  d_loss:0.0037  g_loss:12.7681
# epoch:39585  d_loss:0.0655  g_loss:11.5656
# epoch:39586  d_loss:0.0594  g_loss:9.5081
# epoch:39587  d_loss:0.2909  g_loss:10.3933
# epoch:39588  d_loss:0.0258  g_loss:8.8289
# epoch:39589  d_loss:0.0031  g_loss:10.3668
# epoch:39590  d_loss:0.0773  g_loss:10.1146
# epoch:39591  d_loss:0.1649  g_loss:11.4414
# epoch:39592  d_loss:0.0977  g_loss:12.0993
# epoch:39593  d_loss:0.0429  g_loss:10.6583
# epoch:39594  d_loss:0.0871  g_loss:9.2874
# epoch:39595  d_loss:0.0470  g_loss:9.1960
# epoch:39596  d_loss:0.0361  g_loss:11.1865
# epoch:39597  d_loss:0.0913  g_loss:9.4209
# epoch:39598  d_loss:0.2538  g_loss:8.4940
# epoch:39599  d_loss:0.0683  g_loss:8.2968
# epoch:39600  d_loss:0.1300  g_loss:9.7499
# id2 >  10
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39601  d_loss:0.0248  g_loss:10.8488
# epoch:39602  d_loss:0.0382  g_loss:9.2176
# epoch:39603  d_loss:0.0801  g_loss:8.7270
# epoch:39604  d_loss:0.0357  g_loss:11.1821
# epoch:39605  d_loss:0.0635  g_loss:10.8306
# epoch:39606  d_loss:0.0124  g_loss:10.1292
# epoch:39607  d_loss:0.0923  g_loss:8.4255
# epoch:39608  d_loss:0.0269  g_loss:5.4945
# epoch:39609  d_loss:0.0235  g_loss:8.2965
# epoch:39610  d_loss:0.0149  g_loss:8.9222
# epoch:39611  d_loss:0.2765  g_loss:7.2476
# epoch:39612  d_loss:0.0117  g_loss:8.1484
# epoch:39613  d_loss:0.0310  g_loss:12.9629
# epoch:39614  d_loss:0.0917  g_loss:9.6174
# epoch:39615  d_loss:0.0142  g_loss:9.3549
# epoch:39616  d_loss:0.1983  g_loss:9.7683
# epoch:39617  d_loss:0.0326  g_loss:10.8410
# epoch:39618  d_loss:0.1530  g_loss:5.3522
# epoch:39619  d_loss:0.2062  g_loss:9.4864
# epoch:39620  d_loss:0.0688  g_loss:14.2461
# epoch:39621  d_loss:0.0334  g_loss:18.4137
# epoch:39622  d_loss:1.0512  g_loss:5.2803
# epoch:39623  d_loss:1.5488  g_loss:8.1630
# epoch:39624  d_loss:0.0891  g_loss:18.2241
# epoch:39625  d_loss:0.9489  g_loss:13.4215
# epoch:39626  d_loss:0.0465  g_loss:7.9147
# epoch:39627  d_loss:0.0907  g_loss:5.2039
# epoch:39628  d_loss:0.0421  g_loss:6.2715
# epoch:39629  d_loss:0.3040  g_loss:7.3835
# epoch:39630  d_loss:0.4497  g_loss:7.1049
# epoch:39631  d_loss:0.1085  g_loss:6.1592
# epoch:39632  d_loss:0.1279  g_loss:6.3814
# epoch:39633  d_loss:0.1405  g_loss:7.5343
# epoch:39634  d_loss:0.0946  g_loss:8.2327
# epoch:39635  d_loss:0.3853  g_loss:8.7693
# epoch:39636  d_loss:0.3699  g_loss:6.7207
# epoch:39637  d_loss:0.0033  g_loss:7.5667
# epoch:39638  d_loss:0.0255  g_loss:9.7129
# epoch:39639  d_loss:0.0191  g_loss:8.6558
# epoch:39640  d_loss:0.1456  g_loss:8.5043
# epoch:39641  d_loss:0.2060  g_loss:6.3515
# epoch:39642  d_loss:0.0022  g_loss:8.9868
# epoch:39643  d_loss:0.0090  g_loss:10.3801
# epoch:39644  d_loss:0.6599  g_loss:6.6849
# epoch:39645  d_loss:0.0456  g_loss:4.6381
# epoch:39646  d_loss:0.3236  g_loss:6.9242
# epoch:39647  d_loss:0.2233  g_loss:10.7233
# epoch:39648  d_loss:0.1562  g_loss:13.0045
# epoch:39649  d_loss:0.2514  g_loss:11.3604
# epoch:39650  d_loss:0.0868  g_loss:7.2355
# epoch:39651  d_loss:0.0526  g_loss:6.5213
# epoch:39652  d_loss:0.2590  g_loss:9.5657
# epoch:39653  d_loss:0.0043  g_loss:13.6063
# epoch:39654  d_loss:0.0946  g_loss:13.9789
# epoch:39655  d_loss:0.3066  g_loss:7.7383
# epoch:39656  d_loss:0.3918  g_loss:5.9642
# epoch:39657  d_loss:0.2164  g_loss:8.4969
# epoch:39658  d_loss:0.0337  g_loss:11.2182
# epoch:39659  d_loss:0.0805  g_loss:12.0573
# epoch:39660  d_loss:0.1275  g_loss:9.9630
# epoch:39661  d_loss:0.0473  g_loss:10.2953
# epoch:39662  d_loss:0.1498  g_loss:10.1417
# epoch:39663  d_loss:0.0074  g_loss:9.5638
# epoch:39664  d_loss:0.1172  g_loss:11.1976
# epoch:39665  d_loss:0.0223  g_loss:11.3848
# epoch:39666  d_loss:0.0578  g_loss:13.7309
# epoch:39667  d_loss:0.1477  g_loss:10.8301
# epoch:39668  d_loss:0.2705  g_loss:7.3797
# epoch:39669  d_loss:0.0648  g_loss:9.8624
# epoch:39670  d_loss:0.0239  g_loss:13.4289
# epoch:39671  d_loss:0.3943  g_loss:12.0156
# epoch:39672  d_loss:0.1026  g_loss:4.4595
# epoch:39673  d_loss:0.0672  g_loss:5.7983
# epoch:39674  d_loss:0.6739  g_loss:8.8310
# epoch:39675  d_loss:0.0003  g_loss:13.7201
# epoch:39676  d_loss:0.0608  g_loss:16.8629
# epoch:39677  d_loss:0.5794  g_loss:9.9641
# epoch:39678  d_loss:0.2366  g_loss:6.1700
# epoch:39679  d_loss:0.2753  g_loss:5.5569
# epoch:39680  d_loss:0.0145  g_loss:8.8211
# epoch:39681  d_loss:0.0977  g_loss:12.9303
# epoch:39682  d_loss:0.2914  g_loss:9.8234
# epoch:39683  d_loss:0.2931  g_loss:9.4295
# epoch:39684  d_loss:0.0480  g_loss:7.4718
# epoch:39685  d_loss:0.1530  g_loss:6.7128
# epoch:39686  d_loss:0.0884  g_loss:4.3904
# epoch:39687  d_loss:0.1488  g_loss:6.9673
# epoch:39688  d_loss:0.0178  g_loss:9.1037
# epoch:39689  d_loss:0.4289  g_loss:8.1393
# epoch:39690  d_loss:0.0827  g_loss:7.9223
# epoch:39691  d_loss:0.0144  g_loss:8.1981
# epoch:39692  d_loss:0.0084  g_loss:6.3113
# epoch:39693  d_loss:0.0466  g_loss:7.2698
# epoch:39694  d_loss:0.0040  g_loss:7.0794
# epoch:39695  d_loss:0.0607  g_loss:9.3510
# epoch:39696  d_loss:0.0049  g_loss:10.1057
# epoch:39697  d_loss:0.0380  g_loss:10.6722
# epoch:39698  d_loss:0.0031  g_loss:10.1267
# epoch:39699  d_loss:0.0244  g_loss:11.6792
# epoch:39700  d_loss:0.0320  g_loss:10.5092
# id2 >  19
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39701  d_loss:0.0426  g_loss:9.5617
# epoch:39702  d_loss:0.0236  g_loss:7.2399
# epoch:39703  d_loss:0.4196  g_loss:8.3376
# epoch:39704  d_loss:0.0011  g_loss:14.5947
# epoch:39705  d_loss:0.3946  g_loss:10.2922
# epoch:39706  d_loss:0.1634  g_loss:7.3417
# epoch:39707  d_loss:0.0532  g_loss:6.2250
# epoch:39708  d_loss:0.0197  g_loss:5.4041
# epoch:39709  d_loss:0.2945  g_loss:11.6872
# epoch:39710  d_loss:0.1372  g_loss:14.5993
# epoch:39711  d_loss:0.4904  g_loss:8.2690
# epoch:39712  d_loss:0.0597  g_loss:6.1844
# epoch:39713  d_loss:0.2373  g_loss:4.8510
# epoch:39714  d_loss:0.2490  g_loss:5.8645
# epoch:39715  d_loss:0.2422  g_loss:9.9593
# epoch:39716  d_loss:0.0187  g_loss:12.0346
# epoch:39717  d_loss:0.1912  g_loss:11.4667
# epoch:39718  d_loss:0.1267  g_loss:5.8288
# epoch:39719  d_loss:0.1795  g_loss:7.8758
# epoch:39720  d_loss:0.0494  g_loss:8.0605
# epoch:39721  d_loss:0.0238  g_loss:8.9957
# epoch:39722  d_loss:0.1069  g_loss:10.3804
# epoch:39723  d_loss:0.0210  g_loss:8.1610
# epoch:39724  d_loss:0.0178  g_loss:8.2000
# epoch:39725  d_loss:0.0158  g_loss:7.6867
# epoch:39726  d_loss:0.0595  g_loss:10.4179
# epoch:39727  d_loss:0.0149  g_loss:10.4304
# epoch:39728  d_loss:0.0200  g_loss:11.6679
# epoch:39729  d_loss:0.2608  g_loss:10.1418
# epoch:39730  d_loss:0.0397  g_loss:15.6738
# epoch:39731  d_loss:0.9236  g_loss:9.9242
# epoch:39732  d_loss:0.5959  g_loss:5.7692
# epoch:39733  d_loss:0.2034  g_loss:12.0824
# epoch:39734  d_loss:0.0033  g_loss:14.3949
# epoch:39735  d_loss:0.5624  g_loss:12.0606
# epoch:39736  d_loss:0.0461  g_loss:8.2409
# epoch:39737  d_loss:0.0263  g_loss:7.0138
# epoch:39738  d_loss:0.1695  g_loss:7.6050
# epoch:39739  d_loss:0.1777  g_loss:8.9846
# epoch:39740  d_loss:0.0523  g_loss:13.0627
# epoch:39741  d_loss:0.3582  g_loss:10.1221
# epoch:39742  d_loss:0.2592  g_loss:8.1442
# epoch:39743  d_loss:0.0750  g_loss:5.9046
# epoch:39744  d_loss:0.3058  g_loss:8.3786
# epoch:39745  d_loss:0.0076  g_loss:11.8868
# epoch:39746  d_loss:0.0485  g_loss:14.6225
# epoch:39747  d_loss:0.9446  g_loss:10.7349
# epoch:39748  d_loss:0.0756  g_loss:5.1260
# epoch:39749  d_loss:0.7544  g_loss:10.7216
# epoch:39750  d_loss:0.0757  g_loss:22.3272
# epoch:39751  d_loss:1.0966  g_loss:18.9827
# epoch:39752  d_loss:0.4849  g_loss:11.4849
# epoch:39753  d_loss:0.1196  g_loss:8.1567
# epoch:39754  d_loss:0.7079  g_loss:8.4462
# epoch:39755  d_loss:0.0503  g_loss:14.4107
# epoch:39756  d_loss:0.6241  g_loss:7.9777
# epoch:39757  d_loss:0.4116  g_loss:5.0870
# epoch:39758  d_loss:0.1560  g_loss:7.0081
# epoch:39759  d_loss:0.1569  g_loss:9.6223
# epoch:39760  d_loss:0.1297  g_loss:9.6810
# epoch:39761  d_loss:0.0946  g_loss:7.5108
# epoch:39762  d_loss:0.0039  g_loss:8.3296
# epoch:39763  d_loss:0.0137  g_loss:7.5497
# epoch:39764  d_loss:0.2889  g_loss:10.2699
# epoch:39765  d_loss:0.0022  g_loss:12.8673
# epoch:39766  d_loss:0.0359  g_loss:14.1595
# epoch:39767  d_loss:0.0996  g_loss:10.0093
# epoch:39768  d_loss:0.0344  g_loss:8.7276
# epoch:39769  d_loss:0.0949  g_loss:7.1475
# epoch:39770  d_loss:0.2163  g_loss:6.2164
# epoch:39771  d_loss:0.0405  g_loss:9.2760
# epoch:39772  d_loss:0.1163  g_loss:10.9901
# epoch:39773  d_loss:0.3178  g_loss:9.1279
# epoch:39774  d_loss:0.0027  g_loss:12.3833
# epoch:39775  d_loss:0.1719  g_loss:8.1950
# epoch:39776  d_loss:0.2046  g_loss:8.3574
# epoch:39777  d_loss:0.0786  g_loss:7.9550
# epoch:39778  d_loss:0.1232  g_loss:10.6675
# epoch:39779  d_loss:0.0444  g_loss:11.4707
# epoch:39780  d_loss:0.1029  g_loss:11.5755
# epoch:39781  d_loss:0.0212  g_loss:11.9182
# epoch:39782  d_loss:0.0189  g_loss:11.0117
# epoch:39783  d_loss:0.3178  g_loss:9.0188
# epoch:39784  d_loss:0.0441  g_loss:6.3933
# epoch:39785  d_loss:0.1090  g_loss:5.5853
# epoch:39786  d_loss:0.0589  g_loss:6.8298
# epoch:39787  d_loss:0.1733  g_loss:12.4454
# epoch:39788  d_loss:0.0370  g_loss:14.2054
# epoch:39789  d_loss:0.6525  g_loss:11.6736
# epoch:39790  d_loss:0.1643  g_loss:4.9149
# epoch:39791  d_loss:0.0340  g_loss:7.0648
# epoch:39792  d_loss:0.1701  g_loss:5.8663
# epoch:39793  d_loss:0.1709  g_loss:9.3959
# epoch:39794  d_loss:0.1756  g_loss:11.0158
# epoch:39795  d_loss:0.0098  g_loss:11.3810
# epoch:39796  d_loss:0.2783  g_loss:9.0740
# epoch:39797  d_loss:0.0126  g_loss:7.3537
# epoch:39798  d_loss:0.1175  g_loss:7.7263
# epoch:39799  d_loss:0.1418  g_loss:8.9161
# epoch:39800  d_loss:0.0094  g_loss:11.7465
# id2 >  22
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39801  d_loss:0.0024  g_loss:9.4081
# epoch:39802  d_loss:0.2170  g_loss:8.2706
# epoch:39803  d_loss:0.0315  g_loss:8.1294
# epoch:39804  d_loss:0.0428  g_loss:8.7039
# epoch:39805  d_loss:0.1966  g_loss:7.2490
# epoch:39806  d_loss:0.0438  g_loss:6.3276
# epoch:39807  d_loss:0.0914  g_loss:7.6218
# epoch:39808  d_loss:0.1180  g_loss:8.2322
# epoch:39809  d_loss:0.0233  g_loss:12.1003
# epoch:39810  d_loss:0.2914  g_loss:12.8020
# epoch:39811  d_loss:0.3085  g_loss:11.1470
# epoch:39812  d_loss:0.1304  g_loss:5.8415
# epoch:39813  d_loss:0.1286  g_loss:9.2031
# epoch:39814  d_loss:0.0991  g_loss:12.0492
# epoch:39815  d_loss:0.0182  g_loss:16.8297
# epoch:39816  d_loss:0.3855  g_loss:11.9143
# epoch:39817  d_loss:0.4275  g_loss:10.0530
# epoch:39818  d_loss:0.0930  g_loss:10.5734
# epoch:39819  d_loss:0.0108  g_loss:11.0226
# epoch:39820  d_loss:0.0016  g_loss:11.1149
# epoch:39821  d_loss:0.0313  g_loss:11.9879
# epoch:39822  d_loss:0.3133  g_loss:10.4300
# epoch:39823  d_loss:0.0475  g_loss:7.7530
# epoch:39824  d_loss:0.0220  g_loss:7.2290
# epoch:39825  d_loss:0.1675  g_loss:5.3628
# epoch:39826  d_loss:0.3344  g_loss:8.9094
# epoch:39827  d_loss:0.0125  g_loss:12.9157
# epoch:39828  d_loss:0.1500  g_loss:11.9793
# epoch:39829  d_loss:0.1330  g_loss:8.3761
# epoch:39830  d_loss:0.1941  g_loss:9.0953
# epoch:39831  d_loss:0.0060  g_loss:8.3082
# epoch:39832  d_loss:0.4431  g_loss:9.5070
# epoch:39833  d_loss:0.0092  g_loss:10.4581
# epoch:39834  d_loss:0.0048  g_loss:11.4717
# epoch:39835  d_loss:0.0130  g_loss:11.9920
# epoch:39836  d_loss:0.0481  g_loss:12.4126
# epoch:39837  d_loss:0.0743  g_loss:11.0924
# epoch:39838  d_loss:0.0638  g_loss:11.4305
# epoch:39839  d_loss:0.0042  g_loss:12.9179
# epoch:39840  d_loss:0.0047  g_loss:11.9529
# epoch:39841  d_loss:0.0497  g_loss:10.9982
# epoch:39842  d_loss:0.0156  g_loss:10.7083
# epoch:39843  d_loss:0.0537  g_loss:10.0682
# epoch:39844  d_loss:0.2863  g_loss:6.8316
# epoch:39845  d_loss:0.0043  g_loss:8.7175
# epoch:39846  d_loss:0.0712  g_loss:9.7494
# epoch:39847  d_loss:0.4748  g_loss:17.1236
# epoch:39848  d_loss:0.4308  g_loss:20.8928
# epoch:39849  d_loss:0.6176  g_loss:14.3078
# epoch:39850  d_loss:0.2835  g_loss:12.6172
# epoch:39851  d_loss:0.0765  g_loss:7.7052
# epoch:39852  d_loss:0.0606  g_loss:10.8112
# epoch:39853  d_loss:0.0812  g_loss:10.0907
# epoch:39854  d_loss:0.0574  g_loss:11.7979
# epoch:39855  d_loss:0.0695  g_loss:9.8745
# epoch:39856  d_loss:0.1009  g_loss:10.0171
# epoch:39857  d_loss:0.1391  g_loss:9.5985
# epoch:39858  d_loss:0.0869  g_loss:4.7644
# epoch:39859  d_loss:0.1962  g_loss:6.7517
# epoch:39860  d_loss:0.0419  g_loss:8.3003
# epoch:39861  d_loss:0.1560  g_loss:9.7247
# epoch:39862  d_loss:0.0117  g_loss:8.6945
# epoch:39863  d_loss:0.0022  g_loss:9.4511
# epoch:39864  d_loss:0.0183  g_loss:10.0331
# epoch:39865  d_loss:0.0069  g_loss:8.4657
# epoch:39866  d_loss:0.0074  g_loss:8.5202
# epoch:39867  d_loss:0.0601  g_loss:8.9236
# epoch:39868  d_loss:0.0151  g_loss:8.4110
# epoch:39869  d_loss:0.0106  g_loss:9.9645
# epoch:39870  d_loss:0.0275  g_loss:10.5947
# epoch:39871  d_loss:0.0924  g_loss:10.2103
# epoch:39872  d_loss:0.0257  g_loss:10.7516
# epoch:39873  d_loss:0.0042  g_loss:8.5957
# epoch:39874  d_loss:0.0340  g_loss:11.3729
# epoch:39875  d_loss:0.3134  g_loss:11.3604
# epoch:39876  d_loss:0.1433  g_loss:7.7629
# epoch:39877  d_loss:0.0275  g_loss:8.6178
# epoch:39878  d_loss:0.0058  g_loss:8.7209
# epoch:39879  d_loss:0.0711  g_loss:9.5835
# epoch:39880  d_loss:0.0024  g_loss:9.8157
# epoch:39881  d_loss:0.0067  g_loss:10.4349
# epoch:39882  d_loss:0.0067  g_loss:10.5470
# epoch:39883  d_loss:0.0027  g_loss:10.5376
# epoch:39884  d_loss:0.0020  g_loss:9.5212
# epoch:39885  d_loss:0.0310  g_loss:10.7877
# epoch:39886  d_loss:0.1208  g_loss:9.7036
# epoch:39887  d_loss:0.0644  g_loss:7.6608
# epoch:39888  d_loss:0.0032  g_loss:8.8960
# epoch:39889  d_loss:0.1465  g_loss:10.5487
# epoch:39890  d_loss:0.0049  g_loss:12.9374
# epoch:39891  d_loss:0.0990  g_loss:9.3858
# epoch:39892  d_loss:0.0873  g_loss:10.6881
# epoch:39893  d_loss:0.1857  g_loss:7.2678
# epoch:39894  d_loss:0.4946  g_loss:6.3720
# epoch:39895  d_loss:0.0014  g_loss:8.9394
# epoch:39896  d_loss:0.0837  g_loss:10.9284
# epoch:39897  d_loss:0.5110  g_loss:8.3667
# epoch:39898  d_loss:0.3280  g_loss:7.9364
# epoch:39899  d_loss:0.0013  g_loss:12.0839
# epoch:39900  d_loss:0.0673  g_loss:11.8685
# id2 >  11
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# epoch:39901  d_loss:0.5544  g_loss:11.5410
# epoch:39902  d_loss:0.1478  g_loss:6.9141
# epoch:39903  d_loss:0.3214  g_loss:9.3703
# epoch:39904  d_loss:0.1973  g_loss:12.0076
# epoch:39905  d_loss:0.1344  g_loss:11.6648
# epoch:39906  d_loss:0.1939  g_loss:10.5388
# epoch:39907  d_loss:0.3818  g_loss:6.6386
# epoch:39908  d_loss:0.0621  g_loss:7.5743
# epoch:39909  d_loss:0.1578  g_loss:4.8396
# epoch:39910  d_loss:0.1747  g_loss:10.1410
# epoch:39911  d_loss:0.0264  g_loss:11.2457
# epoch:39912  d_loss:0.1207  g_loss:9.9475
# epoch:39913  d_loss:0.0042  g_loss:10.6367
# epoch:39914  d_loss:0.0101  g_loss:8.8412
# epoch:39915  d_loss:0.0471  g_loss:8.4158
# epoch:39916  d_loss:0.0137  g_loss:7.0646
# epoch:39917  d_loss:0.0411  g_loss:6.7877
# epoch:39918  d_loss:0.0693  g_loss:7.4454
# epoch:39919  d_loss:0.0696  g_loss:7.6828
# epoch:39920  d_loss:0.0077  g_loss:8.3062
# epoch:39921  d_loss:0.0287  g_loss:8.2020
# epoch:39922  d_loss:0.0416  g_loss:7.9996
# epoch:39923  d_loss:0.0207  g_loss:9.0490
# epoch:39924  d_loss:0.0130  g_loss:10.1685
# epoch:39925  d_loss:0.0160  g_loss:9.1498
# epoch:39926  d_loss:0.0683  g_loss:7.1717
# epoch:39927  d_loss:0.0013  g_loss:8.1311
# epoch:39928  d_loss:0.0401  g_loss:7.7346
# epoch:39929  d_loss:0.0600  g_loss:6.8140
# epoch:39930  d_loss:0.0177  g_loss:9.9350
# epoch:39931  d_loss:0.2171  g_loss:9.6521
# epoch:39932  d_loss:0.0058  g_loss:8.6872
# epoch:39933  d_loss:0.0080  g_loss:9.5553
# epoch:39934  d_loss:0.0204  g_loss:8.9167
# epoch:39935  d_loss:0.0303  g_loss:7.7909
# epoch:39936  d_loss:0.0033  g_loss:9.1334
# epoch:39937  d_loss:0.2885  g_loss:10.1030
# epoch:39938  d_loss:0.1519  g_loss:9.6323
# epoch:39939  d_loss:0.0023  g_loss:8.5802
# epoch:39940  d_loss:0.1589  g_loss:7.1652
# epoch:39941  d_loss:0.0258  g_loss:9.0698
# epoch:39942  d_loss:0.0769  g_loss:9.9224
# epoch:39943  d_loss:0.0749  g_loss:12.3005
# epoch:39944  d_loss:0.0735  g_loss:9.8283
# epoch:39945  d_loss:0.0651  g_loss:9.1486
# epoch:39946  d_loss:0.2657  g_loss:10.1760
# epoch:39947  d_loss:0.0420  g_loss:12.5381
# epoch:39948  d_loss:0.0097  g_loss:12.1984
# epoch:39949  d_loss:0.3302  g_loss:9.3207
# epoch:39950  d_loss:0.0891  g_loss:7.0074
# epoch:39951  d_loss:0.1339  g_loss:6.1194
# epoch:39952  d_loss:0.0365  g_loss:6.2211
# epoch:39953  d_loss:0.0166  g_loss:11.7090
# epoch:39954  d_loss:0.0209  g_loss:9.2899
# epoch:39955  d_loss:0.1786  g_loss:8.8326
# epoch:39956  d_loss:0.0180  g_loss:6.8812
# epoch:39957  d_loss:0.0823  g_loss:6.4261
# epoch:39958  d_loss:0.0527  g_loss:8.8882
# epoch:39959  d_loss:0.0024  g_loss:10.6011
# epoch:39960  d_loss:0.0559  g_loss:9.4934
# epoch:39961  d_loss:0.0011  g_loss:11.8518
# epoch:39962  d_loss:0.0786  g_loss:10.3709
# epoch:39963  d_loss:0.0834  g_loss:9.2963
# epoch:39964  d_loss:0.1072  g_loss:6.1273
# epoch:39965  d_loss:0.0453  g_loss:5.4600
# epoch:39966  d_loss:0.1281  g_loss:8.2560
# epoch:39967  d_loss:0.0214  g_loss:10.7264
# epoch:39968  d_loss:0.0153  g_loss:11.9611
# epoch:39969  d_loss:0.0693  g_loss:12.4804
# epoch:39970  d_loss:0.0033  g_loss:14.9532
# epoch:39971  d_loss:0.1001  g_loss:13.9130
# epoch:39972  d_loss:0.0005  g_loss:13.2903
# epoch:39973  d_loss:0.1982  g_loss:10.6373
# epoch:39974  d_loss:0.0668  g_loss:8.2874
# epoch:39975  d_loss:0.0068  g_loss:8.0277
# epoch:39976  d_loss:0.2046  g_loss:9.8511
# epoch:39977  d_loss:0.0939  g_loss:11.7492
# epoch:39978  d_loss:0.0464  g_loss:16.3749
# epoch:39979  d_loss:0.4275  g_loss:10.9558
# epoch:39980  d_loss:0.0427  g_loss:6.1151
# epoch:39981  d_loss:0.2721  g_loss:5.4074
# epoch:39982  d_loss:0.1776  g_loss:10.0963
# epoch:39983  d_loss:0.0007  g_loss:12.4444
# epoch:39984  d_loss:0.1564  g_loss:15.3553
# epoch:39985  d_loss:0.4880  g_loss:8.1618
# epoch:39986  d_loss:0.2193  g_loss:8.1310
# epoch:39987  d_loss:0.0112  g_loss:10.0087
# epoch:39988  d_loss:0.0156  g_loss:8.5748
# epoch:39989  d_loss:0.0461  g_loss:9.7877
# epoch:39990  d_loss:0.1335  g_loss:9.5381
# epoch:39991  d_loss:0.0837  g_loss:7.8184
# epoch:39992  d_loss:0.0347  g_loss:10.3821
# epoch:39993  d_loss:0.0736  g_loss:7.3775
# epoch:39994  d_loss:0.0964  g_loss:8.4482
# epoch:39995  d_loss:0.0214  g_loss:7.2154
# epoch:39996  d_loss:0.2210  g_loss:6.6237
# epoch:39997  d_loss:0.1260  g_loss:5.9281
# epoch:39998  d_loss:0.0388  g_loss:7.4149
# epoch:39999  d_loss:0.0010  g_loss:8.5379
# epoch:40000  d_loss:0.2304  g_loss:6.9859
# id2 >  1
# (25, 68, 68, 1)
# (862, 128)
# (128, 862)
# (110208,)
# end
# 작업 시간 :  2:16:43.422051

# %%
loss_csv = pd.read_csv('E:\\nmb\\gan_image\\csv\\loss_dcgan09.csv')
# print(loss_csv)
# print(loss_csv.shape)
 
# generator loss
plt.plot(loss_csv['g_loss'])

plt.title(epochs-1)
plt.show()

# %%
# discriminator loss
plt.plot(loss_csv['d_loss'], color='orange')

plt.title(epochs-1)
plt.show()
